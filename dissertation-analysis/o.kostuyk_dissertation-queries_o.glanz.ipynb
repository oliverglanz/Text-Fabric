# %% [markdown]
# # Response to Christian Vogel's Dissertation

# %% [markdown]
# # Prelude

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %%
OT = use('bhsa', version='2017', hoist=globals())
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.3.0=#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">C:\Users\Oliver Glanz/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 offline under ~/text-fabric-data">C:\Users\Oliver Glanz/text-fabric-data/etcbc/bhsa/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">C:\Users\Oliver Glanz/text-fabric-data/etcbc/phono/tf/2017</span>
# <b title="local release">data:</b> <span title="r1.2=#395dfe2cb69c261862fab9f0289e594a52121d5c offline under ~/text-fabric-data">C:\Users\Oliver Glanz/text-fabric-data/etcbc/parallels/tf/2017</span>
# ...

# %%
NT = use('tisch', hoist=globals())
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.3.1=#87b0d7fca84918f8d0fd664618e5e3370a46d08c offline under ~/text-fabric-data">C:\Users\Oliver Glanz/text-fabric-data/annotation/app-tisch/code</span>
# <b title="local release">data:</b> <span title="rv.1.12=#c8a8b8c0d9f1746f050f4da0a3e0421835b378df offline under ~/text-fabric-data">C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8</span>
# ...

# %% [markdown]
# ## Introduction and Laudatio
# 1. Yesterday, when I went to bed reading once again through your work, Karen asked me “so, how is the read?”. I told her that it is one of the rather rare dissertations that are easy to read, easy to understand, fun to engage with, interdisciplinary, and directly relevant. In fact, I told her, it is very rare that I read a dissertation that I can bring right to the pulpit to preach from it.
# 2. I think this dissertation represents very much who Oleg is. He moves and engages in the scholarly world with ease and understanding but does so always with the matters of real life, its social, economic, political, and ethical challenges in mind. The language he uses is simple, straight to the point, clear and engaging. In fact, I cannot but think that his dissertation mirrors to a good extent his life in sports: He wrote fast, he cuts down information that is unnecessary baggage, and his book applies the strategy of the negative split. While usually the reader slows down in the second half of a dissertation, I found myself reading faster and getting more excited once I entered the second half of his dissertation.

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Minor Questions
# 1. You state that Mark has been influenced by the messiancing interpretation of Gen 3:15 (p64). Where do you see that?
# 2. Check your Hebrew words. The letters are sometimes in wrong order (e.g. p104).

# %% [markdown]
# ### OT related questions:
# 1. Did you do an analysis of the “aggressive”/”military” language of the messianic texts? YOu will find that they are…

# %%
Schuf = '''
clause
    w1:word lex=CWP[|MXY[|QRR[

'''
Schuf  = OT.search(Schuf)
OT.table(Schuf, start=1, end=10, condensed=False)
# Out:
#   1.18s 18 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="section ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=15&amp;version=2017&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:15">Genesis 3:15</a></span></td><td class="tf rtl"><span class="rtl"><span class="plain rtl  hlbx" ><span class="txtu hbo">ה֚וּא </span><span class="plain rtl  hl" ><span class="txtu hbo">יְשׁוּפְךָ֣ </span></span><span class="txtu hbo">רֹ֔אשׁ </span></span></span></td><td class="tf rtl"><span class="rtl"><span class="plain rtl  hl" ><span class="txtu hbo">יְשׁוּפְךָ֣ </span></span></span></td></tr>
# ...

# %% [markdown]
# 2. I have the impression that Mark reverses the prophetic language of the OT. While you find in the OT that military realities are interpreted spiritually (soldiers are sacrificed - not killed; they die by worshipping the gods - not through warfare) Mark portraits the healer as a general who commands. What is your take on this?

# %% [markdown]
# ### General Questions
# 1. “Son of God” and “Son of man” usage as part of the Markian paradoxical incognito (pp82-85). Why did search its meaning and function mainly within the OT and did not establish the connection to Roman culture and politics where the same term is used for the caesars?
#
# ![image.png](attachment:image.png)

# %%
SonOfGod = '''
verse
    w1:word lex_og=uios
    w2:word lex_og=theos case=genitive
w1 <: w2
'''
SonOfGod  = NT.search(SonOfGod)
NT.table(SonOfGod, start=1, end=10, condensed=False)
# Out:
#   0.62s 7 results
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">verse</th><th class="tf">word</th><th class="tf">word</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="section ltr">Matthew 5:9</span></td><td class="tf ltr"><span class=""></span></td><td class="tf ltr"><span class=""><span class="plain   hl" ><span class="txtu grc">υἱοὶ </span></span></span></td><td class="tf ltr"><span class=""><span class="plain   hl" ><span class="txtu grc">θεοῦ </span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="section ltr">Luke 1:35</span></td><td class="tf ltr"><span class=""></span></td><td class="tf ltr"><span class=""><span class="plain   hl" ><span class="txtu grc">υἱὸς </span></span></span></td><td class="tf ltr"><span class=""><span class="plain   hl" ><span class="txtu grc">θεοῦ. </span></span></span></td></tr>
# ...

# %% [markdown]
# 2. How implicit is the military motif? (p87). I think you have convincingly shown that it is there. In addition, recent scholarship has clearly recognized the same (Gerladini, SChulz). Do you still think that the military references are only implicit and therefore only the reader who “digs deeper” (p88) will be able to recognize (see the work of Luz)? But then, you seem to contradict yourself when you state clearly “the language in the passage is clearly military” (p98).

# %% [markdown]
# 3. p119: why do you not use the platter contrast not later when you explain how the author plays with the reader’s biases?

# %% [markdown]
# 4. The word for miracles is not used in the gospels…

# %% [markdown]
# 5. The original ending of Mark (“and they feared”) is highly emotional and requires a re-reading. Why did you not use this as an argument for the intentional working of the author with the reader’s mind?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Method Questions
# 1. p135ff: It seems that your main focus in reconstructing the plot is on (a) participant (re)introduction, (b) time and space (setting)references, (c) lexical use. But one of the most influential reader-directions is realized by the verbal tense system. I did, however, not find any reference to how the verbal tenses function in the plot development. Think e.g. of the surprising use of the present tense (v31, 37, 38, 48, 50) in a general Aorist context.

# %% [markdown]
# 2. Already 30 years ago Ulrich Luz has identified that Mark seeks to play with the biases of the reader. He came to that conclusion without applying a cognitive-literary method. Why then, is your method necessary if one can come to these conclusions with a cognitive analysis?

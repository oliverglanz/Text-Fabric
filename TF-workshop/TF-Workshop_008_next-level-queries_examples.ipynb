# %%
# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# %%
# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %%
# Now we load a few databases
#BHSa2017 = use('etcbc/bhsa', version='2017')
#BHSaLatest = use('etcbc/bhsa:latest')
#BHSaC = use('etcbc/bhsa', version='c', mod='CenterBLC/BHSaddons/tf')
BHS = use('etcbc/bhsa', version="2021", mod='CenterBLC/BHSaddons/tf', hoist=globals())
bhsF, bhsL, bhsT, bhsS = BHS.api.F, BHS.api.L, BHS.api.T, BHS.api.S

LXX = use("CenterBLC/LXX", version="1935", hoist=globals())
lxxF, lxxL, lxxT, lxxS = LXX.api.F, LXX.api.L, LXX.api.T, LXX.api.S

DSS = use('etcbc/dss', hoist=globals())
dssF, dssL, dssT, dssS = DSS.api.F, DSS.api.L, DSS.api.T, DSS.api.S

GNT = use ("CenterBLC/N1904", version="1.0.0", mod="CenterBLC/N1904/BOLcomplement/tf/", hoist=globals())
gntF, gntL, gntT, gntS = GNT.api.F, GNT.api.L, GNT.api.T, GNT.api.S
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local commit">data:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local commit">data:</b> <span title="#b85ab6e676c425ed8ca20c649daf9099bce26627 offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gaba4367b49750089e4e4122415a77cac43bd97bc offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gf45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
# <b title="local commit">data:</b> <span title="#gb112c161cfd21eae403d51a2733740d8743460e7 offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/ner</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.13</a>, <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/app" title="etcbc/bhsa app">etcbc/bhsa/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">etcbc - bhsa 2021</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="etcbc - bhsa feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>39</td>
#     <td>10938.21</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>929</td>
#     <td>459.19</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>lex</th>
#     <td>9230</td>
#     <td>46.22</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>23213</td>
#     <td>18.38</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>half_verse</th>
#     <td>45179</td>
#     <td>9.44</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>63717</td>
#     <td>6.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence_atom</th>
#     <td>64514</td>
#     <td>6.61</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>88131</td>
#     <td>4.84</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause_atom</th>
#     <td>90704</td>
#     <td>4.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>253203</td>
#     <td>1.68</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase_atom</th>
#     <td>267532</td>
#     <td>1.59</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>113850</td>
#     <td>1.42</td>
#     <td>38</td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>426590</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>Parallel Passages</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://nbviewer.jupyter.org/github/etcbc/parallels/blob/master/programs/parallels.ipynb" title="~/text-fabric-data/github/etcbc/parallels/tf/2021/crossref.tf">crossref</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 🆗 links between similar passages</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b><github>CenterBLC/BHSaddons/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_bhsa_word_order.tf">bol_bhsa_word_order</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ the sequence number of each word in the BHSa (1,2,3,...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_EN.tf">bol_dict_EN</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ English glosses of the BibleOL Hebrew/Aramaic dictionary</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_ES.tf">bol_dict_ES</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ Spanish glosses of the BibleOL Hebrew/Aramaic dictionary</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_HebArm.tf">bol_dict_HebArm</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ BibleOL Hebrew/Aramaic dictionary with homograph disambiguation (ברא I. ברא II)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_abc.tf">bol_dict_abc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ The dictionary sequence number of each word (1,2,3,...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_vc.tf">bol_dict_vc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ BibleOL verbal classes (i-nun, ii-waw, ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/g_word_noaccent.tf">g_word_noaccent</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ each text-realized word with consonants and vowels but no Masoretic signs (B.@R@>, >:ELOHIJM)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/interlinear.tf">interlinear</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ BibleOL verbal classes (i-nun, ii-waw, ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/lex_cons.tf">lex_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ each word in its consonantal form only and with not disambiguation (BR>, >LHJM)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/strong.tf">strong</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ Strong's numbers</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in Latin (Genesis; Numeri; Reges1; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book@am.tf">book@ll</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in amharic (ኣማርኛ)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ chapter number (1; 2; 3; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/code.tf">code</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ identifier of a clause atom relationship (0; 74; 367; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/det.tf">det</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ determinedness of phrase(at
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#f32a98eddf7eb239aa73ab863d70381e416d5076 offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/LXX/app</span>
# <b title="local commit">data:</b> <span title="#f32a98eddf7eb239aa73ab863d70381e416d5076 offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/LXX/tf/1935</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.13</a>, <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/app" title="CenterBLC/LXX app">CenterBLC/LXX/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/home.md" title="provenance of LXX">CenterBLC - LXX 1935</a>, <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features.md" title="Greek characters transcription">Character table</a>, <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/home.md" title="CenterBLC - LXX feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>57</td>
#     <td>10941.98</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>1192</td>
#     <td>523.23</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>30371</td>
#     <td>20.54</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>subverse</th>
#     <td>30419</td>
#     <td>20.50</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>623693</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>LXX</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/abc_order.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/abc_order.tf">abc_order</a>
# </div>
# <div class="fmono">str</div>
#
# <span> dictionary order</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/bol_gloss.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/bol_gloss.tf">bol_gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> BOL English gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/bol_lexeme_dict.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/bol_lexeme_dict.tf">bol_lexeme_dict</a>
# </div>
# <div class="fmono">str</div>
#
# <span> BOL dictionary form of lemma</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/book.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/case.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/case.tf">case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/chapter.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/degree.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/degree.tf">degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> degree</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/freq_lemma.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/freq_lemma.tf">freq_lemma</a>
# </div>
# <div class="fmono">str</div>
#
# <span> frequency of word in corpus</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/g_cons_utf8.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/g_cons_utf8.tf">g_cons_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> word without accents</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/gloss.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/gn.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/lex.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/lex.tf">lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lemma transliteration</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/lex_utf8.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/lex_utf8.tf">lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> normalized word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/mood.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/mood.tf">mood</a>
# </div>
# <div class="fmono">str</div>
#
# <span> mood</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/morphology.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/morphology.tf">morphology</a>
# </div>
# <div class="fmono">str</div>
#
# <span> morphology</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/nu.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/nu.tf">nu</a>
# </div>
# <div class="fmono">str</div>
#
# <span> number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/orig_order.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/orig_order.tf">orig_order</a>
# </div>
# <div class="fmono">str</div>
#
# <span> original word order</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/otype.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/otype.tf">otype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> </span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/ps.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/ps.tf">ps</a>
# </div>
# <div class="fmono">str</div>
#
# <span> person</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/sp.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/sp.tf">sp</a>
# </div>
# <div class="fmono">str</div>
#
# <span> part of speech</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/LXX/blob/master/docs/features/strongs.md" title="~/text-fabric-data/github/CenterBLC/LXX/tf/1935/strongs.tf">strongs</a>
# </div>
# <div class="fmono">str</div>
#
# <span> strongs number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target=
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/app</span>
# <b title="local commit">data:</b> <span title="#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/tf/1.9</span>
# <b title="local commit">data:</b> <span title="#5e032551a4c9ccf86f21c20d66a4180f9f4cae7f offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/parallels/tf/1.9</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 13.0.13</a>, <a target="_blank" href="https://github.com/etcbc/dss/blob/master/app" title="etcbc/dss app">etcbc/dss/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/about.md" title="provenance of Dead Sea Scrolls">etcbc - dss 1.9</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="etcbc - dss feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>scroll</th>
#     <td>1001</td>
#     <td>1428.81</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>lex</th>
#     <td>10450</td>
#     <td>129.14</td>
#     <td>94</td>
# </tr>
#
# <tr>
#     <th>fragment</th>
#     <td>11182</td>
#     <td>127.91</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>line</th>
#     <td>52895</td>
#     <td>27.04</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>125</td>
#     <td>12.85</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>cluster</th>
#     <td>101099</td>
#     <td>6.68</td>
#     <td>47</td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>315</td>
#     <td>5.10</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>500995</td>
#     <td>2.81</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th><i>sign</i></th>
#     <td>1430241</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b><github>etcbc/dss/parallels/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://github.com/etcbc/dss/tree/master/parallels/tf" title="~/text-fabric-data/github/etcbc/dss/parallels/tf/1.9/sim.tf">sim</a>
# </div>
# <div class="fmono">int</div>
#
# <span> similarity between lines, as a percentage of the common material wrt the combined material</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>Dead Sea Scrolls</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> space behind the word, if any</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/alt.tf">alt</a>
# </div>
# <div class="fmono">int</div>
#
# <span> alternative reading</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/biblical.tf">biblical</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether we are in biblical material or not</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> acronym of the book in which the word occurs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/book_etcbc.tf">book_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/chapter.tf">chapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> label of the chapter in which the word occurs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/cl.tf">cl</a>
# </div>
# <div class="fmono">str</div>
#
# <span> class (morphology tag)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/cl2.tf">cl2</a>
# </div>
# <div class="fmono">str</div>
#
# <span> class (for part 2) (morphology tag)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/cor.tf">cor</a>
# </div>
# <div class="fmono">int</div>
#
# <span> correction made by an ancient or modern editor</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/fragment.tf">fragment</a>
# </div>
# <div class="fmono">str</div>
#
# <span> label of a fragment of a scroll</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/full.tf">full</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (Unicode) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/fulle.tf">fulle</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (ETCBC transliteration) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/fullo.tf">fullo</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (original source) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/g_nme_etcbc.tf">g_nme_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/g_prs_etcbc.tf">g_prs_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/text-fabric-data/github/etcbc/dss/tf/1.9/glex.tf">glex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> representation (Unicode) of a lexeme leaving out non-letters</span>
#
# </div>
#
# <div class="frow">
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# ...
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>group</th>
#     <td>8945</td>
#     <td>7.01</td>
#     <td>46</td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>42506</td>
#     <td>8.36</td>
#     <td><i>258</i></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>106868</td>
#     <td>6.88</td>
#     <td><i>533</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>69007</td>
#     <td>1.90</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>116178</td>
#     <td>1.60</td>
#     <td><i>135</i></td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b><github>CenterBLC/N1904/BOLcomplement/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AU_declension.tf">AU_declension</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Andrews University declension selection for exercises</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AU_exercise_selection.tf">AU_exercise_selection</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Andrews University declension selection for exercises</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AU_vocab_builder_chapter.tf">AU_vocab_builder_chapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Andrews University vocab builder booklet chapter</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopChapter.tf">AlandSynopChapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Aland Synoptic Parallel Chapter</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopChapterNr.tf">AlandSynopChapterNr</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Aland Synoptic Parallel Number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopEvent.tf">AlandSynopEvent</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Aland Synoptic Parallel Event</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopEventNr.tf">AlandSynopEventNr</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Aland Synoptic Parallel Event</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopNo.tf">AlandSynopNo</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Aland Synoptic Parallel Number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/BGVB.tf">BGVB</a>
# </div>
# <div class="fmono">str</div>
#
# <span> chapter categoried vocab as it appears in Larry Richards Textbook "Learning Greek in 30 days"</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/abc_order.tf">abc_order</a>
# </div>
# <div class="fmono">int</div>
#
# <span> the dictionary position of a given word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_case.tf">bol_case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_dict_abc.tf">bol_dict_abc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based dictionary position of a given word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_frequency_rank.tf">bol_frequency_rank</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Bible Online Learner based frequency rank of a given lexeme</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_gender.tf">bol_gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_gloss_EN.tf">bol_gloss_EN</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based English gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/text-fabric-data/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_gloss_PT.tf">bol_gloss_PT</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based Portuguese gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="http
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)
# See [here](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/viewtypes.md#start) for more information on viewtypes

# %%
from IPython.display import Image, display

# %% [markdown]
# # Finding Referential Information: Sample Case: Divine Attribution
#
# Referential information is organized in terms of `child` - `mother` relationships.
#
# See here:
#
# ![image.png](attachment:e0d0f21b-19f5-460f-85ec-db1f8f63474d.png)

# %%
bhsS.relationsLegend()
# Out:
#                       = left equal to right (as node)
#                       # left unequal to right (as node)
#                       < left before right (in canonical node ordering)
#                       > left after right (in canonical node ordering)
#                      == left occupies same slots as right
#                      && left has overlapping slots with right
#                      ## left and right do not have the same slot set
#                      || left and right do not have common slots
#                      [[ left embeds right
#                      ]] left embedded in right
#                      << left completely before right
#                      >> left completely after right
#                      =: left and right start at the same slot
#                      := left and right end at the same slot
#                      :: left and right start and end at the same slot
#                      <: left immediately before right
#                      :> left immediately after right
#                     =k: left and right start at k-nearly the same slot
#                     :k= left and right end at k-nearly the same slot
#                     :k: left and right start and end at k-near slots
#                     <k: left k-nearly before right
#                     :k> left k-nearly after right
#                     .f. left.f = right.f
#                   .f=g. left.f = right.g
#                 .f~r~g. left.f matches right.g
#                   .f#g. left.f # right.g
#                   .f>g. left.f > right.g
#                   .f<g. left.f < right.g
#              -crossref> edge feature "crossref" with value specification allowed
#              <crossref- edge feature "crossref" with value specification allowed (opposite direction)
#              <crossref> edge feature "crossref" with value specification allowed (either direction)
#           -crossrefLCS> edge feature "crossrefLCS" with value specification allowed
#           <crossrefLCS- edge feature "crossrefLCS" with value specification allowed (opposite direction)
#           <crossrefLCS> edge feature "crossrefLCS" with value specification allowed (either direction)
#           -crossrefSET> edge feature "crossrefSET" with value specification allowed
#           <crossrefSET- edge feature "crossrefSET" with value specification allowed (opposite direction)
#           <crossrefSET> edge feature "crossrefSET" with value specification allowed (either direction)
# -distributional_parent> edge feature "distributional_parent"
# <distributional_parent- edge feature "distributional_parent" (opposite direction)
# <distributional_parent> edge feature "distributional_parent" (either direction)
#     -functional_parent> edge feature "functional_parent"
#     <functional_parent- edge feature "functional_parent" (opposite direction)
#     <functional_parent> edge feature "functional_parent" (either direction)
#                -mother> edge feature "mother"
#                <mother- edge feature "mother" (opposite direction)
#                <mother> edge feature "mother" (either direction)
# The warp feature "oslots" and omap features cannot be used in searches.
# One of the above relations on nodes and / or slots will suit you better.

# %% [markdown]
# ## Looking for Divine Attribution

# %% [markdown]
# This query finds all cases in which YHWH, Elohim, or El are attributed by adjectival sub-phrases. For example:
#
#
# >And he was the priest of **[God{mother-subphrase}, the most high{daughter-subphrase}]**
#
#
# The TF query below recreates the following SHEBANQ/EMDROS query: http://shebanq.ancient-data.org/hebrew/query?version=2021&id=1124

# %%
DivineAttributesNo1 = '''
verse book
 subphrase rela=atr
 -mother> subphrase
     word lex=JHWH/|>LHJM/|>L/


'''
DivineAttributesNo1  = BHS.search(DivineAttributesNo1)
BHS.table(DivineAttributesNo1, start=1, end=3, condensed=False, extraFeatures={'mother', 'distributional_parent', 'functional_parent', 'mother_object_type'},  colorMap={2: 'magenta', 3:'red', 4:'lightblue'})
# Out:
#   0.39s 136 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">subphrase</th><th class="tf">subphrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=14&amp;verse=18&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 14:18">Genesis 14:18</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">עֶלְיֹֽון׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: red;" ><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">אֵ֥ל </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">אֵ֥ל </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=14&amp;verse=19&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 14:19">Genesis 14:19</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">עֶלְיֹ֔ון </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: red;" ><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">אֵ֣ל </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">אֵ֣ל </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=14&amp;verse=20&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 14:20">Genesis 14:20</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">עֶלְיֹ֔ון </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: red;" ><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">אֵ֣ל </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">אֵ֣ל </span></span></span></td></tr></table>

# %% [markdown]
# This query finds all nominal clauses (NC) in which YHWH/Elohim/El are attributed by means of an adjectival predicate compliment (the element that functions as a predicate in nominal clauses). For example:
#
# >**God{Subj}** (is) **good {PreC})**.
#
# The TF query below recreates the following SHEBANQ/EMDROS query: http://shebanq.ancient-data.org/hebrew/query?version=2021&id=1125

# %%
DivineAttributesNo1 = '''
clause kind=NC
/without/
  word lex=DBR/|XMH/|JWM/|BJT/|JR>H/|M>RH/|M<FH/|QRBH/|PNH/|<JN/|>MRH/|DRK/
/-/
/without/
  word sp=prep
/-/
  phrase function=Subj
    word lex=JHWH/|>LHJM/|>L/
  phrase function=PreC
    word sp=adjv


'''
DivineAttributesNo1  = BHS.search(DivineAttributesNo1)
BHS.table(DivineAttributesNo1, start=1, end=3, condensed=False, extraFeatures={'mother', 'distributional_parent', 'functional_parent', 'mother_object_type'},  colorMap={2: 'magenta', 3:'red', 4:'lightblue'})
# Out:
#   0.85s 112 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=27&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 9:27">Exodus 9:27</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl"  style="background-color: red;" ><span class="txtu hbo">יְהוָה֙ </span></span></span><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">הַ</span><span class="plain rtl  hl" ><span class="txtu hbo">צַּדִּ֔יק </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl"  style="background-color: red;" ><span class="txtu hbo">יְהוָה֙ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: red;" ><span class="txtu hbo">יְהוָה֙ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">הַ</span><span class="plain rtl  hl" ><span class="txtu hbo">צַּדִּ֔יק </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">צַּדִּ֔יק </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=20&amp;verse=5&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 20:5">Exodus 20:5</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">כִּ֣י </span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אָֽנֹכִ֞י </span><span class="plain rtl  hl"  style="background-color: red;" ><span class="txtu hbo">יְהוָ֤ה </span></span><span class="txtu hbo">אֱלֹהֶ֨יךָ֙ </span></span><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֵ֣ל </span><span class="plain rtl  hl" ><span class="txtu hbo">קַנָּ֔א </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אָֽנֹכִ֞י </span><span class="plain rtl  hl"  style="background-color: red;" ><span class="txtu hbo">יְהוָ֤ה </span></span><span class="txtu hbo">אֱלֹהֶ֨יךָ֙ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: red;" ><span class="txtu hbo">יְהוָ֤ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֵ֣ל </span><span class="plain rtl  hl" ><span class="txtu hbo">קַנָּ֔א </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">קַנָּ֔א </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=20&amp;verse=5&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 20:5">Exodus 20:5</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">כִּ֣י </span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אָֽנֹכִ֞י </span><span class="txtu hbo">יְהוָ֤ה </span><span class="plain rtl  hl"  style="background-color: red;" ><span class="txtu hbo">אֱלֹהֶ֨יךָ֙ </span></span></span><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֵ֣ל </span><span class="plain rtl  hl" ><span class="txtu hbo">קַנָּ֔א </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אָֽנֹכִ֞י </span><span class="txtu hbo">יְהוָ֤ה </span><span class="plain rtl  hl"  style="background-color: red;" ><span class="txtu hbo">אֱלֹהֶ֨יךָ֙ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: red;" ><span class="txtu hbo">אֱלֹהֶ֨יךָ֙ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֵ֣ל </span><span class="plain rtl  hl" ><span class="txtu hbo">קַנָּ֔א </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">קַנָּ֔א </span></span></span></td></tr></table>

# %% [markdown]
# This query finds all attributive clauses that refer to YHWH, Elohim, or El. Thus, these attributive clauses are describing God in some further detail. For example:
#
# >This is **JHWH**, **who spoke to her{relative clause}**
#
# The TF query below recreates the following SHEBANQ/EMDROS query: http://shebanq.ancient-data.org/hebrew/query?version=2021&id=1121

# %%
DivineAttributesNo1 = '''
verse book
 clause rela=Attr
 -mother> word lex=>LHJM/|JHWH/|>L/


'''
DivineAttributesNo1  = BHS.search(DivineAttributesNo1)
BHS.table(DivineAttributesNo1, start=1, end=3, condensed=False, hiddenTypes={'half_verse', 'sentence_atom', 'phrase_atom'}, extraFeatures={'mother', 'distributional_parent', 'functional_parent', 'mother_object_type', 'rela'})
# Out:
#   0.23s 20 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">clause</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=5&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:5">Genesis 3:5</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">יֹדְעֵ֖י </span><span class="txtu hbo">טֹ֥וב </span><span class="txtu hbo">וָ</span><span class="txtu hbo">רָֽע׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">אלֹהִ֔ים </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=8&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:8">Genesis 3:8</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">מִתְהַלֵּ֥ךְ </span><span class="txtu hbo">בַּ</span><span class="txtu hbo">גָּ֖ן </span><span class="txtu hbo">לְ</span><span class="txtu hbo">ר֣וּחַ </span><span class="txtu hbo">הַ</span><span class="txtu hbo">יֹּ֑ום </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">יְהוָ֧ה </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=16&amp;verse=13&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 16:13">Genesis 16:13</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">הַ</span><span class="txtu hbo">דֹּבֵ֣ר </span><span class="txtu hbo">אֵלֶ֔יהָ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">יְהוָה֙ </span></span></span></td></tr></table>

# %% [markdown]
# ## Looking for the Antecedent/Reference of a BN/

# %%
ReferenceIdentificationNo1 = '''
book book
 clause rela=Attr
   word gn=f
 -mother> word lex=BN/ gn=m

'''
ReferenceIdentificationNo1  = BHS.search(ReferenceIdentificationNo1)
BHS.table(ReferenceIdentificationNo1, start=1, end=10, condensed=False,\
          hiddenTypes={'half_verse', 'sentence_atom', 'phrase_atom'},\
          extraFeatures={'mother', 'distributional_parent', 'functional_parent', 'mother_object_type', 'rela'},\
          colorMap={2: 'magenta', 3:'lightgreen', 4:'lightblue'})
# Out:
#   0.52s 10 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=16&amp;verse=15&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 16:15">Genesis 16:15</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁר־</span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָ֥ה </span></span><span class="txtu hbo">הָגָ֖ר </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָ֥ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">בְּנֹ֛ו </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=16&amp;verse=15&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 16:15">Genesis 16:15</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁר־</span><span class="txtu hbo">יָלְדָ֥ה </span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">הָגָ֖ר </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">הָגָ֖ר </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">בְּנֹ֛ו </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=24&amp;verse=24&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 24:24">Genesis 24:24</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁ֥ר </span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָ֖ה </span></span><span class="txtu hbo">לְ</span><span class="txtu hbo">נָחֹֽור׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָ֖ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">בֶּן־</span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">4</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=24&amp;verse=47&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 24:47">Genesis 24:47</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁ֥ר </span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָֽלְדָה־</span></span><span class="txtu hbo">לֹּ֖ו </span><span class="txtu hbo">מִלְכָּ֑ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָֽלְדָה־</span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">בֶּן־</span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">5</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=24&amp;verse=47&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 24:47">Genesis 24:47</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁ֥ר </span><span class="txtu hbo">יָֽלְדָה־</span><span class="txtu hbo">לֹּ֖ו </span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">מִלְכָּ֑ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">מִלְכָּ֑ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">בֶּן־</span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">6</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=3&amp;verse=38&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Numbers 3:38">Numbers 3:38</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Numbers</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">שֹֽׁמְרִים֙ </span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">מִשְׁמֶ֣רֶת </span></span><span class="txtu hbo">הַ</span><span class="txtu hbo">מִּקְדָּ֔שׁ </span><span class="txtu hbo">לְ</span><span class="txtu hbo">מִשְׁמֶ֖רֶת </span><span class="txtu hbo">בְּנֵ֣י </span><span class="txtu hbo">יִשְׂרָאֵ֑ל </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">מִשְׁמֶ֣רֶת </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightblue;" ><span class="txtu hbo">בָנָ֗יו </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">7</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a tar

# %%
ReferenceIdentificationNo2 = '''
book book
 clause rela=Attr
     word gn=f
 -mother> phrase 
             word lex=BN/ gn=m

'''
ReferenceIdentificationNo2  = BHS.search(ReferenceIdentificationNo2)
BHS.table(ReferenceIdentificationNo2, start=1, end=19, condensed=False,\
          hiddenTypes={'half_verse', 'sentence_atom', 'phrase_atom'},\
          extraFeatures={'mother', 'distributional_parent', 'functional_parent', 'mother_object_type', 'rela'}, \
          colorMap={2: 'magenta', 3:'lightgreen', 4:'lightblue'})
# Out:
#   0.68s 89 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=9&amp;verse=18&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 9:18">Genesis 9:18</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">הַ</span><span class="txtu hbo">יֹּֽצְאִים֙ </span><span class="txtu hbo">מִן־</span><span class="txtu hbo">הַ</span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">תֵּבָ֔ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">תֵּבָ֔ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="plain rtl  hl" ><span class="txtu hbo">בְנֵי־</span></span><span class="txtu hbo">נֹ֗חַ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בְנֵי־</span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=3&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 21:3">Genesis 21:3</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁר־</span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָה־</span></span><span class="txtu hbo">לֹּ֥ו </span><span class="txtu hbo">שָׂרָ֖ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָה־</span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֶֽת־</span><span class="txtu hbo">שֶׁם־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֧ו </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֧ו </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=3&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 21:3">Genesis 21:3</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁר־</span><span class="txtu hbo">יָלְדָה־</span><span class="txtu hbo">לֹּ֥ו </span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">שָׂרָ֖ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">שָׂרָ֖ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֶֽת־</span><span class="txtu hbo">שֶׁם־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֧ו </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֧ו </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">4</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=9&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 21:9">Genesis 21:9</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁר־</span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָ֥ה </span></span><span class="txtu hbo">לְ</span><span class="txtu hbo">אַבְרָהָ֖ם </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָ֥ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֶֽת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בֶּן־</span></span><span class="txtu hbo">הָגָ֧ר </span><span class="txtu hbo">הַ</span><span class="txtu hbo">מִּצְרִ֛ית </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בֶּן־</span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">5</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=41&amp;verse=50&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 41:50">Genesis 41:50</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁ֤ר </span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָֽלְדָה־</span></span><span class="txtu hbo">לֹּו֙ </span><span class="txtu hbo">אָֽסְנַ֔ת </span><span class="txtu hbo">בַּת־</span><span class="txtu hbo">פֹּ֥וטִי פֶ֖רַע </span><span class="txtu hbo">כֹּהֵ֥ן </span><span class="txtu hbo">אֹֽון׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָֽלְדָה־</span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">שְׁנֵ֣י </span><span class="plain rtl  hl" ><span class="txtu hbo">בָנִ֔ים </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בָנִ֔ים </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">6</td><td class="tf rtl"><span class="t

# %%
ReferenceIdentificationNo2 = '''
book book
 clause rela=Attr
     word gn=f
 -mother> phrase 
             word lex=BN/ gn=m

'''
ReferenceIdentificationNo2  = BHS.search(ReferenceIdentificationNo2)
BHS.table(ReferenceIdentificationNo2, start=1, end=19, condensed=False,\
          hiddenTypes={'half_verse', 'sentence_atom', 'phrase_atom'},\
          extraFeatures={'mother', 'distributional_parent', 'functional_parent', 'mother_object_type', 'rela'}, \
          colorMap={2: 'magenta', 3:'lightgreen', 4:'lightblue'})
# Out:
#   0.66s 89 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=9&amp;verse=18&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 9:18">Genesis 9:18</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">הַ</span><span class="txtu hbo">יֹּֽצְאִים֙ </span><span class="txtu hbo">מִן־</span><span class="txtu hbo">הַ</span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">תֵּבָ֔ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">תֵּבָ֔ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="plain rtl  hl" ><span class="txtu hbo">בְנֵי־</span></span><span class="txtu hbo">נֹ֗חַ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בְנֵי־</span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=3&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 21:3">Genesis 21:3</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁר־</span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָה־</span></span><span class="txtu hbo">לֹּ֥ו </span><span class="txtu hbo">שָׂרָ֖ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָה־</span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֶֽת־</span><span class="txtu hbo">שֶׁם־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֧ו </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֧ו </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=3&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 21:3">Genesis 21:3</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁר־</span><span class="txtu hbo">יָלְדָה־</span><span class="txtu hbo">לֹּ֥ו </span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">שָׂרָ֖ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">שָׂרָ֖ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֶֽת־</span><span class="txtu hbo">שֶׁם־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֧ו </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֧ו </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">4</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=9&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 21:9">Genesis 21:9</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁר־</span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָ֥ה </span></span><span class="txtu hbo">לְ</span><span class="txtu hbo">אַבְרָהָ֖ם </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָלְדָ֥ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">אֶֽת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בֶּן־</span></span><span class="txtu hbo">הָגָ֧ר </span><span class="txtu hbo">הַ</span><span class="txtu hbo">מִּצְרִ֛ית </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בֶּן־</span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">5</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=41&amp;verse=50&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 41:50">Genesis 41:50</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">אֲשֶׁ֤ר </span><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָֽלְדָה־</span></span><span class="txtu hbo">לֹּו֙ </span><span class="txtu hbo">אָֽסְנַ֔ת </span><span class="txtu hbo">בַּת־</span><span class="txtu hbo">פֹּ֥וטִי פֶ֖רַע </span><span class="txtu hbo">כֹּהֵ֥ן </span><span class="txtu hbo">אֹֽון׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl"  style="background-color: lightgreen;" ><span class="txtu hbo">יָֽלְדָה־</span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightblue;" ><span class="txtu hbo">שְׁנֵ֣י </span><span class="plain rtl  hl" ><span class="txtu hbo">בָנִ֔ים </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בָנִ֔ים </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">6</td><td class="tf rtl"><span class="t

# %% [markdown]
# ## References of Pronouns (including suffixes)

# %% [markdown]
# We want to find cases like: "From the fruit of the tree" being referred to by "it" in the clause:
#
#
# "*From the fruit of the tree* ... not you shall eat from **it**."

# %%
FruitNo1 = '''
verse book=Genesis chapter=3 verse=3
 phrase
 -mother> phrase


'''
FruitNo1  = BHS.search(FruitNo1)
BHS.table(FruitNo1, start=1, end=19, condensed=False,\
          hiddenTypes={'half_verse', 'sentence_atom', 'phrase_atom', 'subphrase', 'clause_atom'},\
          extraFeatures={'mother', 'distributional_parent', 'functional_parent', 'mother_object_type', 'rela'}, \
          colorMap={2: 'magenta', 3:'lightgreen', 4:'lightblue'})
# Out:
#   0.08s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase</th><th class="tf">phrase</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=3&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:3">Genesis 3:3</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">מִמֶּ֔נּוּ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightgreen;" ><span class="txtu hbo">מִ</span><span class="txtu hbo">פְּרִ֣י </span><span class="txtu hbo">הָ</span><span class="txtu hbo">עֵץ֮ </span></span></span></td></tr></table>

# %%
FruitNo1 = '''
verse book
 phrase
 -mother> phrase


'''
FruitNo1  = BHS.search(FruitNo1)
BHS.table(FruitNo1, start=1, end=19, condensed=False,\
          hiddenTypes={'half_verse', 'sentence_atom', 'phrase_atom', 'subphrase', 'clause_atom'},\
          extraFeatures={'mother', 'distributional_parent', 'functional_parent', 'mother_object_type', 'rela'}, \
          colorMap={2: 'magenta', 3:'lightgreen', 4:'lightblue'})
# Out:
#   0.33s 539 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase</th><th class="tf">phrase</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=14&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 2:14">Genesis 2:14</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">ה֥וּא </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightgreen;" ><span class="txtu hbo">הַ</span><span class="txtu hbo">נָּהָ֥ר </span><span class="txtu hbo">הָֽ</span><span class="txtu hbo">רְבִיעִ֖י </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=17&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 2:17">Genesis 2:17</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">מִמֶּ֑נּוּ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightgreen;" ><span class="txtu hbo">מֵ</span><span class="txtu hbo">עֵ֗ץ </span><span class="txtu hbo">הַ</span><span class="txtu hbo">דַּ֨עַת֙ </span><span class="txtu hbo">טֹ֣וב </span><span class="txtu hbo">וָ</span><span class="txtu hbo">רָ֔ע </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=19&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 2:19">Genesis 2:19</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">ה֥וּא </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightgreen;" ><span class="txtu hbo">כֹל֩ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">4</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=3&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:3">Genesis 3:3</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">מִמֶּ֔נּוּ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightgreen;" ><span class="txtu hbo">מִ</span><span class="txtu hbo">פְּרִ֣י </span><span class="txtu hbo">הָ</span><span class="txtu hbo">עֵץ֮ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">5</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=12&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:12">Genesis 3:12</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">הִ֛וא </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightgreen;" ><span class="txtu hbo">הָֽ</span><span class="txtu hbo">אִשָּׁה֙ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">6</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=6&amp;verse=17&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 6:17">Genesis 6:17</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">הִנְנִי֩ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightgreen;" ><span class="txtu hbo">אֲנִ֗י </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">7</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=6&amp;verse=19&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 6:19">Genesis 6:19</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">שְׁנַ֧יִם </span><span class="txtu hbo">מִ</span><span class="txtu hbo">כֹּ֛ל </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightgreen;" ><span class="txtu hbo">מִ</span><span class="txtu hbo">כָּל־</span><span class="txtu hbo">הָ֠</span><span class="txtu hbo">חַי </span><span class="txtu hbo">מִֽ</span><span class="txtu hbo">כָּל־</span><span class="txtu hbo">בָּשָׂ֞ר </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">8</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=6&amp;verse=20&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 6:20">Genesis 6:20</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">שְׁנַ֧יִם </span><span class="txtu hbo">מִ</span><span class="txtu hbo">כֹּ֛ל </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx"  style="border-color: lightgreen;" ><span class="txtu hbo">מֵ</span><span class="txtu hbo">הָ</span><span class="txtu hbo">עֹ֣וף </span><span class="txtu hbo">לְ</span><span class="txtu hbo">מִינֵ֗הוּ </span><span class="txtu hbo">וּ</span><span class="txtu hbo">מִן־</span><span class="txtu hbo">הַ</span><span class="txtu hbo">בְּהֵמָה֙ </span><span class="txtu hbo">לְ</span><span class="txtu hbo">מִינָ֔הּ </span><span class="txtu hbo">מִ</span><span class="txtu hbo">כֹּ֛ל </span><span class="txtu hbo">רֶ֥מֶשׂ </span><span class="txtu hbo">הָֽ</span><span class="txtu hbo">אֲדָמָ֖ה </span><span class="txtu hbo">לְ</span><span class="txtu hbo">מִינֵ֑הוּ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">9</t

# %% [markdown]
# # Finding Soundplays in the HB

# %% [markdown]
# ## Introduction
#
# ![Annotation%202019-12-04%20084531.png](attachment:Annotation%202019-12-04%20084531.png)
#
# In this section I will use the LCS (Longest Common Subsequence) algorithm for finding similar sounding word pairs in the ETCBC database. The problem was first brought up by [Lidvar Andvik (PhD student, Andrews University, SDATS)](https://www.linkedin.com/in/lidvar-andvik-1ba849182).
#
# He was asking whether it is possible to detect similar sounding word pairs in the TNK. As an example he used [Isa 53:11](https://ref.ly/logosres/bhssesb?ref=BibleBHS.Is53.11):
#
#
# ![Annotation%202019-12-04%20084459.png](attachment:Annotation%202019-12-04%20084459.png)
#
# As one can see the words used in predicate and object position are very similar and belong to the same lexical family. However, they are two different lexemes:
#
# ![Annotation%202019-12-04%20084938.png](attachment:Annotation%202019-12-04%20084938.png)
#
# See the syntactic structure on SHEBANQ ([bhsa4 Isaiah 53:1](https://shebanq.ancient-data.org/hebrew/text?qactive=hlcustom&qsel_one=grey&qpub=x&qget=x&wactive=hlcustom&wsel_one=gray&wpub=x&wget=x&nactive=hlcustom&nsel_one=black&npub=v&nget=x&chapter=53&lang=en&book=Jesaia&qw=m&tr=hb&tp=txt_p&iid=&verse=1&version=4&mr=m&page=1&wd4_statfl=v&ph_arela=v&wd4_statrl=v&sn_an=v&cl=v&wd1_lang=x&wd1_subpos=x&wd2_person=v&sp_rela=v&wd1_pdp=x&sn_n=v&wd3_uvf=x&ph_fun=v&wd1_nmtp=v&gl=v&sp_n=v&pt=v&ph_an=v&ph_typ=x&cl_typ=v&tt=v&wd4_statro=x&wd3_vbs=x&wd1=v&tl=x&wd3=x&wd4=v&wd2_gender=v&ph=v&wd3_vbe=v&wd1_pos=v&ph_det=v&ph_rela=x&wd4_statfo=x&tl_tlv=x&wd2_stem=v&wd2_state=v&ht=v&ph_n=v&tl_tlc=x&cl_tab=v&wd3_nme=x&hl=v&cl_par=v&cl_an=v&cl_n=v&wd3_prs=v&wd3_pfm=x&sp=v&cl_code=v&ht_hk=v&wd2=v&hl_hlc=x&cl_rela=v&wd2_gnumber=v&wd2_tense=v&cl_txt=v&wd1_n=x&sn=v&ht_ht=v&hl_hlv=v&pref=alt))
#
# In this notebook, then, I will do the following:
# 1. Use a LCS algorithm and adapt it to work with python3.
# 2. Run some simple tests.
# 3. Build a BHS based TF query and store the results as a dataframe.
# 4. Load the query results as a pandas dataframe and clean up the table.
# 5. Run the LCS algrorithm throgh each row of the dataframe.
#
# For an introduction to the LCS approach see the following links: https://en.wikipedia.org/wiki/Longest_common_subsequence_problem
# https://youtu.be/sSno9rV8Rhg
#
# For the coding of the LCS alogrithm see: https://www.geeksforgeeks.org/longest-common-subsequence-dp-4/
#
# **Recognition**: I am particularly thankful for the tips and insights received from (Rodeney Summerscales, Prof of Computer Science, Andrews University)[https://www.andrews.edu/~summersc/]. He helped me understand the LCS algorithm and hinted at the `apply` function for processing an entire data frame.
#
# ## Prelude
# We first load the different pyhton functions and the Text Fabric tool with its BHS database.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections, math, random, re
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %% [markdown]
# ## Longest Common Subsequence function as `LCS`
# ### Defining `LCS`
# Here I am following to a great extent the code found here:
#
# https://www.geeksforgeeks.org/longest-common-subsequence-dp-4/
#
# and
#
# https://www.geeksforgeeks.org/printing-longest-common-subsequence/
#
#
# Its python2 based code and needs to be fixed so that it can run within a python3 based environment (`xrange` => `range`).

# %%
# Dynamic programming implementation of LCS problem 
  
# Returns length of LCS for X[0..m-1], Y[0..n-1]  
def lcs(X, Y, m, n): 
    L = [[0 for x in range(n+1)] for x in range(m+1)] 
  
    # Following steps build L[m+1][n+1] in bottom up fashion. Note 
    # that L[i][j] contains length of LCS of X[0..i-1] and Y[0..j-1]  
    for i in range(m+1): 
        for j in range(n+1): 
            if i == 0 or j == 0: 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1] + 1
            else: 
                L[i][j] = max(L[i-1][j], L[i][j-1]) 
  
    # Following code is used to print LCS 
    index = L[m][n] 
  
    # Create a character array to store the lcs string 
    lcs = [""] * (index+1) 
    lcs[index] = "" 
  
    # Start from the right-most-bottom-most corner and 
    # one by one store characters in lcs[] 
    i = m 
    j = n 
    while i > 0 and j > 0: 
  
        # If current character in X[] and Y are same, then 
        # current character is part of LCS 
        if X[i-1] == Y[j-1]: 
            lcs[index-1] = X[i-1] 
            i-=1
            j-=1
            index-=1
  
        # If not same, then find the larger of two and 
        # go in the direction of larger value 
        elif L[i-1][j] > L[i][j-1]: 
            i-=1
        else: 
            j-=1
    # Now we want to print the results
    print("LCS of " + X + " and " + Y + " is " + "".join(lcs))

# %% [markdown]
# ### Testing LCS
# #### Simple Test with Latin characters

# %%
# Driver program 
X = "AGGTAB"
Y = "GXTXAYB"
m = len(X) 
n = len(Y) 
lcs(X, Y, m, n)
# Out:
# LCS of AGGTAB and GXTXAYB is GTAB

# %% [markdown]
# ### Simple Test with Hebrew characters form Isa 53:11
# ![image.png](attachment:image.png)

# %%
X = "יַצְדִּ֥יק"
Y = "צַדִּ֛יק"
m = len(X) 
n = len(Y) 
lcs(X, Y, m, n)
# Out:
# LCS of יַצְדִּ֥יק and צַדִּ֛יק is צדִּיק

# %%
X = "JAY:D.I71JQ"
Y = "YAD.I91JQ"
m = len(X) 
n = len(Y) 
lcs(X, Y, m, n)
# Out:
# LCS of JAY:D.I71JQ and YAD.I91JQ is YD.I1JQ

# %% [markdown]
# There are two alternatives of applying the function:

# %%
# Option#1
X = "testing"
Y = "rest"
m = len(X) 
n = len(Y) 
lcs(X, Y, m, n)
# Out:
# LCS of testing and rest is est

# %%
# Option#2
lcs("testing", "rest", len("testing"), len("rest"))
# Out:
# LCS of testing and rest is est

# %% [markdown]
# #### Experimenting with Lists...

# %%
preds = ["bites", "drinks"]
objcs = ["Brits", "drunk"]
X = preds[0]
Y = objcs[0]
m = len(X) 
n = len(Y) 
lcs(X, Y, m, n)
# Out:
# LCS of bites and Brits is its

# %% [markdown]
# ## Producing a dataframe for our `LCS` function
# ### Building and Running a TF query
# For the purpose of testing our workflow we will create just a very limited dataframe by searching only predicates with the lexeme YDQ[ and the attached object phrase. We also make sure that there is only one word appearing in each Predicate and Object phrase by using `::`.

# %%
PredObjcWordLists = '''
book
 clause
    phrase function=Pred
        :: word lex=YDQ[
    phrase function=Objc
        :: word lex   
'''
PredObjcWordLists  = BHS.search(PredObjcWordLists)
BHS.table(PredObjcWordLists, start=1, end=5, condensed=False)
# Out:
#   0.67s 6 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=23&amp;verse=7&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 23:7">Exodus 23:7</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Exodus</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">כִּ֥י </span><span class="txtu hbo">לֹא־</span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אַצְדִּ֖יק </span></span></span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">רָשָֽׁע׃ </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אַצְדִּ֖יק </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">אַצְדִּ֖יק </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">רָשָֽׁע׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">רָשָֽׁע׃ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=53&amp;verse=11&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Isaiah 53:11">Isaiah 53:11</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Isaiah</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">בְּ</span><span class="txtu hbo">דַעְתֹּ֗ו </span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">יַצְדִּ֥יק </span></span></span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">צַדִּ֛יק </span></span></span><span class="txtu hbo">עַבְדִּ֖י </span><span class="txtu hbo">לָֽ</span><span class="txtu hbo">רַבִּ֑ים </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">יַצְדִּ֥יק </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">יַצְדִּ֥יק </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">צַדִּ֛יק </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">צַדִּ֛יק </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=3&amp;verse=11&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Jeremiah 3:11">Jeremiah 3:11</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Jeremiah</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">צִדְּקָ֥ה </span></span></span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">נַפְשָׁ֖הּ </span></span></span><span class="txtu hbo">מְשֻׁבָ֣ה </span><span class="txtu hbo">יִשְׂרָאֵ֑ל </span><span class="txtu hbo">מִ</span><span class="txtu hbo">בֹּגֵדָ֖ה </span><span class="txtu hbo">יְהוּדָֽה׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">צִדְּקָ֥ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">צִדְּקָ֥ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">נַפְשָׁ֖הּ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">נַפְשָׁ֖הּ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">4</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Iob&amp;chapter=9&amp;verse=2&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Job 9:2">Job 9:2</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Job</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">וּ</span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">מַה־</span></span></span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">יִּצְדַּ֖ק </span></span></span><span class="txtu hbo">אֱנֹ֣ושׁ </span><span class="txtu hbo">עִם־</span><span class="txtu hbo">אֵֽל׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">יִּצְדַּ֖ק </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">יִּצְדַּ֖ק </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">מַה־</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">מַה־</span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">5</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Iob&amp;chapter=27&amp;verse=5&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Job 27:5">Job 27:5</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Job</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">אִם־</span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אַצְדִּ֢יק </span></span></span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אֶ֫תְכֶ֥ם </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אַצְדִּ֢יק </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl

# %% [markdown]
# ### Exporting the TF query results and loading them as a pandas dataframe

# %%
BHS.export(PredObjcWordLists, toDir='~/Desktop/course_TF-Workshop/data_export/', toFile='PredObjcWordLists.tsv')

# %%
PredObjcWordLists=pd.read_csv('~/Desktop/course_TF-Workshop/data_export/PredObjcWordLists.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
PredObjcWordLists.head()
# Out:
#    R        S1  S2  S3   NODE1 TYPE1   NODE2   TYPE2  \
# 0  1    Exodus  23   7  426592  book  436037  clause
# 1  2    Isaiah  53  11  426602  book  472766  clause
# 2  3  Jeremiah   3  11  426603  book  474156  clause
# 3  4       Job   9   2  426618  book  498095  clause
# 4  5       Job  27   5  426618  book  499264  clause
#
#                                                TEXT2   NODE3   TYPE3  \
# 0                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃   677137  phrase
# 1  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...  786392  phrase
# 2  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...  790186  phrase
# 3               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃   854748  phrase
# 4                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם   858011  phrase
#
#          TEXT3 function3   NODE4 TYPE4        TEXT4  lex4   NODE5   TYPE5  \
# 0  אַצְדִּ֖יק       Pred   41142  word  אַצְדִּ֖יק   YDQ[  677138  phrase
# 1  יַצְדִּ֥יק       Pred  230739  word  יַצְדִּ֥יק   YDQ[  786393  phrase
# 2   צִדְּקָ֥ה       Pred  236233  word   צִדְּקָ֥ה   YDQ[  790187  phrase
# 3  יִּצְדַּ֖ק       Pred  338288  word  יִּצְדַּ֖ק   YDQ[  854747  phrase
# 4  אַצְדִּ֢יק       Pred  342412  word  אַצְדִּ֢יק   YDQ[  858012  phrase
#
#          TEXT5 function5   NODE6 TYPE6        TEXT6   lex6
# 0    רָשָֽׁע׃       Objc   41143  word    רָשָֽׁע׃    RC</
# 1    צַדִּ֛יק       Objc  230740  word    צַדִּ֛יק   YDJQ/
# 2  נַפְשָׁ֖הּ       Objc  236234  word  נַפְשָׁ֖הּ    NPC/
# 3         מַה־      Objc  338287  word         מַה־     MH
# 4   אֶ֫תְכֶ֥ם       Objc  342413  word   אֶ֫תְכֶ֥ם      >T

# %% [markdown]
# ### Cleaning up the dataframe
# #### Lets first drop some irrelelvant columns

# %%
PredObjcWordLists=PredObjcWordLists.drop(columns=["NODE1", "NODE1", "NODE2", "NODE3", "NODE4", "NODE5", "NODE6", "TYPE1", "TYPE2", "TYPE3", "lex4", "lex6"])
PredObjcWordLists
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
#
#   TYPE6        TEXT6
# 0  word    רָשָֽׁע׃
# 1  word    צַדִּ֛יק
# 2  word  נַפְשָׁ֖הּ
# 3  word         מַה־
# 4  word   אֶ֫תְכֶ֥ם
# 5  word       זֹ֣את

# %% [markdown]
# #### Lets now rename some column names

# %%
PredObjcWordLists.rename(columns={"S1": "book", "S2": "chapter", "S3": "verse", "TEXT2": "clause", "TEXT3": "Pred-Phrase", "TEXT5": "Objc-Phrase"})
# Out:
#    R      book  chapter  verse  \
# 0  1    Exodus       23      7
# 1  2    Isaiah       53     11
# 2  3  Jeremiah        3     11
# 3  4       Job        9      2
# 4  5       Job       27      5
# 5  6       Job       33     12
#
#                                               clause  Pred-Phrase function3  \
# 0                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃   אַצְדִּ֖יק       Pred
# 1  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...  יַצְדִּ֥יק       Pred
# 2  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...   צִדְּקָ֥ה       Pred
# 3               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃   יִּצְדַּ֖ק       Pred
# 4                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם   אַצְדִּ֢יק       Pred
# 5                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ   צָדַ֣קְתָּ       Pred
#
#   TYPE4        TEXT4   TYPE5  Objc-Phrase function5 TYPE6        TEXT6
# 0  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc  word    רָשָֽׁע׃
# 1  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc  word    צַדִּ֛יק
# 2  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc  word  נַפְשָׁ֖הּ
# 3  word  יִּצְדַּ֖ק   phrase         מַה־      Objc  word         מַה־
# 4  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc  word   אֶ֫תְכֶ֥ם
# 5  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc  word       זֹ֣את

# %% [markdown]
# ## Applying the simple `lcs` function to each row `axis=1` with `apply` and `lambda row`

# %% [markdown]
# In the code below I seek to add to the dataframe an additional colum
# ```python
# PredObjcWordLists['lcsresults']
# ```
#
# that contains the results of the applied `lcs` function. The `lcs` function contains 4 arguments as seen below:
#
# ![image.png](attachment:image.png)
#
# I will use option#2 and define the arguments **X, Y, m, n** as follows with the `lamda row` function
# ```python
# (lambda row : lcs(row['TEXT4'], row['TEXT6'], len(row['TEXT4']), len(row['TEXT6'])), axis = 1)
# ```
#
# Since I want to have the `lcs` function travel through each row. In order to accomplish this, I am using the `apply` function and have it travel the `lcs` function through each row (i.e. along `axis=1`):
# ```python
# PredObjcWordLists.apply(lambda row : lcs(row['TEXT4'], row['TEXT6'], len(row['TEXT4']), len(row['TEXT6'])), axis = 1)
# ```

# %%
PredObjcWordLists['lcsresults']=PredObjcWordLists.apply(lambda row : lcs(row['TEXT4'], row['TEXT6'], len(row['TEXT4']), len(row['TEXT6'])), axis = 1)
# Out:
# LCS of אַצְדִּ֖יק  and רָשָֽׁע׃  is
# LCS of יַצְדִּ֥יק  and צַדִּ֛יק  is צדִּיק
# LCS of צִדְּקָ֥ה  and נַפְשָׁ֖הּ  is ְָה
# LCS of יִּצְדַּ֖ק  and מַה־ is ַ
# LCS of אַצְדִּ֢יק  and אֶ֫תְכֶ֥ם  is אְ
# LCS of צָדַ֣קְתָּ  and זֹ֣את  is ֣ת

# %%
PredObjcWordLists.head(2)
# Out:
#    R      S1  S2  S3                                              TEXT2  \
# 0  1  Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2  Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5      TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase  רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase  צַדִּ֛יק       Objc
#
#   TYPE6      TEXT6 lcsresults
# 0  word  רָשָֽׁע׃        None
# 1  word  צַדִּ֛יק        None

# %% [markdown]
# ### Adjusting the `lcs` function into a `lcsreturn` function
# As can be seen, the `lcsresults` column is filed with **None**. This has to do with the fact that the results of the lcs print function cannot be stored in the colum. We therefore need to change the final command of the lcs function by replacing the `print` command with the `result` command. I will rename the changed function `lcsreturn`.

# %%
# Dynamic programming implementation of LCS problem 
  
# Returns length of LCS for X[0..m-1], Y[0..n-1]  
def lcsreturn(X, Y, m, n): 
    L = [[0 for x in range(n+1)] for x in range(m+1)] 
  
    # Following steps build L[m+1][n+1] in bottom up fashion. Note 
    # that L[i][j] contains length of LCS of X[0..i-1] and Y[0..j-1]  
    for i in range(m+1): 
        for j in range(n+1): 
            if i == 0 or j == 0: 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1] + 1
            else: 
                L[i][j] = max(L[i-1][j], L[i][j-1]) 
  
    # Following code is used to print LCS 
    index = L[m][n] 
  
    # Create a character array to store the lcs string 
    lcs = [""] * (index+1) 
    lcs[index] = "" 
  
    # Start from the right-most-bottom-most corner and 
    # one by one store characters in lcs[] 
    i = m 
    j = n 
    while i > 0 and j > 0: 
  
        # If current character in X[] and Y are same, then 
        # current character is part of LCS 
        if X[i-1] == Y[j-1]: 
            lcs[index-1] = X[i-1] 
            i-=1
            j-=1
            index-=1
  
        # If not same, then find the larger of two and 
        # go in the direction of larger value 
        elif L[i-1][j] > L[i][j-1]: 
            i-=1
        else: 
            j-=1

    # Return allows me to store it in the df as a column entry
    return(""  + "".join(lcs))

# %% [markdown]
# Lets now run the lcs algorithm again with the updated `lcsreturn` function:

# %%
PredObjcWordLists['lcsresults']=PredObjcWordLists.apply(lambda row : lcsreturn(row['TEXT4'], row['TEXT6'], len(row['TEXT4']), len(row['TEXT6'])), axis = 1)

# %%
PredObjcWordLists.head(6)
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
#
#   TYPE6        TEXT6 lcsresults
# 0  word    רָשָֽׁע׃
# 1  word    צַדִּ֛יק     צדִּיק
# 2  word  נַפְשָׁ֖הּ        ְָה
# 3  word         מַה־          ַ
# 4  word   אֶ֫תְכֶ֥ם         אְ
# 5  word       זֹ֣את         ֣ת

# %% [markdown]
# ## Adding statistical information
# When having a large dataset we would like to filter out those LCS results that embody a high matching value between the first word (in our case the Object) and the second word (in our case the Predicate). In order to allow for such filtering we need additional information added in additional columns. Lets first add information about the string length of each `X` and `Y` word.

# %%
# Adding character length information about the Object-word
PredObjcWordLists['Objclength']=PredObjcWordLists.apply(lambda row : len(row['TEXT4']), axis = 1)

# %%
PredObjcWordLists.head(6)
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
#
#   TYPE6        TEXT6 lcsresults  Objclength
# 0  word    רָשָֽׁע׃                      11
# 1  word    צַדִּ֛יק     צדִּיק           11
# 2  word  נַפְשָׁ֖הּ        ְָה           10
# 3  word         מַה־          ַ          11
# 4  word   אֶ֫תְכֶ֥ם         אְ           11
# 5  word       זֹ֣את         ֣ת           11

# %%
# Adding character lenght information about the Predicate-word
PredObjcWordLists['Predlength']=PredObjcWordLists.apply(lambda row : len(row['TEXT6']), axis = 1)

# %%
PredObjcWordLists.head(6)
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
#
#   TYPE6        TEXT6 lcsresults  Objclength  Predlength
# 0  word    רָשָֽׁע׃                      11           9
# 1  word    צַדִּ֛יק     צדִּיק           11           9
# 2  word  נַפְשָׁ֖הּ        ְָה           10          11
# 3  word         מַה־          ַ          11           4
# 4  word   אֶ֫תְכֶ֥ם         אְ           11          10
# 5  word       זֹ֣את         ֣ת           11           6

# %%
# Adding character lenght information about the LCS-result
PredObjcWordLists['LCSlength']=PredObjcWordLists.apply(lambda row : len(row['lcsresults']), axis = 1)
PredObjcWordLists.head(6)
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
#
#   TYPE6        TEXT6 lcsresults  Objclength  Predlength  LCSlength
# 0  word    רָשָֽׁע׃                      11           9          1
# 1  word    צַדִּ֛יק     צדִּיק           11           9          7
# 2  word  נַפְשָׁ֖הּ        ְָה           10          11          4
# 3  word         מַה־          ַ          11           4          1
# 4  word   אֶ֫תְכֶ֥ם         אְ           11          10          3
# 5  word       זֹ֣את         ֣ת           11           6          3

# %% [markdown]
# ### Calculating Matching %s
# For our research we are interested in displaying:
# 1. the matching ratio between object-word-lenght and LCS-length
# ```python
# #applied to row#2
# 10/100*4
# =40%
# ```
#
# 2. the matching ratio between predicate-word-lenght and the LCS-length
# ```python
# #applied to row#2
# 11/100*4
# =44%
# ```
#
# 3. the mean ratio of object+predicate-word-lenght andthe LCS-lenght
# ```python
# #applied to row#2
# (10+11)/2/100*4
# =42%
# ```

# %% [markdown]
# #### Writing a simple `percentage` function
# Lets define a percentage function that we can run through the data frame.

# %%
 def percentage(v1, v2):
      pctg = float(v1/100 * v2)
      return(pctg)

# %%
v1=10
v2=4
percentage(v1,v2)
# Out:
# 0.4

# %% [markdown]
# ##### Caluclating Percentage Ratio Objectlength to LCS lenght
# The higher the percentage the more of the Objectword appears in the Predicateword

# %%
PredObjcWordLists['LCSmatchObjc']=PredObjcWordLists.apply(lambda row : percentage(row['Objclength'], row['LCSlength']), axis = 1)
PredObjcWordLists.head(6)
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
#
#   TYPE6        TEXT6 lcsresults  Objclength  Predlength  LCSlength  \
# 0  word    רָשָֽׁע׃                      11           9          1
# 1  word    צַדִּ֛יק     צדִּיק           11           9          7
# 2  word  נַפְשָׁ֖הּ        ְָה           10          11          4
# 3  word         מַה־          ַ          11           4          1
# 4  word   אֶ֫תְכֶ֥ם         אְ           11          10          3
# 5  word       זֹ֣את         ֣ת           11           6          3
#
#    LCSmatchObjc
# 0          0.11
# 1          0.77
# 2          0.40
# 3          0.11
# 4          0.33
# 5          0.33

# %% [markdown]
# ##### Caluclating Percentage Ratio Predicatelength to LCS lenght
# The higher the percentage the more of the Predicateword matches with the LCS letters

# %%
PredObjcWordLists['LCSmatchPred']=PredObjcWordLists.apply(lambda row : percentage(row['Predlength'], row['LCSlength']), axis = 1)
PredObjcWordLists.head(6)
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
#
#   TYPE6        TEXT6 lcsresults  Objclength  Predlength  LCSlength  \
# 0  word    רָשָֽׁע׃                      11           9          1
# 1  word    צַדִּ֛יק     צדִּיק           11           9          7
# 2  word  נַפְשָׁ֖הּ        ְָה           10          11          4
# 3  word         מַה־          ַ          11           4          1
# 4  word   אֶ֫תְכֶ֥ם         אְ           11          10          3
# 5  word       זֹ֣את         ֣ת           11           6          3
#
#    LCSmatchObjc  LCSmatchPred
# 0          0.11          0.09
# 1          0.77          0.63
# 2          0.40          0.44
# 3          0.11          0.04
# 4          0.33          0.30
# 5          0.33          0.18

# %% [markdown]
# #### Writing a simple `meanpercentage` function
# Lets define a percentage function that we can run through the data frame and calculates the LCS mean of X+Y matching.
# ```python
# x=(v1+v2)/2 => this would calculate of v1 (lets say "9") and v2 (lets say "5") the mean ((9+5)/2=7)
# LCSpercentage=100/x*lcsresult
# ```

# %%
 def meanpercentage(v1, v2, v3):
      mean = float((v1+v2)/2)
      meanpctg = float(100/mean * v3)
      return(meanpctg)

# %%
v1=5
v2=4
v3=4
meanpercentage(v1,v2,v3)
# Out:
# 88.88888888888889

# %% [markdown]
# ##### Caluclating Percentage Ratio Predicatelength to LCS lenght
# The higher the percentage the more of the Predicateword matches with the LCS letters

# %%
PredObjcWordLists['LCSObjcPredMeanMatch']=PredObjcWordLists.apply(lambda row : meanpercentage(row['Objclength'], row['Predlength'], row['LCSlength']), axis = 1)
PredObjcWordLists.head(6)
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
#
#   TYPE6        TEXT6 lcsresults  Objclength  Predlength  LCSlength  \
# 0  word    רָשָֽׁע׃                      11           9          1
# 1  word    צַדִּ֛יק     צדִּיק           11           9          7
# 2  word  נַפְשָׁ֖הּ        ְָה           10          11          4
# 3  word         מַה־          ַ          11           4          1
# 4  word   אֶ֫תְכֶ֥ם         אְ           11          10          3
# 5  word       זֹ֣את         ֣ת           11           6          3
#
#    LCSmatchObjc  LCSmatchPred  LCSObjcPredMeanMatch
# 0          0.11          0.09             10.000000
# 1          0.77          0.63             70.000000
# 2          0.40          0.44             38.095238
# 3          0.11          0.04             13.333333
# 4          0.33          0.30             28.571429
# 5          0.33          0.18             35.294118

# %% [markdown]
# ## Sorting best matches

# %%
PredObjcWordLists.sort_values(['LCSObjcPredMeanMatch'], ascending=[False])
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
#
#   TYPE6        TEXT6 lcsresults  Objclength  Predlength  LCSlength  \
# 1  word    צַדִּ֛יק     צדִּיק           11           9          7
# 2  word  נַפְשָׁ֖הּ        ְָה           10          11          4
# 5  word       זֹ֣את         ֣ת           11           6          3
# 4  word   אֶ֫תְכֶ֥ם         אְ           11          10          3
# 3  word         מַה־          ַ          11           4          1
# 0  word    רָשָֽׁע׃                      11           9          1
#
#    LCSmatchObjc  LCSmatchPred  LCSObjcPredMeanMatch
# 1          0.77          0.63             70.000000
# 2          0.40          0.44             38.095238
# 5          0.33          0.18             35.294118
# 4          0.33          0.30             28.571429
# 3          0.11          0.04             13.333333
# 0          0.11          0.09             10.000000

# %% [markdown]
# Lets find all values that have a matching mean percentage of at least 40%.

# %%
PredObjcWordLists.where(PredObjcWordLists['LCSObjcPredMeanMatch'] > 0.4)
# Out:
#    R        S1  S2  S3                                              TEXT2  \
# 0  1    Exodus  23   7                     כִּ֥י לֹא־אַצְדִּ֖יק רָשָֽׁע׃
# 1  2    Isaiah  53  11  בְּדַעְתֹּ֗ו יַצְדִּ֥יק צַדִּ֛יק עַבְדִּ֖י לָֽ...
# 2  3  Jeremiah   3  11  צִדְּקָ֥ה נַפְשָׁ֖הּ מְשֻׁבָ֣ה יִשְׂרָאֵ֑ל מִב...
# 3  4       Job   9   2               וּמַה־יִּצְדַּ֖ק אֱנֹ֣ושׁ עִם־אֵֽל׃
# 4  5       Job  27   5                          אִם־אַצְדִּ֢יק אֶ֫תְכֶ֥ם
# 5  6       Job  33  12                          הֶן־זֹ֣את לֹא־צָדַ֣קְתָּ
#
#          TEXT3 function3 TYPE4        TEXT4   TYPE5        TEXT5 function5  \
# 0  אַצְדִּ֖יק       Pred  word  אַצְדִּ֖יק   phrase    רָשָֽׁע׃       Objc
# 1  יַצְדִּ֥יק       Pred  word  יַצְדִּ֥יק   phrase    צַדִּ֛יק       Objc
# 2   צִדְּקָ֥ה       Pred  word   צִדְּקָ֥ה   phrase  נַפְשָׁ֖הּ       Objc
# 3  יִּצְדַּ֖ק       Pred  word  יִּצְדַּ֖ק   phrase         מַה־      Objc
# 4  אַצְדִּ֢יק       Pred  word  אַצְדִּ֢יק   phrase   אֶ֫תְכֶ֥ם       Objc
# 5  צָדַ֣קְתָּ       Pred  word  צָדַ֣קְתָּ   phrase       זֹ֣את       Objc
#
#   TYPE6        TEXT6 lcsresults  Objclength  Predlength  LCSlength  \
# 0  word    רָשָֽׁע׃                      11           9          1
# 1  word    צַדִּ֛יק     צדִּיק           11           9          7
# 2  word  נַפְשָׁ֖הּ        ְָה           10          11          4
# 3  word         מַה־          ַ          11           4          1
# 4  word   אֶ֫תְכֶ֥ם         אְ           11          10          3
# 5  word       זֹ֣את         ֣ת           11           6          3
#
#    LCSmatchObjc  LCSmatchPred  LCSObjcPredMeanMatch
# 0          0.11          0.09             10.000000
# 1          0.77          0.63             70.000000
# 2          0.40          0.44             38.095238
# 3          0.11          0.04             13.333333
# 4          0.33          0.30             28.571429
# 5          0.33          0.18             35.294118

# %% [markdown]
# ## Processing large dataset
# We will first run a query on Isiah and Psalms that outputs the consonantal text of Predicate and Object only by using `g_cons_utf8` as a word feature.

# %%
PredObjWordListsXL = '''
book book=Psalmi|Jesaia|Genesis|Jeremia|Proverbia|Canticum|Ecclesiastes|Reges_I|Deuteronomium
  clause
    phrase function=Pred
        word g_cons_utf8
    phrase function=Objc
        word g_cons_utf8
'''
PredObjWordListsXL = BHS.search(PredObjWordListsXL)
BHS.table(PredObjWordListsXL, start=1, end=5, condensed=False)
# Out:
#   0.88s 18738 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">בְּ</span><span class="txtu hbo">רֵאשִׁ֖ית </span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span><span class="txtu hbo">אֱלֹהִ֑ים </span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אֵ֥ת </span></span><span class="txtu hbo">הַ</span><span class="txtu hbo">שָּׁמַ֖יִם </span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הָ</span><span class="txtu hbo">אָֽרֶץ׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אֵ֥ת </span></span><span class="txtu hbo">הַ</span><span class="txtu hbo">שָּׁמַ֖יִם </span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הָ</span><span class="txtu hbo">אָֽרֶץ׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">אֵ֥ת </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">בְּ</span><span class="txtu hbo">רֵאשִׁ֖ית </span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span><span class="txtu hbo">אֱלֹהִ֑ים </span><span class="plain rtl  hlbx" ><span class="txtu hbo">אֵ֥ת </span><span class="plain rtl  hl" ><span class="txtu hbo">הַ</span></span><span class="txtu hbo">שָּׁמַ֖יִם </span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הָ</span><span class="txtu hbo">אָֽרֶץ׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֵ֥ת </span><span class="plain rtl  hl" ><span class="txtu hbo">הַ</span></span><span class="txtu hbo">שָּׁמַ֖יִם </span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הָ</span><span class="txtu hbo">אָֽרֶץ׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">הַ</span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">בְּ</span><span class="txtu hbo">רֵאשִׁ֖ית </span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span><span class="txtu hbo">אֱלֹהִ֑ים </span><span class="plain rtl  hlbx" ><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הַ</span><span class="plain rtl  hl" ><span class="txtu hbo">שָּׁמַ֖יִם </span></span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הָ</span><span class="txtu hbo">אָֽרֶץ׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הַ</span><span class="plain rtl  hl" ><span class="txtu hbo">שָּׁמַ֖יִם </span></span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הָ</span><span class="txtu hbo">אָֽרֶץ׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">שָּׁמַ֖יִם </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">4</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">בְּ</span><span class="txtu hbo">רֵאשִׁ֖ית </span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span><span class="txtu hbo">אֱלֹהִ֑ים </span><span class="plain rtl  hlbx" ><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הַ</span><span class="txtu hbo">שָּׁמַ֖יִם </span><span class="plain rtl  hl" ><span class="txtu hbo">וְ</span></span><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הָ</span><span class="txtu hbo">אָֽרֶץ׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">בָּרָ֣א </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֵ֥ת </span><span class="txtu hbo">הַ</span><span class="txtu hbo">שָּׁמַ֖יִם </span

# %%
BHS.export(PredObjWordListsXL, toDir='~/Desktop/course_TF-Workshop/data_export/', toFile='PredObjWordListsXL.tsv')

# %%
PredObjWordListsXL=pd.read_csv('~/Desktop/course_TF-Workshop/data_export/PredObjWordListsXL.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
PredObjWordListsXL.head()
# Out:
#    R       S1  S2  S3   NODE1 TYPE1    book1   NODE2   TYPE2  \
# 0  1  Genesis   1   1  426591  book  Genesis  427559  clause
# 1  2  Genesis   1   1  426591  book  Genesis  427559  clause
# 2  3  Genesis   1   1  426591  book  Genesis  427559  clause
# 3  4  Genesis   1   1  426591  book  Genesis  427559  clause
# 4  5  Genesis   1   1  426591  book  Genesis  427559  clause
#
#                                                TEXT2   NODE3   TYPE3  \
# 0  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...  651574  phrase
# 1  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...  651574  phrase
# 2  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...  651574  phrase
# 3  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...  651574  phrase
# 4  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...  651574  phrase
#
#       TEXT3 function3  NODE4 TYPE4     TEXT4 g_cons_utf84   NODE5   TYPE5  \
# 0  בָּרָ֣א       Pred      3  word  בָּרָ֣א           ברא  651576  phrase
# 1  בָּרָ֣א       Pred      3  word  בָּרָ֣א           ברא  651576  phrase
# 2  בָּרָ֣א       Pred      3  word  בָּרָ֣א           ברא  651576  phrase
# 3  בָּרָ֣א       Pred      3  word  בָּרָ֣א           ברא  651576  phrase
# 4  בָּרָ֣א       Pred      3  word  בָּרָ֣א           ברא  651576  phrase
#
#                                  TEXT5 function5  NODE6 TYPE6        TEXT6  \
# 0  אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃       Objc      5  word        אֵ֥ת
# 1  אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃       Objc      6  word           הַ
# 2  אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃       Objc      7  word  שָּׁמַ֖יִם
# 3  אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃       Objc      8  word           וְ
# 4  אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃       Objc      9  word        אֵ֥ת
#
#   g_cons_utf86
# 0           את
# 1            ה
# 2        שׁמים
# 3            ו
# 4           את

# %%
PredObjWordListsXL=PredObjWordListsXL.drop(columns=["NODE1", "NODE1", "NODE2", "NODE3", "NODE4", "NODE5", "TEXT2", "TEXT3", "TEXT4", "TEXT5", "TYPE1", "TYPE2", "TYPE3"])

# %%
PredObjWordListsXL.head()
# Out:
#    R       S1  S2  S3    book1 function3 TYPE4 g_cons_utf84   TYPE5 function5  \
# 0  1  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 1  2  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 2  3  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 3  4  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 4  5  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
#
#    NODE6 TYPE6        TEXT6 g_cons_utf86
# 0      5  word        אֵ֥ת            את
# 1      6  word           הַ            ה
# 2      7  word  שָּׁמַ֖יִם         שׁמים
# 3      8  word           וְ            ו
# 4      9  word        אֵ֥ת            את

# %% [markdown]
# The LCS function can only compare word pairs. When a word in the word pair is missing it will execute an error message and wont output any results. Lets therefore first identify potential unusable rows by searching for **NaN** values.

# %%
PredObjWordListsXL[PredObjWordListsXL.isnull().any(axis=1)]
# Out:
#            R            S1  S2  S3          book1 function3 TYPE4  \
# 73        74       Genesis   1  22        Genesis      Pred  word
# 1552    1553       Genesis  24  31        Genesis      Pred  word
# 1764    1765       Genesis  26  18        Genesis      Pred  word
# 2168    2169       Genesis  30  32        Genesis      Pred  word
# 2175    2176       Genesis  30  32        Genesis      Pred  word
# 2200    2201       Genesis  30  35        Genesis      Pred  word
# 3147    3148       Genesis  42  25        Genesis      Pred  word
# 3151    3152       Genesis  42  25        Genesis      Pred  word
# 3421    3422       Genesis  45  21        Genesis      Pred  word
# 5271    5272   Deuteronomy  14  28  Deuteronomium      Pred  word
# 7248    7249       1_Kings   5   8        Reges_I      Pred  word
# 7252    7253       1_Kings   5   8        Reges_I      Pred  word
# 7536    7537       1_Kings   7  14        Reges_I      Pred  word
# 7541    7542       1_Kings   7  14        Reges_I      Pred  word
# 8210    8211       1_Kings  10  12        Reges_I      Pred  word
# 8720    8721       1_Kings  15  18        Reges_I      Pred  word
# 9196    9197       1_Kings  20  25        Reges_I      Pred  word
# 10151  10152        Isaiah  24  16         Jesaia      Pred  word
# 11615  11616      Jeremiah   2  23        Jeremia      Pred  word
# 12321  12322      Jeremiah  15   8        Jeremia      Pred  word
# 12407  12408      Jeremiah  17   6        Jeremia      Pred  word
# 12528  12529      Jeremiah  19   5        Jeremia      Pred  word
# 12534  12535      Jeremiah  19   5        Jeremia      Pred  word
# 18605  18606  Ecclesiastes   8  13   Ecclesiastes      Pred  word
#
#       g_cons_utf84   TYPE5 function5   NODE6 TYPE6 TEXT6 g_cons_utf86
# 73            מלאו  phrase      Objc     429  word   NaN          NaN
# 1552         פניתי  phrase      Objc   11731  word   NaN          NaN
# 1764          יקרא  phrase      Objc   13330  word   NaN          NaN
# 2168           הסר  phrase      Objc   16112  word   NaN          NaN
# 2175           הסר  phrase      Objc   16119  word   NaN          NaN
# 2200           יסר  phrase      Objc   16195  word   NaN          NaN
# 3147             ל  phrase      Objc   23869  word   NaN          NaN
# 3151            תת  phrase      Objc   23869  word   NaN          NaN
# 3421           יתן  phrase      Objc   25859  word   NaN          NaN
# 5271         תוציא  phrase      Objc  101947  word   NaN          NaN
# 7248          יבאו  phrase      Objc  179505  word   NaN          NaN
# 7252          יבאו  phrase      Objc  179509  word   NaN          NaN
# 7536             ל  phrase      Objc  181134  word   NaN          NaN
# 7541         עשׂות  phrase      Objc  181134  word   NaN          NaN
# 8210          יעשׂ  phrase      Objc  184614  word   NaN          NaN
# 8720           יקח  phrase      Objc  188673  word    הַ          NaN
# 9196          תמנה  phrase      Objc  192480  word   NaN          NaN
# 10151       שׁמענו  phrase      Objc  219910  word   NaN          NaN
# 11615          ראי  phrase      Objc  235766  word   NaN          NaN
# 12321        הבאתי  phrase      Objc  242353  word   NaN          NaN
# 12407         שׁכן  phrase      Objc  243228  word   NaN          NaN
# 12528            ל  phrase      Objc  244244  word   NaN          NaN
# 12534         שׂרף  phrase      Objc  244244  word   NaN          NaN
# 18605        יאריך  phrase      Objc  362146  word   NaN          NaN

# %% [markdown]
# The above rows need to be deleted. We can do so by either taking that one row out with
# ```python
# PredObjWordListsXL.drop(['73', '1548', etc...])
# ```
# or by using the `dropna()` function. We will do the latter to remove al `NaN` values:

# %%
PredObjWordListsXL = PredObjWordListsXL.dropna()

# %% [markdown]
# Now we are ready to run the `lcsresults` function.

# %%
PredObjWordListsXL['lcsresults']=PredObjWordListsXL.apply(lambda row : lcsreturn(row['g_cons_utf84'], row['g_cons_utf86'], len(row['g_cons_utf84']), len(row['g_cons_utf86'])), axis = 1)

# %%
PredObjWordListsXL.head()
# Out:
#    R       S1  S2  S3    book1 function3 TYPE4 g_cons_utf84   TYPE5 function5  \
# 0  1  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 1  2  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 2  3  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 3  4  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 4  5  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
#
#    NODE6 TYPE6        TEXT6 g_cons_utf86 lcsresults
# 0      5  word        אֵ֥ת            את          א
# 1      6  word           הַ            ה
# 2      7  word  שָּׁמַ֖יִם         שׁמים
# 3      8  word           וְ            ו
# 4      9  word        אֵ֥ת            את          א

# %% [markdown]
# Lets find our case in Isa 53:11

# %%
PredObjWordListsXL[
          (PredObjWordListsXL['S1'] == 'Isaiah')
        & (PredObjWordListsXL['S2'] == 53)
        & (PredObjWordListsXL["S3"] == 11)
       ].sort_values(['S2', 'S3'], ascending=[False,True]).head()
# Out:
#            R      S1  S2  S3   book1 function3 TYPE4 g_cons_utf84   TYPE5  \
# 11126  11127  Isaiah  53  11  Jesaia      Pred  word        יצדיק  phrase
# 11127  11128  Isaiah  53  11  Jesaia      Pred  word         יסבל  phrase
#
#       function5   NODE6 TYPE6        TEXT6 g_cons_utf86 lcsresults
# 11126      Objc  230740  word    צַדִּ֛יק          צדיק       צדיק
# 11127      Objc  230746  word  עֲוֹנֹתָ֖ם         עונתם

# %% [markdown]
# Preparing for stats

# %%
PredObjWordListsXL['Predlength']=PredObjWordListsXL.apply(lambda row : len(row['g_cons_utf84']), axis = 1)

# %%
PredObjWordListsXL['Objclength']=PredObjWordListsXL.apply(lambda row : len(row['g_cons_utf86']), axis = 1)

# %%
PredObjWordListsXL['LCSlength']=PredObjWordListsXL.apply(lambda row : len(row['lcsresults']), axis = 1)

# %%
PredObjWordListsXL.head()
# Out:
#    R       S1  S2  S3    book1 function3 TYPE4 g_cons_utf84   TYPE5 function5  \
# 0  1  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 1  2  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 2  3  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 3  4  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 4  5  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
#
#    NODE6 TYPE6        TEXT6 g_cons_utf86 lcsresults  Predlength  Objclength  \
# 0      5  word        אֵ֥ת            את          א           3           2
# 1      6  word           הַ            ה                      3           1
# 2      7  word  שָּׁמַ֖יִם         שׁמים                      3           5
# 3      8  word           וְ            ו                      3           1
# 4      9  word        אֵ֥ת            את          א           3           2
#
#    LCSlength
# 0          1
# 1          0
# 2          0
# 3          0
# 4          1

# %% [markdown]
# Lets calculate highest mean

# %%
PredObjWordListsXL['LCSObjcPredMeanMatch']=PredObjWordListsXL.apply(lambda row : meanpercentage(row['Predlength'], row['Objclength'], row['LCSlength']), axis = 1)
PredObjWordListsXL.head(6)
# Out:
#    R       S1  S2  S3    book1 function3 TYPE4 g_cons_utf84   TYPE5 function5  \
# 0  1  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 1  2  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 2  3  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 3  4  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 4  5  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
# 5  6  Genesis   1   1  Genesis      Pred  word          ברא  phrase      Objc
#
#    NODE6 TYPE6        TEXT6 g_cons_utf86 lcsresults  Predlength  Objclength  \
# 0      5  word        אֵ֥ת            את          א           3           2
# 1      6  word           הַ            ה                      3           1
# 2      7  word  שָּׁמַ֖יִם         שׁמים                      3           5
# 3      8  word           וְ            ו                      3           1
# 4      9  word        אֵ֥ת            את          א           3           2
# 5     10  word           הָ            ה                      3           1
#
#    LCSlength  LCSObjcPredMeanMatch
# 0          1                  40.0
# 1          0                   0.0
# 2          0                   0.0
# 3          0                   0.0
# 4          1                  40.0
# 5          0                   0.0

# %% [markdown]
# Lets sort the results in ascending order (100% matches on top, 0% at the bottom of the table)

# %%
PredObjWordListsXL.sort_values(['LCSObjcPredMeanMatch'], ascending=[False])
# Out:
#            R            S1  S2  S3          book1 function3 TYPE4  \
# 18327  18328  Ecclesiastes   1  17   Ecclesiastes      Pred  word
# 5531    5532   Deuteronomy  18  20  Deuteronomium      Pred  word
# 11209  11210        Isaiah  57   7         Jesaia      Pred  word
# 17731  17732      Proverbs   9   2      Proverbia      Pred  word
# 7030    7031       1_Kings   2  23        Reges_I      Pred  word
# ...      ...           ...  ..  ..            ...       ...   ...
# 7950    7951       1_Kings   8  66        Reges_I      Pred  word
# 7951    7952       1_Kings   8  66        Reges_I      Pred  word
# 7952    7953       1_Kings   8  66        Reges_I      Pred  word
# 7953    7954       1_Kings   8  66        Reges_I      Pred  word
# 18737  18738  Ecclesiastes  12  14   Ecclesiastes      Pred  word
#
#       g_cons_utf84   TYPE5 function5   NODE6 TYPE6        TEXT6 g_cons_utf86  \
# 18327          דעת  phrase      Objc  359557  word      דַ֥עַת           דעת
# 5531           דבר  phrase      Objc  103804  word     דָּבָ֜ר           דבר
# 11209          זבח  phrase      Objc  231661  word     זָֽבַח׃           זבח
# 17731         טבחה  phrase      Objc  349188  word   טִ֭בְחָהּ          טבחה
# 7030           דבר  phrase      Objc  177809  word     דָּבָ֖ר           דבר
# ...            ...     ...       ...     ...   ...          ...          ...
# 7950          שׁלח  phrase      Objc  183640  word        עָ֔ם            עם
# 7951         יברכו  phrase      Objc  183643  word         אֶת־           את
# 7952         יברכו  phrase      Objc  183644  word           הַ            ה
# 7953         יברכו  phrase      Objc  183645  word    מֶּ֑לֶךְ           מלך
# 18737          יבא  phrase      Objc  363499  word  מַֽעֲשֶׂ֔ה         מעשׂה
#
#       lcsresults  Predlength  Objclength  LCSlength  LCSObjcPredMeanMatch
# 18327        דעת           3           3          3                 100.0
# 5531         דבר           3           3          3                 100.0
# 11209        זבח           3           3          3                 100.0
# 17731       טבחה           4           4          4                 100.0
# 7030         דבר           3           3          3                 100.0
# ...          ...         ...         ...        ...                   ...
# 7950                       4           2          0                   0.0
# 7951                       5           2          0                   0.0
# 7952                       5           1          0                   0.0
# 7953                       5           3          0                   0.0
# 18737                      3           5          0                   0.0
#
# [18714 rows x 19 columns]

# %% [markdown]
# Lets only look for those cases that have 80% matching:

# %%
PredObjWordListsXL[PredObjWordListsXL.LCSObjcPredMeanMatch >= 80].sort_values(['R', 'g_cons_utf84'], ascending=[True,False])
# Out:
#            R             S1  S2  S3         book1 function3 TYPE4  \
# 18        19        Genesis   1  11       Genesis      Pred  word
# 629      630        Genesis  11   5       Genesis      Pred  word
# 633      634        Genesis  11   5       Genesis      Pred  word
# 741      742        Genesis  12   7       Genesis      Pred  word
# 1491    1492        Genesis  24   7       Genesis      Pred  word
# ...      ...            ...  ..  ..           ...       ...   ...
# 17996  17997       Proverbs  23   6     Proverbia      Pred  word
# 18065  18066       Proverbs  25   9     Proverbia      Pred  word
# 18281  18282  Song_of_songs   7  13      Canticum      Pred  word
# 18327  18328   Ecclesiastes   1  17  Ecclesiastes      Pred  word
# 18704  18705   Ecclesiastes  11   6  Ecclesiastes      Pred  word
#
#       g_cons_utf84   TYPE5 function5   NODE6 TYPE6       TEXT6 g_cons_utf86  \
# 18           תדשׁא  phrase      Objc     185  word   דֶּ֔שֶׁא          דשׁא
# 629            ראת  phrase      Objc    5047  word        אֶת־           את
# 633            ראת  phrase      Objc    5051  word        אֶת־           את
# 741            אתן  phrase      Objc    5619  word        אֶת־           את
# 1491           אתן  phrase      Objc   11248  word        אֶת־           את
# ...            ...     ...       ...     ...   ...         ...          ...
# 17996         תלחם  phrase      Objc  353053  word     לֶ֭חֶם           לחם
# 18065          ריב  phrase      Objc  353806  word  רִֽ֭יבְךָ          ריבך
# 18281          אתן  phrase      Objc  359035  word        אֶת־           את
# 18327          דעת  phrase      Objc  359557  word     דַ֥עַת           דעת
# 18704          זרע  phrase      Objc  363127  word  זַרְעֶ֔ךָ          זרעך
#
#       lcsresults  Predlength  Objclength  LCSlength  LCSObjcPredMeanMatch
# 18          דשׁא           5           4          4             88.888889
# 629           את           3           2          2             80.000000
# 633           את           3           2          2             80.000000
# 741           את           3           2          2             80.000000
# 1491          את           3           2          2             80.000000
# ...          ...         ...         ...        ...                   ...
# 17996        לחם           4           3          3             85.714286
# 18065        ריב           3           4          3             85.714286
# 18281         את           3           2          2             80.000000
# 18327        דעת           3           3          3            100.000000
# 18704        זרע           3           4          3             85.714286
#
# [116 rows x 19 columns]

# %% [markdown]
# Lets find again our case in Isa 53:11

# %%
PredObjWordListsXL[
          (PredObjWordListsXL['S1'] == 'Isaiah')
        & (PredObjWordListsXL['S2'] == 53)
        & (PredObjWordListsXL["S3"] == 11)
       ].sort_values(['S2', 'S3'], ascending=[False,True]).head()
# Out:
#            R      S1  S2  S3   book1 function3 TYPE4 g_cons_utf84   TYPE5  \
# 11126  11127  Isaiah  53  11  Jesaia      Pred  word        יצדיק  phrase
# 11127  11128  Isaiah  53  11  Jesaia      Pred  word         יסבל  phrase
#
#       function5   NODE6 TYPE6        TEXT6 g_cons_utf86 lcsresults  \
# 11126      Objc  230740  word    צַדִּ֛יק          צדיק       צדיק
# 11127      Objc  230746  word  עֲוֹנֹתָ֖ם         עונתם
#
#        Predlength  Objclength  LCSlength  LCSObjcPredMeanMatch
# 11126           5           4          4             88.888889
# 11127           4           5          0              0.000000

# %% [markdown]
# Lets find all cases that have a higher than 70% matching rate.

# %%
PredObjWordListsXL[PredObjWordListsXL.LCSObjcPredMeanMatch > 70].sort_values(['LCSObjcPredMeanMatch', 'S1'], ascending=[False,True]).head(20)
# Out:
#            R            S1  S2  S3          book1 function3 TYPE4  \
# 7030    7031       1_Kings   2  23        Reges_I      Pred  word
# 7273    7274       1_Kings   5  17        Reges_I      Pred  word
# 7285    7286       1_Kings   5  19        Reges_I      Pred  word
# 5531    5532   Deuteronomy  18  20  Deuteronomium      Pred  word
# 18327  18328  Ecclesiastes   1  17   Ecclesiastes      Pred  word
# 2000    2001       Genesis  29  13        Genesis      Pred  word
# 3146    3147       Genesis  42  25        Genesis      Pred  word
# 3248    3249       Genesis  43  16        Genesis      Pred  word
# 9778    9779        Isaiah  10   6         Jesaia      Pred  word
# 9780    9781        Isaiah  10   6         Jesaia      Pred  word
# 9798    9799        Isaiah  10  16         Jesaia      Pred  word
# 10137  10138        Isaiah  24   3         Jesaia      Pred  word
# 11209  11210        Isaiah  57   7         Jesaia      Pred  word
# 11307  11308        Isaiah  58  13         Jesaia      Pred  word
# 12527  12528      Jeremiah  19   5        Jeremia      Pred  word
# 17731  17732      Proverbs   9   2      Proverbia      Pred  word
# 6979    6980       1_Kings   2   3        Reges_I      Pred  word
# 11840  11841      Jeremiah   6  24        Jeremia      Pred  word
# 7791    7792       1_Kings   8  32        Reges_I      Pred  word
# 5975    5976   Deuteronomy  26  12  Deuteronomium      Pred  word
#
#       g_cons_utf84   TYPE5 function5   NODE6 TYPE6          TEXT6  \
# 7030           דבר  phrase      Objc  177809  word       דָּבָ֖ר
# 7273             ל  phrase      Objc  179697  word             לְ
# 7285             ל  phrase      Objc  179734  word             לְ
# 5531           דבר  phrase      Objc  103804  word       דָּבָ֜ר
# 18327          דעת  phrase      Objc  359557  word        דַ֥עַת
# 2000          שׁמע  phrase      Objc   15198  word      שֵׁ֣מַע׀
# 3146             ל  phrase      Objc   23868  word             לַ
# 3248           טבח  phrase      Objc   24459  word       טֶ֨בַח֙
# 9778          שׁלל  phrase      Objc  215613  word       שָׁלָל֙
# 9780            בז  phrase      Objc  215617  word         בַּ֔ז
# 9798           יקד  phrase      Objc  215816  word        יְקֹ֖ד
# 10137          דבר  phrase      Objc  219753  word       דָּבָ֥ר
# 11209          זבח  phrase      Objc  231661  word       זָֽבַח׃
# 11307          דבר  phrase      Objc  232200  word      דָּבָֽר׃
# 12527            ל  phrase      Objc  244243  word             לַ
# 17731         טבחה  phrase      Objc  349188  word     טִ֭בְחָהּ
# 6979         שׁמרת  phrase      Objc  177308  word  מִשְׁמֶ֣רֶת׀
# 11840       שׁמענו  phrase      Objc  238105  word     שָׁמְעֹ֖ו
# 7791         הצדיק  phrase      Objc  182802  word      צַדִּ֔יק
# 5975          עשׂר  phrase      Objc  107421  word     מַעְשַׂ֧ר
#
#       g_cons_utf86 lcsresults  Predlength  Objclength  LCSlength  \
# 7030           דבר        דבר           3           3          3
# 7273             ל          ל           1           1          1
# 7285             ל          ל           1           1          1
# 5531           דבר        דבר           3           3          3
# 18327          דעת        דעת           3           3          3
# 2000          שׁמע       שׁמע           4           4          4
# 3146             ל          ל           1           1          1
# 3248           טבח        טבח           3           3          3
# 9778          שׁלל       שׁלל           4           4          4
# 9780            בז         בז           2           2          2
# 9798           יקד        יקד           3           3          3
# 10137          דבר        דבר           3           3          3
# 11209          זבח        זבח           3           3          3
# 11307          דבר        דבר           3           3          3
# 12527            ל          ל           1           1          1
# 17731         טבחה       טבחה           4           4          4
# 6979        משׁמרת      שׁמרת           5           6          5
# 11840        שׁמעו      שׁמעו           6           5          5
# 7791          צדיק       צדיק           5           4          4
# 5975         מעשׂר       עשׂר           4           5          4
#
#        LCSObjcPredMeanMatch
# 7030             100.000000
# 7273             100.000000
# 7285             100.000000
# 5531             100.000000
# 18327            100.000000
# 2000             100.000000
# 3146             100.000000
# 3248             100.000000
# 9778             100.000000
# 9780             100.000000
# 9798             100.000000
# 10137            100.000000
# 11209            100.000000
# 11307            100.000000
# 12527            100.000000
# 17731            100.000000
# 6979              90.909091
# 11840             90.909091
# 7791              88.888889
# 5975              88.888889

# %% [markdown]
# ## Visualizing!
# ### Distribution over Queried Books
# Lets do some visualization. Which book has how man LCS matches of 75% or higher?

# %%
PredObjWordListsXLplot75 = PredObjWordListsXL[PredObjWordListsXL.LCSObjcPredMeanMatch >= 75]

# %%
figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
PredObjWordListsXLplot75.groupby("S1").size().sort_values(ascending=True).plot.barh()
plt.xlabel('books')
plt.ylabel('number of LCS mean-matches above 80%')
plt.title('similar sounding predicates and Objects')
plt.show()

# %% [markdown]
# Lets see how the LCS phenomenon is distributed over the different books according to its matching percentage.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 15)

for S1, df in PredObjWordListsXL.groupby('LCSObjcPredMeanMatch'):
    ax.scatter(x="S1", y="LCSObjcPredMeanMatch", data=df, label=S1)

ax.set_xlabel("TNK books")
ax.set_ylabel("percentage of LCS matching")
ax.legend();

# %%
sns.lmplot(x="R", y="LCSObjcPredMeanMatch", data=PredObjWordListsXL, hue='S1', height=10, aspect=1/1, fit_reg=False, scatter_kws={"s": 200})
ax = plt.gca()
ax.set_ylabel('LCS matching percentage')
ax.set_xlabel('OT books')
# Out:
# Text(0.5, 28.999999999999986, 'OT books')

# %% [markdown]
# We can see quickly that Isiah, Jeremiah, and Psalms have a much higher density of high matching (>=80%) LCS cases.

# %% [markdown]
# ### Distributions in Isiah's chapters
# Lets have a look at the distribution of the phenomena over the different chapters in Isiah. While we do so, lets compare the >=90% matching with a >=60% matching in Isiah.

# %%
PredObjWordListsXLplot60 = PredObjWordListsXL[PredObjWordListsXL.LCSObjcPredMeanMatch >= 60]

# %%
PredObjWordListsXLplot75Isa = PredObjWordListsXLplot75[PredObjWordListsXLplot75.S1 == 'Isaiah']
PredObjWordListsXLplot60Isa = PredObjWordListsXLplot60[PredObjWordListsXLplot60.S1 == 'Isaiah']

plt.plot(PredObjWordListsXLplot60Isa.S2,PredObjWordListsXLplot60Isa.LCSObjcPredMeanMatch)
plt.plot(PredObjWordListsXLplot75Isa.S2,PredObjWordListsXLplot75Isa.LCSObjcPredMeanMatch)
plt.xlabel("chapter")
plt.ylabel("LCS matching percentage")
# Out:
# Text(0, 0.5, 'LCS matching percentage')

# %% [markdown]
# Now, lets see how the LCS phenomenon is distributed over the different chapters of Isiah:

# %%
PredObjWordListsXLIsaAll = PredObjWordListsXL[PredObjWordListsXL.S1 == 'Isaiah']

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)

for S2, df in PredObjWordListsXLIsaAll.groupby('LCSObjcPredMeanMatch'):
    ax.scatter(x="S2", y="LCSObjcPredMeanMatch", data=df, label=S1)

ax.set_xlabel("chapters in Isiah")
ax.set_ylabel("percentage of LCS matching")
ax.legend();

# %%
sns.lmplot(x="R", y="LCSObjcPredMeanMatch", data=PredObjWordListsXLIsaAll, hue='S2', height=10, aspect=2/1, fit_reg=False, scatter_kws={"s": 200})
ax = plt.gca()
ax.set_ylabel('percentage of LCS matching')
ax.set_xlabel('chapters')
# Out:
# Text(0.5, 28.999999999999986, 'chapters')

# %% [markdown]
# # MISC

# %% [markdown]
# ## version: Rosettacode.org

# %%
#https://rosettacode.org/wiki/Longest_common_subsequence#Python


def lcs2(a, b):
    # generate matrix of length of longest common subsequence for substrings of both words
    lengths = [[0] * (len(b)+1) for _ in range(len(a)+1)]
    for i, x in enumerate(a):
        for j, y in enumerate(b):
            if x == y:
                lengths[i+1][j+1] = lengths[i][j] + 1
            else:
                lengths[i+1][j+1] = max(lengths[i+1][j], lengths[i][j+1])
 
    # read a substring from the matrix
    result = ''
    j = len(b)
    for i in range(1, len(a)+1):
        if lengths[i][j] != lengths[i-1][j]:
            result += a[i-1]
 
    return result

# %%
a = "GTY"
b = "GXTXAYB"
lcs2(a,b)
# Out:
# 'GTY'

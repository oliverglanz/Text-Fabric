# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Optimizing-the-Jupyter-Notebook-Workbench" data-toc-modified-id="Optimizing-the-Jupyter-Notebook-Workbench-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Optimizing the Jupyter-Notebook-Workbench</a></span></li><li><span><a href="#Whats-Next?:-Getting-to-know-the-bhsa-database" data-toc-modified-id="Whats-Next?:-Getting-to-know-the-bhsa-database-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Whats Next?: Getting to know the <code>bhsa</code> database</a></span></li></ul></div>

# %% [markdown]
# # Optimizing the Jupyter-Notebook-Workbench
# There are several ways by which the work with Jupyter Notebooks can be significantly improved. Two ways will be highlighted here:
#
# ||**Viewing a Navigation Pane**| **Table of Content**|
# |---:|:---|:---|
# |**how it looks**|||
# ||![Annotation%202020-10-05%20211630.png](attachment:Annotation%202020-10-05%20211630.png)| ![Screenshot%202020-10-06%20093853.png](attachment:Screenshot%202020-10-06%20093853.png) |
# |**what to do**|||
# ||The simpliest and fastest way to install the Navigation Pane is by running the following command in your terminal <br> ```conda install -c conda-forge jupyter_contrib_nbextensions```. <br> The command only works when Anaconda is installed. If python has been installed differently the following command needs to be run <br> ```pip3 install jupyter_contrib_nbextensions && jupyter contrib nbextension install``` <br> When the command have been executed you have to activate the TOC extension in the Jupyter Notebook Tree overview: <br> ![Screenshot%202020-10-06%20094249.png](attachment:Screenshot%202020-10-06%20094249.png) | In order to activate the TOC features do the following: <br> ![Annotation%202020-10-05%20214105.png](attachment:Annotation%202020-10-05%20214105.png)|
#
# Helpful Links: https://towardsdatascience.com/jupyter-notebook-extensions-517fa69d2231 <br> https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/nbextensions/toc2/README.html

# %% [markdown]
# # Whats Next?: Getting to know the `bhsa` database
# 1. We learn how the architecture of the `bhsa` database looks like.
# 2. We start building complex syntactical queries.

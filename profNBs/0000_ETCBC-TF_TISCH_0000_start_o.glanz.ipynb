# %% [markdown]
# # Getting started with the Greek Tischendorf text
# ## History
# It is due to the work of Ulrik Sandborg-Petersen, PhD, MA, B.Sc. ([Aalborg Univeristy](https://www.en.aau.dk/)) that we have the Tischendorf text available in a high quality and morphologically analyzed form. Ulrik relied to a great extent on the work of Maurice A. Robinson and G. Clint Yale for the morphological anaylsis.
# In 2019 Cody Kingham, MA, MA, PhD cand ([University of Cambridge](https://www.cam.ac.uk/)) converted Ulrik's electronic version of the Tischendorf text into the ([Text Fabric](https://annotation.github.io/text-fabric/)) format and made it available as a TF app. You can check out his conversion protocoll [here](https://github.com/codykingham/tischendorf_tf/blob/master/tisch2tf/tisch2TF.ipynb).
# After Cody's work I (Oliver Glanz, MTh, MA, PhD ([Andrews University](https://www.andrews.edu/)), extracted from Ulrik's compact morphological coding (available in one TF feature collection) all morphological categories as single TF features that can now be searched individually. See my extraction protocoll [here](https://nbviewer.jupyter.org/github/oliverglanz/Tischendorf-Morphology-tf-/blob/master/0000_ETCBC-TISCH-featureadd_o.glanz.ipynb).
# ## This notebook
# In this notebook I help you getting started witht the Tischendorf app. You will learn how to run the app on your computer, how to formulate simple queries, and how to visualize your search results.

# %% [markdown]
# ## Installing the necessary environment to run jupyter notebooks
# 1. Go to https://www.anaconda.com/distribution/ and download the Phython 3.7 version for your platform (available for Linux, MacOS, Windows).
#
# 2. After Anaconda has been installed start the ```Anaconda prompt``` terminal.
#
# 3. Once the terminal is available you want to install the TextFabric environment that holds all the biblical data of the ETCBC research group (http://etcbc.nl/). You do so by writing the following command into the terminal:
#
# ```
# pip3 install text-fabric
# ```
# or when you are on windows
# ```
# pip install text-fabric
# ```
#
# After TF has been installed run the following command to make sure that you have upgraded to the latest TF version:
#
# ```
# pip3 install --upgrade text-fabric
# ```
# or when you are on Windows
# ```
# pip install --upgrade text-fabric
# ```
#
# Finally, to work most smoothly with a table of content (toc) it makes a lot of sense to also install the following extension in the terminal (See [Jupyter Notebook Extensions](https://towardsdatascience.com/jupyter-notebook-extensions-517fa69d2231)):
# ```
# pip3 install jupyter_contrib_nbextensions && jupyter contrib nbextension install
# ```
# or when you are on Windows
# ```
# pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install -user
# ```
# ## Starting the Text-Fabric Browser
# The quickest and easiest way to use Text-Fabric's text display and search options is to use the Text-Fabric Browser. You can start the TF browswer with the following command in the console:
# ```py
# text-fabric tisch
# ```
# This will start the Tischedorf corpus of TF:
# ![](https://fewvhq.dm.files.1drv.com/y4mc7lpog3z0mZW714DU4mvUUvX3uqitIF1I3fe9JIvW6vZj0UwQzWAyBRZ221BTLMjEz9RsvebsMesLYibjms_TAVN7Bv7SpuLU_FH6vZGFDbknnXy_R-hDGq8WZQnEw4rwOaRSVhTHMk1lk1XGzBTTMZLsoYX_-Ky6OBBa3QWCKhnLRlkHlc3x69WgvqO-qyYl6ZsBvQsNBVb1y2zOZ9EPQ/text-fabric_tisch.png?psid=1)
#
# If you want to start another corpus like the Biblia Hebraica Stuttgartensia you would have to alter the command:
# ```py
# text-fabric bhsa
# ```
# ![](https://qp4enq.dm.files.1drv.com/y4mpH00HIKJUjc1OUhxC9N_-YpiKp5EHk2eWT48f-19dEC3qvLsYudNEDCUKQ0JhzOFpMj4TM7JHwpFsQCSlaODUP7TAiOzYkwnrJZCxfrqPyIcfos5cGPYuDcSjKXlOpOSdQSdovoeG4qeMRq1gpnAU2lb1_TMEgsj7IJ48rp_OW4--v-SYEAczxS8irKEOMvqY3Eaz7aywE8ut_KlZXEaqQ/text-fabric_bhsa.png?psid=1)
#
# If you want to start another corpus like the Dead Sea Scrolls you would have to alter the command:
# ```py
# text-fabric dss
# ```
# ![](https://nwcuqg.dm.files.1drv.com/y4mNo2KAd9mffRaHTai9-Wulyi9tCNLGFAPkHiGfHyMaNtQmJ0ibvA8z27QigHX5xLGklAE2OsNFSjdzSTgxNHFkh8zuMV59TdYT9DPHY_iJOe1zRykUXZx1SEKpanzynAVGEJd27Vyq374tDBB63NlpjfEMuRQRB6b-mFTm7VEyqf_J9ZkitXD9iCSciO6KTnkmXPMZf3TzirS5Jvh-h1nzg/text-fabric_dss.png?psid=1)
#
# A full list of apps can be found here: https://annotation.github.io/text-fabric/About/Corpora/

# %% [markdown]
# ## Starting a jupyter notebook
# 1. Now all the tools are installed for doing our exegetical research. Lets fire up Jupyter Notebooks by executing the command ```jupyter notebook``` in your Anaconda prompt termnal. Your default webbrowser will start and showing you the folder structure of your default OS folder.
#
# 2. Now Download this notebook.
# ![Annotation2019-06-09_220638-tisch.png](attachment:Annotation2019-06-09_220638-tisch.png)
#
# 3. Check where your default folder is located and copy this downloaded notebook into that folder.
#
# 4. Refresh your broswer and you will see the downloaded folder appear.
#
# 5. You can now start this notebook by clicking on the filename within your jupyter's folder overview.
#
# 6. Now you are ready to go!
#
#
# ## Loading important apps
# This very jupyter notebook is now running in your browser!
# Lets load some important python apps so that we can start writing our first queries.
#
# Run the code cells below.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %%
A = use('tisch', hoist=globals())
# Out:
# 	connecting to online GitHub repo annotation/app-tisch ... failed
# GitHub says: 403 {"message": "API rate limit exceeded for 143.207.173.16. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)", "documentation_url": "https://developer.github.com/v3/#rate-limiting"}
# The offline TF-app may not be the latest
# Using TF-app in C:\Users\Oliver Glanz/text-fabric-data/annotation/app-tisch/code:
# 	rv.1.2=#6bbf132c3854f186062b417a981aef0f51a8b714 (latest? release)
# 	connecting to online GitHub repo codykingham/tischendorf_tf ... failed
# GitHub says: 403 {"message": "API rate limit exceeded for 143.207.173.16. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)", "documentation_url": "https://developer.github.com/v3/#rate-limiting"}
# The offline data may not be the latest
# Using data in C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8:
# 	rv.1.12=#c8a8b8c0d9f1746f050f4da0a3e0421835b378df (latest? release)
#    |     0.00s No structure info in otext, the structure part of the T-API cannot be used
# <b>Documentation:</b> <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs" title="provenance of Tischendorf's 8th New Testament">TISCHENDORF_TF</a> <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md" title="('Greek characters transcription',)">Character table</a> <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#features.md" title="TISCHENDORF_TF feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-tisch" title="tisch API documentation">tisch API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.9.0</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Tischendorf's 8th New Testament</b>: <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#anlex_lem" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/anlex_lem.tf">anlex_lem</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#book" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/book.tf">book</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#book_code" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/book_code.tf">book_code</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#case" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/case.tf">case</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#chapter" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/chapter.tf">chapter</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#freq_lex" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/freq_lex.tf">freq_lex</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#gloss" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/gloss.tf">gloss</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#gn" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/gn.tf">gn</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#ketiv" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/ketiv.tf">ketiv</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#mood" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/mood.tf">mood</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#morph" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/morph.tf">morph</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#nountype" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/nountype.tf">nountype</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#nu" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/nu.tf">nu</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#originterrdiff" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/originterrdiff.tf">originterrdiff</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#otype" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/otype.tf">otype</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#para" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/para.tf">para</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#prntyp" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/prntyp.tf">prntyp</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#ps" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendorf_tf/tf/2.8/ps.tf">ps</a>  <a target="_blank" href="https://github.com/codykingham/tischendorf_tf/blob/master/docs/features.md#qere" title="C:\Users\Oliver Glanz/text-fabric-data/codykingham/tischendor ...
# <style>
# @font-face {
#   font-family: "SBL_BLit";
#   src:
#     local("SBL_BLit.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_BLit.ttf?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: ltr;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: ltr;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: ltr;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .grk,.grk a:visited,.sy a:link {
#     font-family: "SBL_BLit", serif;
#     font-size: large;
#     color: #111111;
#     direction: ltr;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">isSilent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">setSilent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">silentOff</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">silentOn</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">warning</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# # What books are available in the ETCBC Tisch collection?
# Text-Fabric has two special features, `otype` (object types) and `oslots` (object slots), that must occur in every Text-Fabric data set.
# `otype` tells you for each node its type, and you can ask for the number of `slot`s in the text.
# Lets check out what `otype`s are available by using the `F` function. `F` gives access to all features. Every feature has a method
# `freqList()`
# to generate a frequency list of its values, higher frequencies first.
#
#
# ```python
# slotType = 'word'
# otext = {'fmt:text-orig-full':'{qere} ',
#          'sectionTypes':'book,chapter,verse',
#          'sectionFeatures':'book,chapter,verse'}
#
# generic = {'Name': 'Morph-GNT Tischendorf',
#            'Version': None, # to be filled in
#            'Author': 'Constantin von Tischendorf',
#            'Editors': 'Ulrik Sandborg-Petersen, G. Clint Yale, and Maurice A. Robinson',
#            'Converter': 'Cody Kingham',
#            'Source:':'https://github.com/morphgnt/tischendorf-data/',
#            'Note':'Feature descriptions adapted from tischendorf-data README'}
#
# intFeatures = {'chapter', 'para', 'verse'}
#
# featureMeta = {'book': {'description': 'A book name'},
#                'chapter': {'description': 'A chapter number'},
#                'verse': {'description': 'A verse number'},
#                'book_code':{'description': 'Short book abbreviation'},
#                'para': {'description': 'A paragraph number'},
#                'ketiv': {'descrption': 'The text as it is written in the printed Tischendorf'},
#                'qere': {'description': 'The text as the editor thinks it should have been'},
#                'morph': {'description': 'Word morphological tag based on Maurice A Robinson\'s analysis'},
#                'strongs': {'description': 'A word\'s number in Strongs'},
#                'vrsnum': {'description': 'N-word in verse'},
#                'str_lem': {'description': 'Word lemma that corresponds to The NEW Strong\'sComplete Dictionary of Bible Words'},
#                'anlex_lem': {'description': 'Word lemma that corresponds to Friberg, Friberg and Miller\'s ANLEX'}
#               }
# ```

# %%
F.otype.all
# Out:
# ('book', 'chapter', 'paragraph', 'lex', 'verse', 'word')

# %% [markdown]
# These are then the object types we can work with. But what features do those object types (`otype`) have? Lets investigate the scrolls first.

# %%
TF.featureSets
# Out:
# {'nodes': {'anlex_lem',
#   'book',
#   'book_code',
#   'case',
#   'chapter',
#   'freq_lex',
#   'gloss',
#   'gn',
#   'ketiv',
#   'mood',
#   'morph',
#   'nountype',
#   'nu',
#   'originterrdiff',
#   'otype',
#   'para',
#   'prntyp',
#   'ps',
#   'qere',
#   'sp',
#   'str_lem',
#   'strongs',
#   'verse',
#   'voice',
#   'vrsnum',
#   'vt'},
#  'edges': {'oslots'},
#  'configs': {'otext'},
#  'computeds': {'__boundary__',
#   '__levDown__',
#   '__levUp__',
#   '__levels__',
#   '__order__',
#   '__rank__',
#   '__sections__',
#   '__structure__'}}

# %%
verse1 = A.nodeFromSectionStr('Matthew 1:1')
A.plain(verse1)
# Out:
# <span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="Matthew 1:1" sec="Matthew 1:1">Matthew 1:1</a>Βίβλος γενέσεως Ἰησοῦ Χριστοῦ υἱοῦ Δαυεὶδ υἱοῦ Ἀβραάμ. </span>

# %%
wordShow = (1, 2, 3)
for word in wordShow:
  A.pretty(word)
# Out:
# <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 1:1">Matthew 1:1</a>
# <div class="outeritem">
# <div class="word  " >
# <div class="grk">Βίβλος </div>
# <div class="features"></div>
# </div>
# </div>
# <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 1:1">Matthew 1:1</a>
# <div class="outeritem">
# <div class="word  " >
# <div class="grk">γενέσεως </div>
# <div class="features"></div>
# </div>
# </div>
# <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 1:1">Matthew 1:1</a>
# <div class="outeritem">
# <div class="word  " >
# <div class="grk">Ἰησοῦ </div>
# <div class="features"></div>
# </div>
# </div>

# %%
phraseShow = 3
A.pretty(phraseShow)
# Out:
# <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 1:1">Matthew 1:1</a>
# <div class="outeritem">
# <div class="word  " >
# <div class="grk">Ἰησοῦ </div>
# <div class="features"></div>
# </div>
# </div>

# %% [markdown]
# # word searching
# ## simple searches
# ### Searching for one word only
# #### Lets search for the word "Ἰησοῦς" in the nominative case in the gospel of John:
#
# - lexeme = **Ἰησοῦς**
# - case = **nominative**

# %%
JesusInJohn = '''
book book=John
    word anlex_lem=Ἰησοῦς case=nominative
'''
JesusInJohn=A.search(JesusInJohn)
# Out:
#   0.13s 197 results

# %% [markdown]
# Lets show the results and highlight them in magenta!

# %%
A.table(JesusInJohn, start=1, end=10, condensed=True, colorMap={2: 'magenta'})
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">verse</th><th>word</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="see this passage in its source document" sec="John 1:38">John 1:38</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="John 1:38" sec="John 1:38"></a>στραφεὶς ὁ <span  class="hl"  style="background-color: magenta;" >Ἰησοῦς </span>καὶ θεασάμενος αὐτοὺς ἀκολουθοῦντας λέγει αὐτοῖς· </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >Ἰησοῦς </span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="see this passage in its source document" sec="John 1:43">John 1:43</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="John 1:43" sec="John 1:43"></a>ἤγαγεν αὐτὸν πρὸς τὸν Ἰησοῦν. ἐμβλέψας αὐτῷ ὁ <span  class="hl"  style="background-color: magenta;" >Ἰησοῦς </span>εἶπεν· σὺ εἶ Σίμων ὁ υἱὸς Ἰωάννου, σὺ κληθήσῃ Κηφᾶς, ὃ ἑρμηνεύεται Πέτρος. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >Ἰησοῦς </span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="see this passage in its source document" sec="John 1:44">John 1:44</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="John 1:44" sec="John 1:44"></a>Τῇ ἐπαύριον ἠθέλησεν ἐξελθεῖν εἰς τὴν Γαλιλαίαν, καὶ εὑρίσκει Φίλιππον. καὶ λέγει αὐτῷ ὁ <span  class="hl"  style="background-color: magenta;" >Ἰησοῦς, </span>ἀκολούθει μοι. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >Ἰησοῦς, </span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="see this passage in its source document" sec="John 1:48">John 1:48</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="John 1:48" sec="John 1:48"></a>εἶδεν <span  class="hl"  style="background-color: magenta;" >Ἰησοῦς </span>τὸν Ναθαναὴλ ἐρχόμενον πρὸς αὐτὸν καὶ λέγει περὶ αὐτοῦ· ἴδε ἀληθῶς Ἰσραηλείτης, ἐν ᾧ δόλος οὐκ ἔστιν. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >Ἰησοῦς </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="see this passage in its source document" sec="John 1:49">John 1:49</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="John 1:49" sec="John 1:49"></a>λέγει αὐτῷ Ναθαναήλ· πόθεν με γινώσκεις; ἀπεκρίθη <span  class="hl"  style="background-color: magenta;" >Ἰησοῦς </span
a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/JOH.txt" title="John 1:43" sec="John 1:43"></a>ἤγαγεν αὐτὸν πρὸς τὸν Ἰησοῦν. ἐμβλέψας αὐτῷ ὁ <span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span>εἶπεν· σὺ εἶ Σίμων ὁ υἱὸς Ἰωάννου, σὺ κληθήσῃ Κηφᾶς, ὃ ἑρμηνεύεται Πέτρος. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span></span></td></tr></table>

# %% [markdown]
# #### Lets look for all words that are verbs, 2nd person, singular, perfect, indicative, and passive!
# - part of speech = **verbs**
# - number = **singular**
# - person = **2nd person**
# - verbal tense = **perfect**
# - mood = **indicative**
# - voice = **passive**

# %%
specialverb ='''
book
    word sp=verb nu=sg ps=p2 vt=perfect mood=indicative voice=passive
'''
specialverb=A.search(specialverb)
# Out:
#   0.14s 3 results

# %% [markdown]
# Lets show the results and highlight them in yellow!

# %%
A.table(specialverb, start=1, end=10, condensed=True, colorMap={2: 'yellow'})
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">verse</th><th>word</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/LU.txt" title="see this passage in its source document" sec="Luke 13:12">Luke 13:12</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/LU.txt" title="Luke 13:12" sec="Luke 13:12"></a>ἰδὼν δὲ αὐτὴν ὁ Ἰησοῦς προσεφώνησεν καὶ εἶπεν αὐτῇ· γύναι, <span  class="hl"  style="background-color: yellow;" >ἀπολέλυσαι </span>ἀπὸ τῆς ἀσθενείας σου, </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: yellow;" >ἀπολέλυσαι </span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/1CO.txt" title="see this passage in its source document" sec="1_Corinthians 7:27">1_Corinthians 7:27</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/1CO.txt" title="1_Corinthians 7:27" sec="1_Corinthians 7:27"></a>δέδεσαι γυναικί; μὴ ζήτει λύσιν· <span  class="hl"  style="background-color: yellow;" >λέλυσαι </span>ἀπὸ γυναικός; μὴ ζήτει γυναῖκα. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: yellow;" >λέλυσαι </span></span></td><td class="tf"><span class="grk">δέδεσαι </span></td></tr></table>

# %% [markdown]
# You can also let TF show all the morphological coding within each verse by adding to your query all other morphological catories and then run `A.show` instead of `A.table`:

# %%
specialverb2 ='''
book
    word sp=verb nu=sg ps=p2 vt=perfect mood=indicative voice=passive anlex_lem* case* gloss* gn* ketiv* morph* nountype* originterrdiff* qere* str_lem* strongs* prntyp*
'''
specialverb2=A.search(specialverb2)
# Out:
#   0.75s 3 results

# %%
A.show(specialverb2, start=1, end=3, condensed=True, colorMap={2: 'yellow'})
# Out:
# <p><b>verse</b> <i>1</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/LU.txt" title="see this passage in its source document" sec="Luke 13:12">Luke 13:12</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="grk">ἰδὼν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁράω</span> <span class="case xft"><span class="f">case=</span>nominative</span> <span class="gloss xft"><span class="f">gloss=</span>to see</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="ketiv xft"><span class="f">ketiv=</span>ἰδὼν</span> <span class="mood xft"><span class="f">mood=</span>participle</span> <span class="morph xft"><span class="f">morph=</span>V-2AAP-NSM</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span>p2</span> <span class="qere xft"><span class="f">qere=</span>ἰδὼν</span> <span class="sp xft"><span class="f">sp=</span>verb</span> <span class="str_lem xft"><span class="f">str_lem=</span>ὁράω</span> <span class="strongs xft"><span class="f">strongs=</span>3708</span> <span class="voice xft"><span class="f">voice=</span></span> <span class="vt xft"><span class="f">vt=</span>aorist</span></div>
# </div>
# <div class="word  " >
# <div class="grk">δὲ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>δέ</span> <span class="case xft"><span class="f">case=</span></span> <span class="gloss xft"><span class="f">gloss=</span>but</span> <span class="gn xft"><span class="f">gn=</span></span> <span class="ketiv xft"><span class="f">ketiv=</span>δὲ</span> <span class="mood xft"><span class="f">mood=</span></span> <span class="morph xft"><span class="f">morph=</span>CONJ</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span></span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span></span> <span class="qere xft"><span class="f">qere=</span>δὲ</span> <span class="sp xft"><span class="f">sp=</span>pronoun</span> <span class="str_lem xft"><span class="f">str_lem=</span>δέ</span> <span class="strongs xft"><span class="f">strongs=</span>1161</span> <span class="voice xft"><span class="f">voice=</span></span> <span class="vt xft"><span class="f">vt=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">αὐτὴν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>αὐτός</span> <span class="case xft"><span class="f">case=</span>accusative</span> <span class="gloss xft"><span class="f">gloss=</span>he</span> <span class="gn xft"><span class="f">gn=</span>f</span> <span class="ketiv xft"><span class="f">ketiv=</span>αὐτὴν</span> <span class="mood xft"><span class="f">mood=</span></span> <span class="morph xft"><span class="f">morph=</span>P-ASF</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span>pers</span> <span class="ps xft"><span class="f">ps=</span></span> <span class="qere xft"><span class="f">qere=</span>αὐτὴν</span> <span class="sp xft"><span class="f">sp=</span>pronoun</span> <span class="str_lem xft"><span class="f">str_lem=</span>αὐτός</span> <span class="strongs xft"><span class="f">strongs=</span>846</span> <span class="voice xft"><span class="f">voice=</span></span> <span class="vt xft"><span class="f">vt=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ὁ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>nominative</span> <span class="gloss xft"><span class="f">gloss=</span>the</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="ketiv xft"><span class="f">ketiv=</span>ὁ</span> <span class="mood xft"><span class="f">mood=</span></span> <span class="morph xft"><span class="f">morph=</span>T-NSM</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span></span> <span class="qere xft"><span class="f">qere=</span>ὁ</span> <span class="sp xft"><span class="f">sp=</span>article</span> <span class="str_lem xft"><span class="f">str_lem=</span>ὁ</span> <span class="strongs xft"><span class="f">strongs=</span>3588</span> <span class="voice xft"><span class="f">voice=</span></span> <span class="vt xft"><span class="f">vt=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἰησοῦς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἰησοῦς</span> <span class="case xft"><span class="f">case=</span>nominative</span> <span class="gloss xft"><span class="f">gloss=</span>Jesus</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="ketiv xft"><span class="f">ketiv=</span>Ἰησοῦς</span> <span class="mood xft"><span class="f">mood=</span></span> <span class="morph xft"><span class="f">morph=</span>N-NSM</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span></span> <span class="qere xft"><span class="f">qere=</span>Ἰησοῦς</span> <span class="sp xft"><span class="f">sp=</span>noun</span> <span class="str_lem xft"><span class="f">str_lem=</span>Ἰησοῦς</span> <span class="strongs xft"><span class="f">strongs=</span>2424</span> <span class="voice xft"><span class="f">voice=</span></span> <span class="vt xft"><span class="f">vt=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">προσεφώνησεν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>προσφωνέω</span> <span class="case xft"><span class="f">case=</span></span> <span class="gloss xft"><span class="f">gloss=</span>to call out</span> <span class="gn xft"><span class="f">gn=</span></span> <span class="ketiv xft"><span class="f">ketiv=</span>προσεφώνησεν</span> <span class="mood xft"><span class="f">mood=</span>indicative</span> <span class="morph xft"><span class="f">morph=</span>V-AAI-3S</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span>p3</span> <span class="qere xft"><span class="f">qere=</span>προσεφώνησεν</span> <span class="sp xft"><span class="f">sp=</span>verb</span> <span class="str_lem xft"><span class="f">str_lem=</span>προσφωνέω</span> <span class="strongs xft"><span class="f">strongs=</span>4377</span> <span class="voice xft"><span class="f">voice=</span>active</span> <span class="vt xft"><span class="f">vt=</span>aorist</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class=
# <p><b>verse</b> <i>2</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/1CO.txt" title="see this passage in its source document" sec="1_Corinthians 7:27">1_Corinthians 7:27</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  hl"  style="background-color: yellow;" >
# <div class="grk">δέδεσαι </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>δέω</span> <span class="case xft"><span class="f">case=</span></span> <span class="gloss xft"><span class="f">gloss=</span>to tie</span> <span class="gn xft"><span class="f">gn=</span></span> <span class="ketiv xft"><span class="f">ketiv=</span>δέδεσαι</span> <span class="mood xft"><span class="f">mood=</span>indicative</span> <span class="morph xft"><span class="f">morph=</span>V-RPI-2S</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span>p2</span> <span class="qere xft"><span class="f">qere=</span>δέδεσαι</span> <span class="sp xft"><span class="f">sp=</span>verb</span> <span class="str_lem xft"><span class="f">str_lem=</span>δέω</span> <span class="strongs xft"><span class="f">strongs=</span>1210</span> <span class="voice xft"><span class="f">voice=</span>passive</span> <span class="vt xft"><span class="f">vt=</span>perfect</span></div>
# </div>
# <div class="word  " >
# <div class="grk">γυναικί; </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>γυνή</span> <span class="case xft"><span class="f">case=</span>dative</span> <span class="gloss xft"><span class="f">gloss=</span>woman</span> <span class="gn xft"><span class="f">gn=</span>f</span> <span class="ketiv xft"><span class="f">ketiv=</span>γυναικί;</span> <span class="mood xft"><span class="f">mood=</span></span> <span class="morph xft"><span class="f">morph=</span>N-DSF</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span></span> <span class="qere xft"><span class="f">qere=</span>γυναικί;</span> <span class="sp xft"><span class="f">sp=</span>noun</span> <span class="str_lem xft"><span class="f">str_lem=</span>γυνή</span> <span class="strongs xft"><span class="f">strongs=</span>1135</span> <span class="voice xft"><span class="f">voice=</span></span> <span class="vt xft"><span class="f">vt=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">μὴ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μή</span> <span class="case xft"><span class="f">case=</span></span> <span class="gloss xft"><span class="f">gloss=</span>no</span> <span class="gn xft"><span class="f">gn=</span>n</span> <span class="ketiv xft"><span class="f">ketiv=</span>μὴ</span> <span class="mood xft"><span class="f">mood=</span></span> <span class="morph xft"><span class="f">morph=</span>PRT-N</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span></span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span></span> <span class="qere xft"><span class="f">qere=</span>μὴ</span> <span class="sp xft"><span class="f">sp=</span>particle</span> <span class="str_lem xft"><span class="f">str_lem=</span>μή</span> <span class="strongs xft"><span class="f">strongs=</span>3361</span> <span class="voice xft"><span class="f">voice=</span></span> <span class="vt xft"><span class="f">vt=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ζήτει </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ζητέω</span> <span class="case xft"><span class="f">case=</span></span> <span class="gloss xft"><span class="f">gloss=</span>to look for</span> <span class="gn xft"><span class="f">gn=</span></span> <span class="ketiv xft"><span class="f">ketiv=</span>ζήτει</span> <span class="mood xft"><span class="f">mood=</span>imperative</span> <span class="morph xft"><span class="f">morph=</span>V-PAM-2S</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span>p2</span> <span class="qere xft"><span class="f">qere=</span>ζήτει</span> <span class="sp xft"><span class="f">sp=</span>verb</span> <span class="str_lem xft"><span class="f">str_lem=</span>ζητέω</span> <span class="strongs xft"><span class="f">strongs=</span>2212</span> <span class="voice xft"><span class="f">voice=</span>active</span> <span class="vt xft"><span class="f">vt=</span>present</span></div>
# </div>
# <div class="word  " >
# <div class="grk">λύσιν· </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>λύσις</span> <span class="case xft"><span class="f">case=</span>accusative</span> <span class="gloss xft"><span class="f">gloss=</span>divorce</span> <span class="gn xft"><span class="f">gn=</span>f</span> <span class="ketiv xft"><span class="f">ketiv=</span>λύσιν·</span> <span class="mood xft"><span class="f">mood=</span></span> <span class="morph xft"><span class="f">morph=</span>N-ASF</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span></span> <span class="qere xft"><span class="f">qere=</span>λύσιν·</span> <span class="sp xft"><span class="f">sp=</span>noun</span> <span class="str_lem xft"><span class="f">str_lem=</span>λύσις</span> <span class="strongs xft"><span class="f">strongs=</span>3080</span> <span class="voice xft"><span class="f">voice=</span></span> <span class="vt xft"><span class="f">vt=</span></span></div>
# </div>
# <div class="word  hl"  style="background-color: yellow;" >
# <div class="grk">λέλυσαι </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>λύω</span> <span class="case xft"><span class="f">case=</span></span> <span class="gloss xft"><span class="f">gloss=</span>to loose</span> <span class="gn xft"><span class="f">gn=</span></span> <span class="ketiv xft"><span class="f">ketiv=</span>λέλυσαι</span> <span class="mood xft"><span class="f">mood=</span>indicative</span> <span class="morph xft"><span class="f">morph=</span>V-RPI-2S</span> <span class="nountype xft"><span class="f">nountype=</span></span> <span class="nu xft"><span class="f">nu=</span>sg</span> <span class="originterrdiff xft"><span class="f">originterrdiff=</span></span> <span class="prntyp xft"><span class="f">prntyp=</span></span> <span class="ps xft"><span class="f">ps=</span>p2</span> <span class="qere xft"><span class="f">qere=</span>λέλυσαι</span> <span class="sp xft"><span class="f">sp=</span>verb</span> <span class="str_lem xft"><span class="f">str_lem=</span>λύω</span> <span class="strongs xft"><span class="f">strongs=</span>3089</span> <span class="voice xft"><span class="f">voice=</span>passive</span> <span class="vt xft"><span class="f">vt=</span>perfect</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἀπὸ </div>
# <div class="features"

# %% [markdown]
# ### Searching for word combinations
# #### Searching for "the testimony of Jesus"
# As we search for the phrase we want to make sure that "martyria" can have and case and "Jaesu" needs to be in the genetive case.
# The operator `<:` determines that `w2` needs to follow `<` `w1` without any word inbetween `:`.

# %%
TestimonyOfJesus = '''
book
    w1:word anlex_lem=μαρτυρία
    w2:word anlex_lem=Ἰησοῦς case=genitive
w1 <: w2
'''
TestimonyOfJesus=A.search(TestimonyOfJesus)
# Out:
#   0.27s 6 results

# %%
A.show(TestimonyOfJesus, start=1, end=10, condensed=True, colorMap={2: 'red', 3: 'orange'})
# Out:
# <p><b>verse</b> <i>1</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/RE.txt" title="see this passage in its source document" sec="Revelation 1:2">Revelation 1:2</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="grk">ὃς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὅς</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐμαρτύρησεν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μαρτυρέω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὸν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">λόγον </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>λόγος</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">θεοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>θεός</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὴν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">μαρτυρίαν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μαρτυρία</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: orange;" >
# <div class="grk">Ἰησοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἰησοῦς</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Χριστοῦ, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Χριστός</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ὅσα </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὅσος</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἴδεν. </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁράω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# </div>
# </div>
# <p><b>verse</b> <i>2</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/RE.txt" title="see this passage in its source document" sec="Revelation 1:9">Revelation 1:9</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="grk">Ἐγὼ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐγώ</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἰωάννης, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἰωάννης</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ὁ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἀδελφὸς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἀδελφός</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ὑμῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>σύ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">συνκοινωνὸς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>συγκοινωνός</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐν</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῇ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">θλίψει </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>θλῖψις</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">βασιλείᾳ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>βασιλεία</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ὑπομονῇ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὑπομονή</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐν</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἰησοῦ, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἰησοῦς</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐγενόμην </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>γίνομαι</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐν</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῇ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">νήσῳ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>νῆσος</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῇ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καλουμένῃ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καλέω</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Πάτμῳ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Πάτμος</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">διὰ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>διά</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὸν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">λόγον </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>λόγος</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">θεοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>θεός</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">διὰ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>διά</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὴν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">μαρτυρίαν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μαρτυρία</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: orange;" >
# <div class="grk">Ἰησοῦ. </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἰησοῦς</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# </div>
# </div>
# <p><b>verse</b> <i>3</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/RE.txt" title="see this passage in its source document" sec="Revelation 12:17">Revelation 12:17</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ὠργίσθη </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὀργίζω</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ὁ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">δράκων </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>δράκων</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐπὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐπί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῇ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">γυναικί, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>γυνή</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἀπῆλθεν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἀπέρχομαι</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ποιῆσαι </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ποιέω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">πόλεμον </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πόλεμος</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">μετὰ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μετά</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">λοιπῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>λοιπός</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">σπέρματος </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>σπέρμα</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">αὐτῆς, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>αὐτός</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τηρούντων </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>τηρέω</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐντολὰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐντολή</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">θεοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>θεός</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐχόντων </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἔχω</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὴν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">μαρτυρίαν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μαρτυρία</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: orange;" >
# <div class="grk">Ἰησοῦ· </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἰησοῦς</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# </div>
# </div>
# <p><b>verse</b> <i>4</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/RE.txt" title="see this passage in its source document" sec="Revelation 19:10">Revelation 19:10</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἔπεσα </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πίπτω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἔμπροσθεν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἔμπροσθεν</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ποδῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πούς</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">αὐτοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>αὐτός</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">προσκυνῆσαι </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>προσκυνέω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">αὐτῷ. </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>αὐτός</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">λέγει </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>λέγω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">μοι, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐγώ</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ὅρα </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁράω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">μή· </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μή</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">σύνδουλός </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>σύνδουλος</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">σού </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>σύ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">εἰμι </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>εἰμί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἀδελφῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἀδελφός</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">σου </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>σύ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐχόντων </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἔχω</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὴν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">μαρτυρίαν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μαρτυρία</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: orange;" >
# <div class="grk">Ἰησοῦ· </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἰησοῦς</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῷ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">θεῷ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>θεός</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">προσκύνησον. </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>προσκυνέω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἡ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">γὰρ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>γάρ</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">μαρτυρία </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μαρτυρία</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  hl"  style="background-color: orange;" >
# <div class="grk">Ἰησοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἰησοῦς</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐστιν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>εἰμί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὸ </div>
# <div class="features"> <span class="an
# <p><b>verse</b> <i>5</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/RE.txt" title="see this passage in its source document" sec="Revelation 20:4">Revelation 20:4</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="grk">Καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἴδον </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁράω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">θρόνους, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>θρόνος</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐκάθισαν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καθίζω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐπ’ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐπί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">αὐτούς, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>αὐτός</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">κρίμα </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>κρίμα</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐδόθη </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>δίδωμι</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">αὐτοῖς, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>αὐτός</span> <span class="case xft"><span class="f">case=</span>dative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ψυχὰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ψυχή</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τῶν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">πεπελεκισμένων </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πελεκίζω</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">διὰ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>διά</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὴν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">μαρτυρίαν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μαρτυρία</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  hl"  style="background-color: orange;" >
# <div class="grk">Ἰησοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἰησοῦς</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">διὰ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>διά</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὸν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">λόγον </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>λόγος</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τοῦ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">θεοῦ, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>θεός</span> <span class="case xft"><span class="f">case=</span>genitive</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">οἵτινες </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὅστις</span> <span class="case xft"><span class="f">case=</span>nominative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">οὐ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>οὐ</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">προσεκύνησαν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>προσκυνέω</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὸ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">θηρίον </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>θηρίον</span> <span class="case xft"><span class="f">case=</span>accusative</span></div>
# </div>
# <div class="word  " >
# <div class="grk">οὐδὲ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>οὐδέ</span> <span class="case xft"><span class="f">case=</span></span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὴν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span> <span class="

# %% [markdown]
# ## Complex searches
# ### Lets search for corellated conjunctions
# In Col 2:16-17 we find a syntactical construction that involves a series of conjunctions (καί and ἤ). The critical edition of the [NA28](https://ref.ly/logosres/na28?ref=BibleNA27.Col2.18) presents the text in the following way:
# ![col2_16-18.png](attachment:col2_16-18.png)
#
# The syntactical structure is differently analyzed by scholars. Below you see a comparison between the [cascadia](https://ref.ly/logosres/csgntsbl?ref=BibleSBLGNT.Col2.16) and [opentext](https://ref.ly/logosres/opentextgraph?ref=BibleNA27.Col2.16) analysis. One needs to keep in mind that the NA edition renders the text slightly different (see ἤ => καί) than the Mehrheitstext that is followed by the SBL edition (see καί => ἤ) :
# ![col2_16-18_cascadia-opentext.png](attachment:col2_16-18_cascadia-opentext.png)

# %% [markdown]
a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">Ἀθηναῖοι </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>Ἀθηναῖος</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">δὲ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>δέ</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">πάντες </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πᾶς</span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span></div>
# </div>
# <div class="word  " >
# <div class="grk">οἱ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐπιδημοῦντες </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐπιδημέω</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ξένοι </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ξένος</span></div>
# </div>
# <div class="word  " >
# <div class="grk">εἰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>εἰς</span></div>
# </div>
# <div class="word  " >
# <div class="grk">οὐδὲν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>οὐδείς</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἕτερον </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἕτερος</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ηὐκαίρουν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>εὐκαιρέω</span></div>
# </div>
# <div class="word  hl"  style="background-color: magenta;" >
# <div class="grk">ἢ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἤ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">λέγειν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>λέγω</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τι </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>τὶς</span></div>
# </div>
# <div class="word  hl"  style="background-color: magenta;" >
# <div class="grk">ἢ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἤ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἀκούειν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἀκούω</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τι </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>τὶς</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καινότερον. </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καινός</span></div>
# </div>
# </div>
# </div>
# <p><b>verse</b> <i>7</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/1TI.txt" title="see this passage in its source document" sec="1_Timothy 2:9">1_Timothy 2:9</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ὡσαύτως </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὡσαύτως</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">γυναῖκας </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>γυνή</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ἐν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐν</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">καταστολῇ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καταστολή</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">κοσμίῳ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>κόσμιος</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">μετὰ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μετά</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">αἰδοῦς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>αἰδώς</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">σωφροσύνης </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>σωφροσύνη</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">κοσμεῖν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>κοσμέω</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ἑαυτάς, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἑαυτοῦ</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">μὴ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μή</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ἐν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐν</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">πλέγμασιν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πλέγμα</span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span></div>
# </div>
# <div class="word  " >
# <div class="grk">χρυσῷ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>χρυσός</span></div>
# </div>
# <div class="word  hl"  style="background-color: magenta;" >
# <div class="grk">ἢ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἤ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">μαργαρίταις </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μαργαρίτης</span></div>
# </div>
# <div class="word  hl"  style="background-color: magenta;" >
# <div class="grk">ἢ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἤ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἱματισμῷ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἱματισμός</span></div>
# </div>
# <div class="word  " >
# <div class="grk">πολυτελεῖ, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πολυτελής</span></div>
# </div>
# </div>
# </div>

# %% [markdown]
# This is too much of noisy data. Lets reduce the distance between the conjunctions.

# %%
KaiHeHe2 ='''
v1:verse
    w1:word
    w2:word anlex_lem=καί
    w3:word anlex_lem=ἤ
    w4:word anlex_lem=ἤ    
v1 =20: w1
w1 < w2
w1 <10: w2
w2 < w3
w2 <6: w3
w3 < w4
w3 <6: w4
'''
KaiHeHe2=A.search(KaiHeHe2)
# Out:
#   0.47s 21 results

# %%
A.show(KaiHeHe2, start=1, end=200, condensed=True, colorMap={2: 'grey', 3: 'red', 4: 'magenta', 5: 'magenta'})
# Out:
# <p><b>verse</b> <i>1</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/LU.txt" title="see this passage in its source document" sec="Luke 12:11">Luke 12:11</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ὅταν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὅταν</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">δὲ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>δέ</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">εἰσφέρωσιν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>εἰσφέρω</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ὑμᾶς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>σύ</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ἐπὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐπί</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">τὰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">συναγωγὰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>συναγωγή</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">τὰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ἀρχὰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἀρχή</span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὰς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὁ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐξουσίας, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐξουσία</span></div>
# </div>
# <div class="word  " >
# <div class="grk">μὴ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μή</span></div>
# </div>
# <div class="word  " >
# <div class="grk">μεριμνήσητε </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μεριμνάω</span></div>
# </div>
# <div class="word  " >
# <div class="grk">πῶς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πῶς</span></div>
# </div>
# <div class="word  hl"  style="background-color: magenta;" >
# <div class="grk">ἢ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἤ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τί </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>τίς</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἀπολογήσησθε </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἀπολογέομαι</span></div>
# </div>
# <div class="word  hl"  style="background-color: magenta;" >
# <div class="grk">ἢ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἤ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τί </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>τίς</span></div>
# </div>
# <div class="word  " >
# <div class="grk">εἴπητε· </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>λέγω</span></div>
# </div>
# </div>
# </div>
# <p><b>verse</b> <i>2</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/1TI.txt" title="see this passage in its source document" sec="1_Timothy 2:9">1_Timothy 2:9</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="grk">ὡσαύτως </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ὡσαύτως</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span></div>
# </div>
# <div class="word  " >
# <div class="grk">γυναῖκας </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>γυνή</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐν</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">καταστολῇ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καταστολή</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">κοσμίῳ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>κόσμιος</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">μετὰ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μετά</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">αἰδοῦς </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>αἰδώς</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">σωφροσύνης </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>σωφροσύνη</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">κοσμεῖν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>κοσμέω</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ἑαυτάς, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἑαυτοῦ</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">μὴ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μή</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">ἐν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἐν</span></div>
# </div>
# <div class="word  hl"  style="background-color: grey;" >
# <div class="grk">πλέγμασιν </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πλέγμα</span></div>
# </div>
# <div class="word  hl"  style="background-color: red;" >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>καί</span></div>
# </div>
# <div class="word  " >
# <div class="grk">χρυσῷ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>χρυσός</span></div>
# </div>
# <div class="word  hl"  style="background-color: magenta;" >
# <div class="grk">ἢ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἤ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">μαργαρίταις </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>μαργαρίτης</span></div>
# </div>
# <div class="word  hl"  style="background-color: magenta;" >
# <div class="grk">ἢ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἤ</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἱματισμῷ </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>ἱματισμός</span></div>
# </div>
# <div class="word  " >
# <div class="grk">πολυτελεῖ, </div>
# <div class="features"> <span class="anlex_lem xft"><span class="f">anlex_lem=</span>πολυτελής</span></div>
# </div>
# </div>
# </div>

# %% [markdown]
# Lets look at the pattern that appears in the Mehrheitstext.

# %%
NoKaiButHeHe ='''
verse
/without/
    w0:word anlex_lem=καί
    w1:word anlex_lem=ἤ
    w2:word anlex_lem=ἤ
    w0 < w1
    w1 < w2
/-/
    w1:word anlex_lem=ἤ
    w2:word anlex_lem=ἤ
    w3:word anlex_lem=ἤ
    w1 < w2
    w2 < w3
'''
NoKaiButHeHe=A.search(NoKaiButHeHe)
# Out:
#   0.75s 68 results

# %%
A.show(NoKaiButHeHe, start=1, end=10, condensed=True, colorMap={2: 'magenta', 3: 'magenta', 4: 'magenta'})
# Out:
# <p><b>verse</b> <i>1</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MR.txt" title="see this passage in its source document" sec="Mark
span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >ἢ </span></span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >ἢ </span></span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >ἢ </span></span></td><td class="tf"><span class="grk">ἢ </span></td><td class="tf"><span class="grk">ἢ </span></td><td class="tf"><span class="grk">ἢ </span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/1CO.txt" title="see this passage in its source document" sec="1_Corinthians 5:11">1_Corinthians 5:11</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/1CO.txt" title="1_Corinthians 5:11" sec="1_Corinthians 5:11"></a>νυνὶ δὲ ἔγραψα ὑμῖν μὴ συναναμίγνυσθαι ἐάν τις ἀδελφὸς ὀνομαζόμενος ᾖ πόρνος <span  class="hl"  style="background-color: magenta;" >ἢ </span>πλεονέκτης <span  class="hl"  style="background-color: magenta;" >ἢ </span>εἰδωλολάτρης <span  class="hl"  style="background-color: magenta;" >ἢ </span>λοίδορος ἢ μέθυσος ἢ ἅρπαξ, τῷ τοιούτῳ μηδὲ συνεσθίειν. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >ἢ </span></span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >ἢ </span></span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >ἢ </span></span></td><td class="tf"><span class="grk">ἢ </span></td><td class="tf"><span class="grk">ἢ </span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/1CO.txt" title="see this passage in its source document" sec="1_Corinthians 14:6">1_Corinthians 14:6</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/1CO.txt" title="1_Corinthians 14:6" sec="1_Corinthians 14:6"></a>νῦν δέ, ἀδελφοί, ἐὰν ἔλθω πρὸς ὑμᾶς γλώσσαις λαλῶν, τί ὑμᾶς ὠφελήσω, ἐὰν μὴ ὑμῖν λαλήσω ἢ ἐν ἀποκαλύψει <span  class="hl"  style="background-color: magenta;" >ἢ </span>ἐν γνώσει <span  class="hl"  style="background-color: magenta;" >ἢ </span>ἐν προφητείᾳ <span  class="hl"  style="background-color: magenta;" >ἢ </span>διδαχῇ; </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >ἢ </span></span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >ἢ </span></span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: magenta;" >ἢ </span></span></td><td class="tf"><span class="grk">ἢ </span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/COL.txt" title="see this passage in its source document" sec="Colossians 2:16">Colossians 2:16</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/COL.txt" title="Colossians 2:16" sec="Colossians 2:16"></a>Μὴ οὖν τις ὑμᾶς κρινέτω ἐν βρώσει <span  class="hl"  style="background-color: magenta;" >ἢ </span>ἐν πόσει <span  class="hl"  style="background-color: magenta;" >ἢ </span>ἐν μέρει ἑορτῆς ἢ νουμηνίας <span  class="hl"  style="background-color: magenta;" >ἢ </span

# %% [markdown]
# No "either ... or" construction in:
# - Mat 6:31 (NA28)
# - Mark 10:29
# - Luk 18:29
# - Rom 8:35
# - 1 Cor 5:11 (its not the first ἢ  but the previous ἐάν  that initiates the "either")
# - 1 Cor 14:6 (its not the first ἢ  but the previous ἐάν  that initiates the "either")
# - 1 Thes 2:19
# - 1 Peter 4:15
#
# The only exception is Mk 13:35. But the construction is not triggering the "either ... or" function (see also modern translations). It rather hints at a textcritical issue which is also well documented in the text critical apparatus:
#
# ![image.png](attachment:image.png)
#
# Consequently, the proper translation is "X or Y or Z...".
#
#
# **Conclusion: it is highly unlikely that Col 2:16 resembles an "either ... or" construction. By default if there are three ἢ  conjunctions appearing in a sequence they trigger the meaning "or ... or".**

# %% [markdown]
# The following query does not exclude a preceding καὶ:

# %%
HeHeHe ='''
verse
    word anlex_lem=ἤ
    < word anlex_lem=ἤ
    < word anlex_lem=ἤ    
'''
HeHeHe=A.search(HeHeHe)
# Out:
#   0.37s 102 results

# %%
A.table(HeHeHe, start=1, end=10, condensed=True, colorMap={2: 'magenta', 3: 'magenta', 4: 'magenta'})
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">verse</th><th>word</th><th>word</th><th>word</th><th>word</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 18:8">Matthew 18:8</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="Matthew
a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/RO.txt" title="Romans 8:35" sec="Romans 8:35"></a>τίς ἡμᾶς χωρίσει ἀπὸ τῆς ἀγάπης τοῦ Χριστοῦ; θλῖψις <span  class="hl"  style="background-color: magenta;" >ἢ </span>στενοχωρία <span  class="hl"  style="background-color: magenta;" >ἢ </span>διωγμὸς <span  class="hl"  style="background-color: magenta;" >ἢ </spa

# %% [markdown]
# # Producing some graphical representations
# Since we will be using the python based visualization tools we need to first export our TF search results as a table and then load that table as a pandas dataframe.
# ## The distribution of Jesus as subject (nominative case) in the NT

# %%
JesusInNT = '''
book
    word anlex_lem=Ἰησοῦς case=nominative
'''
JesusInNT=A.search(JesusInNT)
# Out:
#   0.14s 456 results

# %%
A.table(JesusInNT, start=1, end=5, condensed=True, colorMap={2: 'gold'})
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">verse</th><th>word</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 1:16">Matthew 1:16</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="Matthew 1:16" sec="Matthew 1:16"></a>Ἰακὼβ δὲ ἐγέννησεν τὸν Ἰωσὴφ τὸν ἄνδρα Μαρίας, ἐξ ἧς ἐγεννήθη <span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span>ὁ λεγόμενος Χριστός. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 3:13">Matthew 3:13</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="Matthew 3:13" sec="Matthew 3:13"></a>Τότε παραγίνεται ὁ <span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span>ἀπὸ τῆς Γαλιλαίας ἐπὶ τὸν Ἰορδάνην πρὸς τὸν Ἰωάννην τοῦ βαπτισθῆναι ὑπ’ αὐτοῦ. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 3:15">Matthew 3:15</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="Matthew 3:15" sec="Matthew 3:15"></a>ἀποκριθεὶς δὲ ὁ <span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span>εἶπεν πρὸς αὐτόν, ἄφες ἄρτι, οὕτως γὰρ πρέπον ἐστὶν ἡμῖν πληρῶσαι πᾶσαν δικαιοσύνην. τότε ἀφίησιν αὐτόν. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 3:16">Matthew 3:16</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="Matthew 3:16" sec="Matthew 3:16"></a>βαπτισθεὶς δὲ ὁ <span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span>εὐθὺς ἀνέβη ἀπὸ τοῦ ὕδατος· καὶ ἰδοὺ ἀνεῴχθησαν οἱ οὐρανοί, καὶ εἶδεν πνεῦμα θεοῦ καταβαῖνον ὡσεὶ περιστερὰν ἐρχόμενον ἐπ’ αὐτόν· </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 4:1">Matthew 4:1</a></td><td class="tf"><span class="grk"><a class="vn" href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="Matthew 4:1" sec="Matthew 4:1"></a>Τότε ὁ <span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span>ἀνήχθη εἰς τὴν ἔρημον ὑπὸ τοῦ πνεύματος, πειρασθῆναι ὑπὸ τοῦ διαβόλου. </span></td><td class="tf"><span class="grk"><span  class="hl"  style="background-color: gold;" >Ἰησοῦς </span></span></td></tr></table>

# %%
A.export(JesusInNT, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='JesusInNT.tsv')

# %%
JesusInNT=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/JesusInNT.tsv',delimiter='\t',encoding='utf-16')
JesusInNT.head()
# Out:
#    R       S1  S2  S3   NODE1 TYPE1  NODE2 TYPE2    TEXT2 anlex_lem2  \
# 0  1  Matthew   1  16  137712  book    243  word  Ἰησοῦς      Ἰησοῦς
# 1  2  Matthew   3  13  137712  book   1130  word  Ἰησοῦς      Ἰησοῦς
# 2  3  Matthew   3  15  137712  book   1163  word  Ἰησοῦς      Ἰησοῦς
# 3  4  Matthew   3  16  137712  book   1183  word  Ἰησοῦς      Ἰησοῦς
# 4  5  Matthew   4   1  137712  book   1223  word  Ἰησοῦς      Ἰησοῦς
#
#         case2
# 0  nominative
# 1  nominative
# 2  nominative
# 3  nominative
# 4  nominative

# %% [markdown]
# ### Simple Bar plot

# %%
figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
JesusInNT.groupby("S1").size().sort_values(ascending=True).plot.barh()
plt.xlabel('occurence of Jesus as subject')
plt.ylabel('NT books')
plt.title('Jesus as subject (case=nominative)')
plt.show()

# %% [markdown]
# ### Simple Pie chart

# %%
JesusInNT.S1.value_counts(sort=False).plot.pie(autopct='%1.0f%%', shadow=True, startangle=90)
plt.show()

# %% [markdown]
# ### Simple Scatter Plot

# %%
sns.lmplot(x="S1", y="R", data=JesusInNT, hue='anlex_lem2', height=5, aspect=4/1, fit_reg=False, scatter_kws={"s": 200})
ax = plt.gca()
ax.set_ylabel('Occurence of Jesus as subject')
ax.set_xlabel('NT books')
# Out:
# Text(0.5, 28.999999999999986, 'NT books')

# %% [markdown]
# # Misc

# %%
wordsinMat = '''
book book=Matthew
    chapter chapter=1
        verse verse=1|2
            word vrsnum*
'''
wordsinMat=A.search(wordsinMat)
# Out:
#   0.21s 26 results

# %%
A.show(wordsinMat, start=1, end=5, condensed=True, colorMap={2: 'gold'})
# Out:
# <p><b>verse</b> <i>1</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 1:1">Matthew 1:1</a></div>
#
#         <div class="features"> <span class="verse xft"><span class="f">verse=</span>1</span></div>
#     </div>
#
# <div class="word  " >
# <div class="grk">Βίβλος </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>1</span></div>
# </div>
# <div class="word  " >
# <div class="grk">γενέσεως </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>2</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἰησοῦ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>3</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Χριστοῦ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>4</span></div>
# </div>
# <div class="word  " >
# <div class="grk">υἱοῦ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>5</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Δαυεὶδ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>6</span></div>
# </div>
# <div class="word  " >
# <div class="grk">υἱοῦ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>7</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἀβραάμ. </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>8</span></div>
# </div>
# </div>
# </div>
# <p><b>verse</b> <i>2</i></p>
# <div class="outeritem">
# <div class="verse  " >
#
#     <div class="ll">
#         <div class="line"><a href="https://github.com/morphgnt/tischendorf-data/tree/master/word-per-line/2.8/Unicode/MT.txt" title="see this passage in its source document" sec="Matthew 1:2">Matthew 1:2</a></div>
#
#         <div class="features"> <span class="verse xft"><span class="f">verse=</span>2</span></div>
#     </div>
#
# <div class="word  " >
# <div class="grk">Ἀβραὰμ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>1</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐγέννησεν </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>2</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὸν </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>3</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἰσαάκ, </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>4</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἰσαὰκ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>5</span></div>
# </div>
# <div class="word  " >
# <div class="grk">δὲ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>6</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐγέννησεν </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>7</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὸν </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>8</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἰακώβ, </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>9</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἰακὼβ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>10</span></div>
# </div>
# <div class="word  " >
# <div class="grk">δὲ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>11</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἐγέννησεν </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>12</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τὸν </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>13</span></div>
# </div>
# <div class="word  " >
# <div class="grk">Ἰούδαν </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>14</span></div>
# </div>
# <div class="word  " >
# <div class="grk">καὶ </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>15</span></div>
# </div>
# <div class="word  " >
# <div class="grk">τοὺς </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>16</span></div>
# </div>
# <div class="word  " >
# <div class="grk">ἀδελφοὺς </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>17</span></div>
# </div>
# <div class="word  " >
# <div class="grk">αὐτοῦ, </div>
# <div class="features"> <span class="vrsnum xft"><span class="f">vrsnum=</span>18</span></div>
# </div>
# </div>
# </div>

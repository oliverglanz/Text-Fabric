# %% [markdown]
# # Prelude

# %%
# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# %%
pd.set_option('display.max_rows', None)

# %%
# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %%
# Now we load the TF bhsa database
OT = use('etcbc/bhsa', version="2021", mod='CenterBLC/BHSaddons/tf')
# Out:
# <b title="local commit">TF-app:</b> <span title="#b83bcaee62ada4d03547df0b0e7aac2fd5de3f67 offline under ~/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local release">data:</b> <span title="rv1.7.3=#af70cebe9d23ea736bb40e3ccd6768875b52a49d offline under ~/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv1.0.0=#37d989c69b3addba2235d4bd8b899f484f1a328f offline under ~/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#aba4367b49750089e4e4122415a77cac43bd97bc offline under ~/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#f45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under ~/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
# ...

# %% [markdown]
# # Themes and Topics

# %% [markdown]
# ## (re)Building after the World broke down
#
# ### General Statistics on BNH[

# %%
Building='''
book book=Jesaia|Jeremia|Ezechiel|Hosea|Joel|Amos|Obadia|Jona|Micha|Nahum|Habakuk|Zephania|Haggai|Sacharia|Maleachi
   word lex=BNH[ lex_utf8 bol_dict_EN bol_dict_HebArm

'''
Building  = OT.search(Building)
OT.table(Building, start=1, end=2, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.48s 72 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=5&amp;verse=2&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Isaiah 5:2">Isaiah 5:2</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Isaiah</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl"  style="background-color: magenta;" ><span class="txtu hbo">יִּ֤בֶן </span></span></span></td></tr>
# ...

# %%
OT.export(Building, toDir='/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah', toFile='Building.tsv')

# %%
Building=pd.read_csv('/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah/Building.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
Building.head()
# Out:
#    R      S1  S2  S3   NODE1 TYPE1   book1   NODE2 TYPE2           TEXT2  \
# 0  1  Isaiah   5   2  426602  book  Jesaia  213449  word        יִּ֤בֶן
# 1  2  Isaiah   9   9  426602  book  Jesaia  215321  word       נִבְנֶ֑ה
# 2  3  Isaiah  25   2  426602  book  Jesaia  220091  word     יִבָּנֶֽה׃
# 3  4  Isaiah  44  26  426602  book  Jesaia  227843  word  תִּבָּנֶ֔ינָה
# 4  5  Isaiah  44  28  426602  book  Jesaia  227870  word     תִּבָּנֶ֔ה
#
#                 bol_dict_EN2 bol_dict_HebArm2  lex2 lex_utf82
# 0  qal: build; ni: be built;             בנה   BNH[       בנה
# 1  qal: build; ni: be built;             בנה   BNH[       בנה
# 2  qal: build; ni: be built;             בנה   BNH[       בנה
# 3  qal: build; ni: be built;             בנה   BNH[       בנה
# 4  qal: build; ni: be built;             בנה   BNH[       בנה

# %%
Building.S1.value_counts(sort=False).plot.pie(autopct='%1.0f%%', shadow=True, startangle=140)
plt.show()

# %%
BuildingJer=(Building[Building['book1']=="Jeremia"])
BuildingJer.head(5)
# Out:
#      R        S1  S2  S3   NODE1 TYPE1    book1   NODE2 TYPE2      TEXT2  \
# 12  13  Jeremiah   1  10  426603  book  Jeremia  235175  word   בְנֹ֖ות
# 13  14  Jeremiah   7  31  426603  book  Jeremia  238851  word    בָנ֞וּ
# 14  15  Jeremiah  12  16  426603  book  Jeremia  241153  word  נִבְנ֖וּ
# 15  16  Jeremiah  18   9  426603  book  Jeremia  243827  word    בְנֹ֖ת
# 16  17  Jeremiah  19   5  426603  book  Jeremia  244230  word    בָנ֞וּ
#
#                  bol_dict_EN2 bol_dict_HebArm2  lex2 lex_utf82
# 12  qal: build; ni: be built;             בנה   BNH[       בנה
# 13  qal: build; ni: be built;             בנה   BNH[       בנה
# 14  qal: build; ni: be built;             בנה   BNH[       בנה
# 15  qal: build; ni: be built;             בנה   BNH[       בנה
# 16  qal: build; ni: be built;             בנה   BNH[       בנה

# %%
BuildingJer.S2.value_counts(sort=False).plot.pie(autopct='%1.0f%%', shadow=True, startangle=140)
plt.show()

# %%
figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
BuildingJer.groupby("S2").size().plot.barh()
plt.xlabel('occurence of BNH[')
plt.ylabel('chapter')
plt.title('distribution of BNH[ in Jeremiah')
plt.show()

# %%
Building='''
book book=Jeremia
 chapter chapter
   word lex=BNH[ lex_utf8 bol_dict_EN bol_dict_HebArm

'''
Building  = OT.search(Building)
OT.table(Building, start=1, end=25, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.48s 23 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">chapter</th><th class="tf">word</th></tr>
# ...

# %%
BuildingPredObjc='''
clause
    phrase function=Pred
        word lex=BNH[ lex_utf8 bol_dict_EN bol_dict_HebArm
    phrase function=Objc
        word lex lex_utf8 bol_dict_EN bol_dict_HebArm sp=subs|nmpr
'''
BuildingPredObjc  = OT.search(BuildingPredObjc)
OT.table(BuildingPredObjc, start=1, end=2, condensed=False, colorMap={2: 'magenta'})
# Out:
#   1.57s 399 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %%
OT.export(BuildingPredObjc, toDir='/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah', toFile='BuildingPredObjc.tsv')

# %%
BuildingPredObjc=pd.read_csv('/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah/BuildingPredObjc.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
BuildingPredObjc.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   2  22  427763  clause
# 1  2  Genesis   8  20  428255  clause
# 2  3  Genesis  10  11  428376  clause
# 3  4  Genesis  10  11  428376  clause
# 4  5  Genesis  10  11  428376  clause
#
#                                                TEXT1   NODE2   TYPE2  \
# 0  וַיִּבֶן֩ יְהוָ֨ה אֱלֹהִ֧ים׀ אֶֽת־הַצֵּלָ֛ע לְ...  652182  phrase
# 1              וַיִּ֥בֶן נֹ֛חַ מִזְבֵּ֖חַ לַֽיהוָ֑ה   653746  phrase
# 2  וַיִּ֨בֶן֙ אֶת־נִ֣ינְוֵ֔ה וְאֶת־רְחֹבֹ֥ת עִ֖יר...  654122  phrase
# 3  וַיִּ֨בֶן֙ אֶת־נִ֣ינְוֵ֔ה וְאֶת־רְחֹבֹ֥ת עִ֖יר...  654122  phrase
# 4  וַיִּ֨בֶן֙ אֶת־נִ֣ינְוֵ֔ה וְאֶת־רְחֹבֹ֥ת עִ֖יר...  654122  phrase
#
#        TEXT2 function2  NODE3 TYPE3      TEXT3               bol_dict_EN3  \
# 0   יִּבֶן֩       Pred   1098  word   יִּבֶן֩   qal: build; ni: be built;
# 1   יִּ֥בֶן       Pred   3944  word   יִּ֥בֶן   qal: build; ni: be built;
# 2  יִּ֨בֶן֙       Pred   4682  word  יִּ֨בֶן֙   qal: build; ni: be built;
# ...

# %%
figure(num=None, figsize=(5, 20), dpi=80, facecolor='w', edgecolor='k')
BuildingPredObjc.bol_dict_EN5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
figure(num=None, figsize=(5, 20), dpi=80, facecolor='w', edgecolor='k')
BuildingPredObjc.bol_dict_HebArm5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
figure(num=None, figsize=(5, 20), dpi=80, facecolor='w', edgecolor='k')
BuildingPredObjc.lex5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
BuildingPredObjc='''
clause
    phrase function=Pred
        word lex=BNH[ lex_utf8 bol_dict_EN bol_dict_HebArm
    phrase function=Objc
        word lex=JHWH/ lex_utf8 bol_dict_EN bol_dict_HebArm sp=subs|nmpr
'''
BuildingPredObjc  = OT.search(BuildingPredObjc)
OT.table(BuildingPredObjc, start=1, end=2, condensed=False, colorMap={2: 'magenta'})
# Out:
#   1.29s 23 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# ### General statistcs on NV<

# %%
Planting='''
book book
   word lex=NV<[ lex_utf8 bol_dict_EN bol_dict_HebArm

'''
Planting  = OT.search(Planting)
OT.table(Planting, start=1, end=2, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.62s 58 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">book</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=8&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 2:8">Genesis 2:8</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="txtu hbo rtl"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl"  style="background-color: magenta;" ><span class="txtu hbo">יִּטַּ֞ע </span></span></span></td></tr>
# ...

# %%
OT.export(Planting, toDir='/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah', toFile='Planting.tsv')

# %%
Planting=pd.read_csv('/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah/Planting.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
Planting.head()
# Out:
#    R         S1  S2  S3   NODE1 TYPE1      book1  NODE2 TYPE2          TEXT2  \
# 0  1    Genesis   2   8  426591  book    Genesis    816  word      יִּטַּ֞ע
# 1  2    Genesis   9  20  426591  book    Genesis   4407  word      יִּטַּ֖ע
# 2  3    Genesis  21  33  426591  book    Genesis  10200  word      יִּטַּ֥ע
# 3  4     Exodus  15  17  426592  book     Exodus  37124  word  תִטָּעֵ֨מֹו֙
# 4  5  Leviticus  19  23  426593  book  Leviticus  64176  word   נְטַעְתֶּם֙
#
#                   bol_dict_EN2 bol_dict_HebArm2  lex2 lex_utf82
# 0  qal: plant; ni: be planted;             נטע   NV<[       נטע
# 1  qal: plant; ni: be planted;             נטע   NV<[       נטע
# 2  qal: plant; ni: be planted;             נטע   NV<[       נטע
# 3  qal: plant; ni: be planted;             נטע   NV<[       נטע
# 4  qal: plant; ni: be planted;             נטע   NV<[       נטע

# %%
Planting.S1.value_counts(sort=False).plot.pie(autopct='%1.0f%%', shadow=True, startangle=140)
plt.show()

# %%
PlantingPredObjc='''
clause
    phrase function=Pred
        word lex=NV<[ lex_utf8 bol_dict_EN bol_dict_HebArm
    phrase function=Objc
        word lex lex_utf8 bol_dict_EN bol_dict_HebArm sp=subs|nmpr
'''
PlantingPredObjc  = OT.search(PlantingPredObjc)
OT.table(PlantingPredObjc, start=1, end=2, condensed=False, colorMap={2: 'magenta'})
# Out:
#   1.99s 36 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %%
OT.export(PlantingPredObjc, toDir='/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah', toFile='PlantingPredObjc.tsv')

# %%
PlantingPredObjc=pd.read_csv('/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah/PlantingPredObjc.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
PlantingPredObjc.head()
# Out:
#    R         S1  S2  S3   NODE1   TYPE1  \
# 0  1    Genesis   2   8  427709  clause
# 1  2    Genesis   9  20  428331  clause
# 2  3    Genesis  21  33  429485  clause
# 3  4  Leviticus  19  23  439903  clause
# 4  5  Leviticus  19  23  439903  clause
#
#                                                TEXT1   NODE2   TYPE2  \
# 0  וַיִּטַּ֞ע יְהוָ֧ה אֱלֹהִ֛ים גַּן־בְּעֵ֖דֶן מִ...  652026  phrase
# 1                               וַיִּטַּ֖ע כָּֽרֶם׃   653976  phrase
# 2              וַיִּטַּ֥ע אֶ֖שֶׁל בִּבְאֵ֣ר שָׁ֑בַע   657520  phrase
# 3                  וּנְטַעְתֶּם֙ כָּל־עֵ֣ץ מַאֲכָ֔ל   689115  phrase
# 4                  וּנְטַעְתֶּם֙ כָּל־עֵ֣ץ מַאֲכָ֔ל   689115  phrase
#
#           TEXT2 function2  NODE3 TYPE3         TEXT3  \
# 0     יִּטַּ֞ע       Pred    816  word     יִּטַּ֞ע
# 1     יִּטַּ֖ע       Pred   4407  word     יִּטַּ֖ע
# 2     יִּטַּ֥ע       Pred  10200  word     יִּטַּ֥ע
# 3  נְטַעְתֶּם֙       Pred  64176  word  נְטַעְתֶּם֙
# ...

# %%
figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
PlantingPredObjc.bol_dict_EN5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
PlantingPredObjc.lex5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
PlantingPredObjc.bol_dict_HebArm5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

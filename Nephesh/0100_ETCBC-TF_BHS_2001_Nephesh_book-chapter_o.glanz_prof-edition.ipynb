# %% [markdown]
# # Linguistic Analysis of Nephesh
# ## Introduction
# This chapter seeks to approach the meaning of the Hebrew term Nephesh from a linguistic perspective. Thus, the primary focus will not be on its theological function, its ontological significance, or its reception history in both the NT and more generally church history. These areas of study are covered in various other chapters of this book. However, the linguistic path that I will walk in this article are is not narrow. Linguistics is a wide field of study comprising the areas of anthropological linguistics, cognitivice linguistics, socioingistics, semiotics, morphosyntax, text-linguistics, and more. The reason for why the field of linguistics is so wide is because language in both its spoken and written transports meaning by integrating sociological, anthroplogical, grammatical, and ontological aspects of human life. Without recognizing these realities it becomes difficult and at times impossible to actually understand the linguistic expression of a person or community. The importance of such a wide approach increases when a significant historical distance  is found between the present listener/reader and the linguistic object one seeks to understand.
# Some examples follow here:
# - Familia
# - Antlitz scheinen über dich
# - Garden
#
# Any translation needs to transport the meaning expressed in the source-language-texts into the target-language-text. This transportation is so complex that it can never be accomplished without shortfallings (Ortega Gasset). That is also the reason why different translators will have to choose between different translation strategies (skopos theory, funcitona theory, etc.). Consequently, a perfect translation is never possbile since the meaning of source-langauge-text can never be fully epxressed in a target-langauge-text. Any translation that seeks to expose the full meaning of the source-language-text will automatically turn into a commentary.
# Some examples follow here:
#
# In this chapter I will approach the meaning of the Hebrew word **Nephesh** by studying thee following aspects in the outlined order:
# 1. Analysis of the meaning transport found in Bible translations between the source-language word **Nephesh** and its different target-language words/phrases.
# 2. Describing some general insights from antropological linguistics that are crucial for analyzing the meaning of **Nephesh**.
# 3. Analyzing the different valence constructions with **Nephesh** as found in the TNK.
# 4. Comparing our analysis with Qumran texts.
# 5. Comparing our analysis with Septuagint texts.
#
# After these five analytic processes this chapter will conlcude by suggesting an English word/phrase that would best render the actual meaning of **Nephesh** as used in the OT.

# %% [markdown]
# ## The Dictionaries...
# It is a typical feature of languges that many of their nouns are derived from verbs. E.g. the noun "search" in "the search for gold was painful" is derived from the verb "to search". This is no different to Hebrew where many nouns, including NPC/. In the TNK the verb NPC[ appears only in its niphal form with the meaning "to breath freely"  (cf. HALOT (https://ref.ly/logosres/hal?ref=Page.p+711&off=1935). We can, however, assume that the standard qal stem meaning must be "to breath". Thus, the meaning is not just to take in air and release it again in order to sustain life. It rather refers to a particular type of breathing that could be best rendered in english as "to breath freely" or "to breath without restrictions". This is clear through the insights of comparative linguistics. The same root NPC appears in Arabic (nafasa) and Akkadian (napāšu) also with the meaning "to breath (freely)".
#
# Usually human beings are not aware of their breathing activity, it comes naturally and automatic. It is only at the moment where a sickness has caused a swelling of the throat that we realize that there is such a thing as breathing *freely*. In the sabbath related laws of Exodus we find this type of meaning:
#
# **Ex 22:12**
# “Six days you shall do your work, but on the seventh day you shall rest; that your ox and your donkey may have rest, and the son of your servant woman, and the alien, may be refreshed (וְיִנָּפֵ֥שׁ). (ESV: https://ref.ly/logosres/esv?ref=BibleESV.Ex23.12&off=0&ctx=our+olive+orchard.+%0a~12%C2%A0n%E2%80%9CSix+days+you+sh)
#
# **Ex 31:17**
# It is a sign forever between me and the people of Israel that in six days the LORD made heaven and earth, and on the seventh day he rested and was refreshed.’ ”
# (ESV: https://ref.ly/logosres/esv?ref=BibleESV.Ex31.17&off=0&ctx=a+covenant+forever.+~17%C2%A0q%EF%BB%BFIt+is+a+sign+fo)
#
# **2 Sam 16:14**
# And the king, and all the people who were with him, arrived weary at the Jordan. And there he refreshed himself (וַיִּנָּפֵ֖שׁ).
# (ESV: https://ref.ly/logosres/esv?ref=BibleESV.2Sa16.14&off=3&ctx=nd+flung%E2%80%A2%E2%80%A2+dust.+14%C2%A0~And+the+king%2c+and+al)
#
#
# It does not suprise that the nominal NPC form refers in Akkadian primarily to the throut (napištu). In Amorite it means "breath" (napš ). In both languages the concrete meaning of NPC is then used to refer to the more abstract concept of "life" (https://ref.ly/logosres/hal?ref=Page.p+711&off=3444&ctx=throat%2c+life%3b+Amor.+~naps%CC%8C+breath%2c+life+). The rational is quite obvious: when breathing comes to an end, life comes to an end. THus the most primary need and desire of existnce is breathing. NPC is therefore considered the most important organ and a symbol for vitality (see A. R. Johnson Vitality 3ff; Sander ZAW 77 (1965):329ff; D. Lys Nephesh (Paris 1959); Reicke-R. Hw. 1755f; Wolff Anthropologie 25ff; THAT 2:71ff and 72). While once can fast for some time, abstain from sex or sleep for a while, One cannot stop breathing for more than a few minutes. Thus, breathing becomes the most central desire of human existance. This desire is so fundamental that the word NPC is also used as a synonym for desire.
#
#
# NPC/ itself, then becomes a symbol for the unity and integrity of the person.

# %% [markdown]
# ## Analysis of the meaning transport found in Bible Translations

# %% [markdown]
# ## General insights from anthropological linguistics
#
# - Historical linguistics; from the concrete to the metaphorical to the abstract. Search for example...
# - Ich werde damit schwanger gehen
# - Ich hab's nicht mehr auf dem Schirm: Schirm, Bildschirm, auf dem Schirm

# %% [markdown]
# ## The different valence constructions of **Nephesh** in the TNK

# %% [markdown]
# ### The TF prelude...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %%
A = use('bhsa', hoist=globals())
# Out:
# <b title="local release">TF-app:</b> <span title="rv2.3.0=#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">C:\Users\OliverGlanz/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6=#bac4a9f5a2bbdede96ba6caea45e762fe88f88c5 offline under ~/text-fabric-data">C:\Users\OliverGlanz/text-fabric-data/etcbc/bhsa/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#1ac68e976ee4a7f23eb6bb4c6f401a033d0ec169 offline under ~/text-fabric-data">C:\Users\OliverGlanz/text-fabric-data/etcbc/phono/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2=#395dfe2cb69c261862fab9f0289e594a52121d5c offline under ~/text-fabric-data">C:\Users\OliverGlanz/text-fabric-data/etcbc/parallels/tf/c</span>
# ...

# %% [markdown]
# ### General introductory statistics
# #### *Query01* (book chapter): How often does **Nephesh** appear in the TNK

# %%
NepehshDistribution='''
word lex=NPC/
'''
NepehshDistribution  = A.search(NepehshDistribution)
A.table(NepehshDistribution, start=1, end=4, condensed=True)
# Out:
#   0.53s 754 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="section ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=20&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:20">Genesis 1:20</a></span></td><td class="tf rtl"><span class="rtl"></span></td><td class="tf rtl"><span class="rtl"><span class="plain rtl  hl" ><span class="txtu hbo">נֶ֣פֶשׁ </span></span></span></td></tr>
# ...

# %% [markdown]
# As one can see, the word **Nephesh** belongs to the most frequently used nouns (754x) in the TNK. This is also the reason why all students of introductory Hebrew will learn this word as one of the first vocabulary. For a linguist, a good distribution of a word is an optimal condition for further research and promises the possibility of convincing results.
#
# #### Whats the distribution of **Nephesh** in the TNK?

# %%
A.export(NepehshDistribution, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='NepehshDistribution.tsv')

# %%
NepehshDistribution=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/NepehshDistribution.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
NepehshDistribution.head()
# Out:
#    R       S1  S2  S3  NODE1 TYPE1     TEXT1  lex1
# 0  1  Genesis   1  20    367  word  נֶ֣פֶשׁ   NPC/
# 1  2  Genesis   1  21    391  word  נֶ֣פֶשׁ   NPC/
# 2  3  Genesis   1  24    452  word  נֶ֤פֶשׁ   NPC/
# 3  4  Genesis   1  30    643  word  נֶ֣פֶשׁ   NPC/
# 4  5  Genesis   2   7    813  word  נֶ֥פֶשׁ   NPC/

# %%
NepehshDistribution["S1"].value_counts()
# Out:
# Psalms           144
# Jeremiah          62
# Leviticus         60
# Proverbs          56
# Numbers           50
# Genesis           43
# Ezekiel           42
# Job               35
# Deuteronomy       35
# 1_Samuel          34
# Isaiah            34
# 1_Kings           23
# Exodus            17
# 2_Samuel          17
# Joshua            16
# 2_Kings           15
# Lamentations      12
# Judges            10
# Song_of_songs      7
# Ecclesiastes       7
# Esther             6
# 1_Chronicles       5
# Jonah              5
# 2_Chronicles       4
# Amos               3
# Habakkuk           3
# Micah              3
# Hosea              2
# Zechariah          2
# Ruth               1
# Haggai             1
# Name: S1, dtype: int64

# %%
figure(num=None, figsize=(5, 5), dpi=300, facecolor='w', edgecolor='k')
NepehshDistribution.groupby("S1").size().sort_values(ascending=True).plot.barh()
plt.xlabel('number of occurences of nefesh')
plt.ylabel('OT books')
plt.title('nefesh and its distribution')
plt.show()

# %% [markdown]
# The above graph shows that **Nephesh** is most frequently used in the Ketubim with Psalms (144x), Proverbs (56x), and Job (35x) leading the ranking. After that, it is the Torah (total 205x) and the prophets with particularly Jeremiah (62x) and Ezekiel (42x). Thus, the word is well distributed over all major parts of the TNK (Torah, Nephiim, Ketubim). This shows, that **Nephesh** is a genre independent word. It is used in simple narrations, in sophisticated wisdom literature, and the cult sensitive literature of the priests and prophets.
#
# From a linguistic perspetive, it is, however, important to differentiate between the various genres as each genre can transport different meanings.
# Some examples here:
#
# We will, therefore, have to anaylze per genre when we go into the details of the analysis. But at this stage we will first approach the topic from a more generalistic angle by means of queries ran over the entire TNK.
#
# In order to prepare the valence research we will have to see in what syntactical functions **Nephesh** appears (subject, predicate, objects, etc.).

# %% [markdown]
# ### *Query04* (book chapter)

# %%
NepehshPhraseFunctions='''
clause kind*
    phrase function*
        word lex=NPC/
'''
NepehshPhraseFunctions  = A.search(NepehshPhraseFunctions)
A.table(NepehshPhraseFunctions, start=1, end=2, condensed=True)
# Out:
#   1.00s 754 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %%
A.export(NepehshPhraseFunctions, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='NepehshPhraseFunctions.tsv')

# %%
NepehshPhraseFunctions=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/NepehshPhraseFunctions.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
NepehshPhraseFunctions.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   1  20  427621  clause
# 1  2  Genesis   1  21  427623  clause
# 2  3  Genesis   1  24  427640  clause
# 3  4  Genesis   1  30  427671  clause
# 4  5  Genesis   2   7  427702  clause
#
#                                                TEXT1 kind1   NODE2   TYPE2  \
# 0     יִשְׁרְצ֣וּ הַמַּ֔יִם שֶׁ֖רֶץ נֶ֣פֶשׁ חַיָּ֑ה     VC  651750  phrase
# 1  וַיִּבְרָ֣א אֱלֹהִ֔ים אֶת־הַתַּנִּינִ֖ם הַגְּד...    VC  651758  phrase
# 2      תֹּוצֵ֨א הָאָ֜רֶץ נֶ֤פֶשׁ חַיָּה֙ לְמִינָ֔הּ     VC  651802  phrase
# 3                      אֲשֶׁר־בֹּו֙ נֶ֣פֶשׁ חַיָּ֔ה     NC  651894  phrase
# 4            וַֽיְהִ֥י הָֽאָדָ֖ם לְנֶ֥פֶשׁ חַיָּֽה׃     VC  651993  phrase
#
#                                                TEXT2 function2  NODE3 TYPE3  \
# 0                           שֶׁ֖רֶץ נֶ֣פֶשׁ חַיָּ֑ה       Objc    367  word
# 1  אֶת־הַתַּנִּינִ֖ם הַגְּדֹלִ֑ים וְאֵ֣ת כָּל־נֶ֣...      Objc    391  word
# ...

# %%
NepehshPhraseFunctions["function2"].value_counts()
# Out:
# Objc    262
# Subj    233
# Cmpl    110
# Adju     68
# PreC     35
# Frnt     30
# Voct     13
# Modi      2
# PrAd      1
# Name: function2, dtype: int64

# %%
NepehshPhraseFunctionsreduced = NepehshPhraseFunctions.groupby("function2").filter(lambda x: len(x) >=100)
NepehshPhraseFunctionsreduced["function2"].value_counts()
# Out:
# Objc    262
# Subj    233
# Cmpl    110
# Name: function2, dtype: int64

# %%
figure(num=None, figsize=(5, 2), dpi=300, facecolor='w', edgecolor='k')
NepehshPhraseFunctionsreduced.groupby("function2").size().sort_values(ascending=True).plot.barh()
plt.xlabel('number of occurences in OT')
plt.ylabel('phrase function')
plt.title('most frequent phrase functions of nefesh')
plt.show()

# %%
NepehshPhraseFunctions["kind1"].value_counts()
# Out:
# VC    604
# NC     79
# WP     71
# Name: kind1, dtype: int64

# %% [markdown]
# ## Active Finte Verbal Forms in clauses with NPC/

# %% [markdown]
# As we can see most of the time **Nephesh** is either a syntactical object (Objc, 262x), subject (Subj, 233x), or indirect object (Cmpl, 110x), and most o fthe time it appears in verbal clauses (VC). Since we have a strong distribution we can simplify our valence analysis by restricting ourselves to the verbal clauses. Within the context of verbal clauses we further simplify the datapool by looking only at those clauses that have finite verbal forms (perf|impf|wayq|impv).

# %% [markdown]
# ### *Query02* (book chapter)

# %%
NepheshValenceVCFiniteVerbs='''
clause kind=VC
    phrase function=Subj
        word lex=NPC/
    phrase function=Pred|PreO|PreS
        word sp=verb vt=perf|impf|wayq|impv vs=qal|piel|hit|hif lex_utf8* lex* freq_lex*
'''
NepheshValenceVCFiniteVerbs  = A.search(NepheshValenceVCFiniteVerbs)
A.table(NepheshValenceVCFiniteVerbs, start=1, end=10, condensed=True)
# Out:
#   2.77s 145 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">phrase</th></tr>
# ...

# %%
A.export(NepheshValenceVCFiniteVerbs, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='NepheshValenceVCFiniteVerbs.tsv')

# %%
NepheshValenceVCFiniteVerbs=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/NepheshValenceVCFiniteVerbs.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
NepheshValenceVCFiniteVerbs.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1                                   TEXT1  \
# 0  1  Genesis  12  13  428559  clause     וְחָיְתָ֥ה נַפְשִׁ֖י בִּגְלָלֵֽךְ׃
# 1  2  Genesis  19  20  429212  clause                    וּתְחִ֥י נַפְשִֽׁי׃
# 2  3  Genesis  27   4  430232  clause      בַּעֲב֛וּר תְּבָרֶכְךָ֥ נַפְשִׁ֖י
# 3  4  Genesis  27  19  430297  clause  בַּעֲב֖וּר תְּבָרֲכַ֥נִּי נַפְשֶֽׁךָ׃
# 4  5  Genesis  27  25  430325  clause       לְמַ֥עַן תְּבָֽרֶכְךָ֖ נַפְשִׁ֑י
#
#   kind1   NODE2   TYPE2         TEXT2 function2  NODE3 TYPE3         TEXT3  \
# 0    VC  654679  phrase    נַפְשִׁ֖י       Subj   5742  word    נַפְשִׁ֖י
# 1    VC  656641  phrase   נַפְשִֽׁי׃       Subj   8890  word   נַפְשִֽׁי׃
# 2    VC  659712  phrase    נַפְשִׁ֖י       Subj  13700  word    נַפְשִׁ֖י
# 3    VC  659886  phrase  נַפְשֶֽׁךָ׃       Subj  13954  word  נַפְשֶֽׁךָ׃
# 4    VC  659956  phrase    נַפְשִׁ֑י       Subj  14043  word    נַפְשִׁ֑י
#
# ...

# %%
NepheshValenceVCFiniteVerbs["lex5"].nunique()
# Out:
# 79

# %% [markdown]
# ### *Results01* (book chapter)

# %%
NepheshValenceVCFiniteVerbs["lex_utf85"].value_counts()
# Out:
# היה    8
# אוה    8
# חיה    8
# יקר    5
# נקע    5
#       ..
# הלך    1
# אבל    1
# עטף    1
# קוה    1
# יצא    1
# Name: lex_utf85, Length: 79, dtype: int64

# %%
NepheshValenceVCFiniteVerbs[
     (NepheshValenceVCFiniteVerbs["lex5"] == 'CWB[') 
    | (NepheshValenceVCFiniteVerbs["lex5"] == 'HLK[') 
    | (NepheshValenceVCFiniteVerbs["lex5"] == 'BW>[') 
    | (NepheshValenceVCFiniteVerbs["lex5"] == 'JY>[')
                            ].head(10)
# Out:
#        R             S1   S2  S3   NODE1   TYPE1  \
# 8      9        Genesis   49   6  433331  clause
# 41    42        1_Kings   17  21  463685  clause
# 42    43        1_Kings   17  22  463687  clause
# 53    54         Isaiah   46   2  472047  clause
# 105  106         Psalms  105  18  495462  clause
# 139  140  Song_of_songs    5   6  503541  clause
#
#                                                  TEXT1 kind1   NODE2   TYPE2  \
# 8                     בְּסֹדָם֙ אַל־תָּבֹ֣א נַפְשִׁ֔י     VC  668938  phrase
# 41   תָּ֥שָׁב נָ֛א נֶֽפֶשׁ־הַיֶּ֥לֶד הַזֶּ֖ה עַל־קִ...    VC  761111  phrase
# 42         וַתָּ֧שָׁב נֶֽפֶשׁ־הַיֶּ֛לֶד עַל־קִרְבֹּ֖ו     VC  761119  phrase
# 53                וְנַפְשָׁ֖ם בַּשְּׁבִ֥י הָלָֽכָה׃ ס     VC  784580  phrase
# 105                     בַּ֝רְזֶ֗ל בָּ֣אָה נַפְשֹֽׁו׃     VC  848027  phrase
# 139                               נַפְשִׁי֙ יָֽצְאָ֣ה     VC  869407  phrase
#
#                           TEXT2 function2   NODE3 TYPE3        TEXT3  lex3  \
# ...

# %%
NepheshValenceVCFiniteVerbsMovingVerbs = NepheshValenceVCFiniteVerbs[
          (NepheshValenceVCFiniteVerbs['lex5'] == 'CWB[') 
        | (NepheshValenceVCFiniteVerbs['lex5'] == 'HLK[')      
        | (NepheshValenceVCFiniteVerbs['lex5'] == 'BW>[')
        | (NepheshValenceVCFiniteVerbs['lex5'] == 'JY>[')
       ]

# %%
NepheshValenceVCFiniteVerbsMovingVerbs["lex_utf85"].value_counts()
# Out:
# שׁוב    2
# בוא     2
# הלך     1
# יצא     1
# Name: lex_utf85, dtype: int64

# %%
NepheshValenceVCFiniteVerbsMovingVerbs.sort_values(['lex5', 'function4'], ascending=[False,True]).head(10)
# Out:
#        R             S1   S2  S3   NODE1   TYPE1  \
# 139  140  Song_of_songs    5   6  503541  clause
# 53    54         Isaiah   46   2  472047  clause
# 41    42        1_Kings   17  21  463685  clause
# 42    43        1_Kings   17  22  463687  clause
# 8      9        Genesis   49   6  433331  clause
# 105  106         Psalms  105  18  495462  clause
#
#                                                  TEXT1 kind1   NODE2   TYPE2  \
# 139                               נַפְשִׁי֙ יָֽצְאָ֣ה     VC  869407  phrase
# 53                וְנַפְשָׁ֖ם בַּשְּׁבִ֥י הָלָֽכָה׃ ס     VC  784580  phrase
# 41   תָּ֥שָׁב נָ֛א נֶֽפֶשׁ־הַיֶּ֥לֶד הַזֶּ֖ה עַל־קִ...    VC  761111  phrase
# 42         וַתָּ֧שָׁב נֶֽפֶשׁ־הַיֶּ֛לֶד עַל־קִרְבֹּ֖ו     VC  761119  phrase
# 8                     בְּסֹדָם֙ אַל־תָּבֹ֣א נַפְשִׁ֔י     VC  668938  phrase
# 105                     בַּ֝רְזֶ֗ל בָּ֣אָה נַפְשֹֽׁו׃     VC  848027  phrase
#
#                           TEXT2 function2   NODE3 TYPE3        TEXT3  lex3  \
# ...

# %% [markdown]
# ### **נֶפֶשׁ** and verbs of movement (lex=HLX[ | JY>[ | CWB[ | BW>[)
#
# In this query I want to see whether the soul can move out or move into bodies since this is the way how the socratic Greek and Latin text describe the relation of the sould to the body.
#
# In order to reduce the data but sill generate representative results I am looking only within verbal clauses (typ=VC) that contain finite verbal forms (perf,impf,wayq,impv) excluding participles and infinitive forms.

# %%
MovingNPCValence1='''
clause kind=VC
    phrase function=Subj
        word lex=NPC/
    phrase function=Pred|PreO|PreS
        word sp=verb lex=HLK[|JY>[|CWB[|BW>[ vt=perf|impf|wayq|impv lex_utf8* freq_lex* vs*

'''
MovingNPCValence1  = A.search(MovingNPCValence1)
A.table(MovingNPCValence1, start=1, end=10, condensed=True)
# Out:
#   1.85s 6 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">phrase</th><th class="tf">clause</th></tr>
# ...

# %% [markdown]
# ### *Query03* (book chapter)

# %%
MovingNPCValence3='''
clause kind=VC
    phrase function=Objc
        word lex=NPC/
    phrase function=Pred|PreS|PreO
        word sp=verb vt=perf|impf|wayq|impv vs=qal|piel|hit|hif lex* lex_utf8* freq_lex*

'''
MovingNPCValence3  = A.search(MovingNPCValence3)
A.table(MovingNPCValence3, start=1, end=11, condensed=True)
# Out:
#   2.76s 180 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.export(MovingNPCValence3, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='MovingNPCValence3.tsv')

# %%
MovingNPCValence3=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/MovingNPCValence3.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
MovingNPCValence3.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   1  20  427621  clause
# 1  2  Genesis   1  21  427623  clause
# 2  3  Genesis   1  24  427640  clause
# 3  4  Genesis   2  19  427749  clause
# 4  5  Genesis   9   4  428273  clause
#
#                                                TEXT1 kind1   NODE2   TYPE2  \
# 0     יִשְׁרְצ֣וּ הַמַּ֔יִם שֶׁ֖רֶץ נֶ֣פֶשׁ חַיָּ֑ה     VC  651750  phrase
# 1  וַיִּבְרָ֣א אֱלֹהִ֔ים אֶת־הַתַּנִּינִ֖ם הַגְּד...    VC  651758  phrase
# 2      תֹּוצֵ֨א הָאָ֜רֶץ נֶ֤פֶשׁ חַיָּה֙ לְמִינָ֔הּ     VC  651802  phrase
# 3    אֲשֶׁ֨ר יִקְרָא־לֹ֧ו הָֽאָדָ֛ם נֶ֥פֶשׁ חַיָּ֖ה     VC  652123  phrase
# 4  אַךְ־בָּשָׂ֕ר בְּנַפְשֹׁ֥ו דָמֹ֖ו לֹ֥א תֹאכֵֽל...    VC  653791  phrase
#
#                                                TEXT2 function2  NODE3 TYPE3  \
# 0                           שֶׁ֖רֶץ נֶ֣פֶשׁ חַיָּ֑ה       Objc    367  word
# 1  אֶת־הַתַּנִּינִ֖ם הַגְּדֹלִ֑ים וְאֵ֣ת כָּל־נֶ֣...      Objc    391  word
# ...

# %%
MovingNPCValence3["lex5"].nunique()
# Out:
# 72

# %%
NepehshObj1MovementVerbs = MovingNPCValence3[
          (MovingNPCValence3['lex5'] == 'CWB[') 
        | (MovingNPCValence3['lex5'] == 'HLK[')      
        | (MovingNPCValence3['lex5'] == 'BW>[')
        | (MovingNPCValence3['lex5'] == 'JY>[')
       ].head()

# %%
NepehshObj1MovementVerbs["lex_utf85"].value_counts()
# Out:
# יצא     3
# שׁוב    2
# Name: lex_utf85, dtype: int64

# %%
NepehshObj1MovementVerbs.sort_values(['lex3', 'function4'], ascending=[False,True]).head(10)
# Out:
#        R       S1   S2  S3   NODE1   TYPE1  \
# 2      3  Genesis    1  24  427640  clause
# 113  114   Psalms   23   3  491184  clause
# 121  122   Psalms   35  17  491782  clause
# 150  151   Psalms  142   8  497188  clause
# 153  154   Psalms  143  11  497231  clause
#
#                                               TEXT1 kind1   NODE2   TYPE2  \
# 2     תֹּוצֵ֨א הָאָ֜רֶץ נֶ֤פֶשׁ חַיָּה֙ לְמִינָ֔הּ     VC  651802  phrase
# 113                           נַפְשִׁ֥י יְשֹׁובֵ֑ב     VC  837667  phrase
# 121             הָשִׁ֣יבָה נַ֭פְשִׁי מִשֹּׁאֵיהֶ֑ם     VC  839109  phrase
# 150            הֹ֘וצִ֤יאָה מִמַּסְגֵּ֨ר׀ נַפְשִׁי֮     VC  852320  phrase
# 153  בְּצִדְקָתְךָ֓׀ תֹוצִ֖יא מִצָּרָ֣ה נַפְשִֽׁי׃     VC  852425  phrase
#
#                 TEXT2 function2   NODE3 TYPE3        TEXT3  lex3   NODE4  \
# 2    נֶ֤פֶשׁ חַיָּה֙       Objc     452  word     נֶ֤פֶשׁ   NPC/  651800
# 113        נַפְשִׁ֥י       Objc  313909  word   נַפְשִׁ֥י   NPC/  837668
# ...

# %% [markdown]
# ### *Query03b* (book chapter)

# %%
NPCmovinginandout='''
clause
    phrase function=Pred|PreC
        word sp=verb lex=HLX[|JY>[|CWB[ lex_utf8* freq_lex* vt* vs*
    phrase function=Subj
        word lex=NPC/
'''
NPCmovinginandout  = A.search(NPCmovinginandout)
A.table(NPCmovinginandout, start=1, end=4, condensed=True)
# Out:
#   1.88s 4 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">phrase</th></tr>
# ...

# %% [markdown]
# ### **Nephesh** as a syntactical subject in Verbal Clauses
# In our first query we seek to find all verbal predicates that **Nephesh** receives in VCs. Thus, we want to catalogue the activities of **Nephesh** in order to better understand the nature of **Nephesh** as an acting entity.

# %%
NepehshSub1='''
clause kind=VC
    phrase function=Subj
        word lex=NPC/
    phrase function=Pred|PreO|PreC
        word sp=verb lex* lex_utf8* freq_lex* vt* vs*
'''
NepehshSub1  = A.search(NepehshSub1)
A.table(NepehshSub1, start=1, end=4, condensed=True)
# Out:
#   2.76s 184 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">phrase</th></tr>
# ...

# %%
A.export(NepehshSub1, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='NepehshSub1.tsv')

# %%
NepehshSub1=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/NepehshSub1.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
NepehshSub1.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis  12  13  428559  clause
# 1  2  Genesis  17  14  428902  clause
# 2  3  Genesis  19  20  429212  clause
# 3  4  Genesis  27   4  430232  clause
# 4  5  Genesis  27  19  430297  clause
#
#                                           TEXT1 kind1   NODE2   TYPE2  \
# 0           וְחָיְתָ֥ה נַפְשִׁ֖י בִּגְלָלֵֽךְ׃     VC  654679  phrase
# 1  וְנִכְרְתָ֛ה הַנֶּ֥פֶשׁ הַהִ֖וא מֵעַמֶּ֑יהָ     VC  655740  phrase
# 2                          וּתְחִ֥י נַפְשִֽׁי׃     VC  656641  phrase
# 3            בַּעֲב֛וּר תְּבָרֶכְךָ֥ נַפְשִׁ֖י     VC  659712  phrase
# 4        בַּעֲב֖וּר תְּבָרֲכַ֥נִּי נַפְשֶֽׁךָ׃     VC  659886  phrase
#
#                  TEXT2 function2  NODE3 TYPE3         TEXT3  lex3   NODE4  \
# 0           נַפְשִׁ֖י       Subj   5742  word    נַפְשִׁ֖י   NPC/  654678
# 1  הַנֶּ֥פֶשׁ הַהִ֖וא       Subj   7555  word     נֶּ֥פֶשׁ   NPC/  655739
# 2          נַפְשִֽׁי׃       Subj   8890  word   נַפְשִֽׁי׃   NPC/  656640
# ...

# %%
NepehshSub1["vs5"].value_counts()
# Out:
# qal     121
# nif      25
# piel     22
# hit      12
# pual      3
# hif       1
# Name: vs5, dtype: int64

# %%
NepehshSub1[
          (NepehshSub1['vs5'] == 'qal') 
        | (NepehshSub1['vs5'] == 'piel')    
        | (NepehshSub1['vs5'] == 'hit')
        | (NepehshSub1['vs5'] == 'hif')    
       ].sort_values(['lex3', 'function4'], ascending=[False,True]).head()
# Out:
#        R         S1   S2  S3   NODE1   TYPE1  \
# 11    12    Genesis   44  30  432837  clause
# 58    59   1_Samuel   25  29  457278  clause
# 110  111  Zechariah   11   8  489691  clause
# 149  150     Psalms  139  14  497045  clause
# 3      4    Genesis   27   4  430232  clause
#
#                                                  TEXT1 kind1   NODE2   TYPE2  \
# 11                וְנַפְשֹׁ֖ו קְשׁוּרָ֥ה בְנַפְשֹֽׁו׃     VC  667437  phrase
# 58   וְֽהָיְתָה֩ נֶ֨פֶשׁ אֲדֹנִ֜י צְרוּרָ֣ה׀ בִּצְר...    VC  741701  phrase
# 110                   וְגַם־נַפְשָׁ֖ם בָּחֲלָ֥ה בִֽי׃     VC  833813  phrase
# 149                     וְ֝נַפְשִׁ֗י יֹדַ֥עַת מְאֹֽד׃     VC  851998  phrase
# 3                   בַּעֲב֛וּר תְּבָרֶכְךָ֥ נַפְשִׁ֖י     VC  659712  phrase
#
#                  TEXT2 function2   NODE3 TYPE3       TEXT3  lex3   NODE4  \
# 11          נַפְשֹׁ֖ו       Subj   25370  word  נַפְשֹׁ֖ו   NPC/  667438
# 58   נֶ֨פֶשׁ אֲדֹנִ֜י       Subj  157169  word    נֶ֨פֶשׁ   NPC/  741702
# ...

# %% [markdown]
# ### *Results02* (book chapter)

# %%
NepehshSub1["lex_utf85"].value_counts().head()
# Out:
# כרת    16
# היה     8
# אוה     8
# חיה     8
# יקר     5
# Name: lex_utf85, dtype: int64

# %%
NepehshSub1active = NepehshSub1[
          (NepehshSub1['vs5'] == 'qal') 
        | (NepehshSub1['vs5'] == 'piel')    
        | (NepehshSub1['vs5'] == 'hit')
        | (NepehshSub1['vs5'] == 'hif')    
       ].sort_values(['lex3', 'function4'], ascending=[False,True])

# %%
NepehshSub1active["lex_utf85"].value_counts().head(100)
# Out:
# חיה     8
# אוה     8
# היה     8
# געל     5
# שׂבע    5
#        ..
# עגם     1
# קוה     1
# מוג     1
# ערג     1
# אבל     1
# Name: lex_utf85, Length: 85, dtype: int64

# %%
NepehshSub1active["lex5"].value_counts().head(10)
# Out:
# >WH[    8
# HJH[    8
# XJH[    8
# NQ<[    5
# JQR[    5
# FB<[    5
# G<L[    5
# QYR[    4
# BRK[    4
# >HB[    4
# Name: lex5, dtype: int64

# %%
NepehshSub1active["lex5"].nunique()
# Out:
# 85

# %%
NepehshSub1activeMovement = NepehshSub1active[
          (NepehshSub1active['lex5'] == 'CWB[') 
        | (NepehshSub1active['lex5'] == 'HLK[')      
        | (NepehshSub1active['lex5'] == 'BW>[')
        | (NepehshSub1active['lex5'] == 'JY>[')
       ]

# %%
NepehshSub1activeMovement["lex_utf85"].value_counts().head(100)
# Out:
# הלך     2
# שׁוב    2
# בוא     2
# יצא     2
# Name: lex_utf85, dtype: int64

# %%
NepehshSub1activeMovement.sort_values(["freq_lex5"], ascending=False)
# Out:
#        R             S1   S2  S3   NODE1   TYPE1  \
# 12    13        Genesis   49   6  433331  clause
# 134  135         Psalms  105  18  495462  clause
# 76    77         Isaiah   46   2  472047  clause
# 178  179   Ecclesiastes    6   9  504272  clause
# 10    11        Genesis   35  18  431505  clause
# 174  175  Song_of_songs    5   6  503541  clause
# 64    65        1_Kings   17  21  463685  clause
# 65    66        1_Kings   17  22  463687  clause
#
#                                                  TEXT1 kind1   NODE2   TYPE2  \
# 12                    בְּסֹדָם֙ אַל־תָּבֹ֣א נַפְשִׁ֔י     VC  668938  phrase
# 134                     בַּ֝רְזֶ֗ל בָּ֣אָה נַפְשֹֽׁו׃     VC  848027  phrase
# 76                וְנַפְשָׁ֖ם בַּשְּׁבִ֥י הָלָֽכָה׃ ס     VC  784580  phrase
# 178                                 מֵֽהֲלָךְ־נָ֑פֶשׁ     VC  871245  phrase
# 10                                בְּצֵ֤את נַפְשָׁהּ֙     VC  663517  phrase
# ...

# %%
NepehshSub1activeMovement["lex5"].value_counts()
# Out:
# HLK[    2
# JY>[    2
# CWB[    2
# BW>[    2
# Name: lex5, dtype: int64

# %%
NepehshSub1.sort_values(["freq_lex5"], ascending=False)
# Out:
#        R            S1   S2  S3   NODE1   TYPE1  \
# 182  183  Lamentations    3  24  505031  clause
# 55    56      1_Samuel   20   4  456482  clause
# 92    93      Jeremiah   21   9  476200  clause
# 97    98      Jeremiah   39  18  478357  clause
# 94    95      Jeremiah   38   2  478167  clause
# ..   ...           ...  ...  ..     ...     ...
# 140  141        Psalms  119  28  496214  clause
# 138  139        Psalms  119  20  496197  clause
# 157  158           Job   30  25  499494  clause
# 74    75        Isaiah   15   4  469302  clause
# 110  111     Zechariah   11   8  489691  clause
#
#                                                  TEXT1 kind1   NODE2   TYPE2  \
# 182                                אָמְרָ֣ה נַפְשִׁ֔י     VC  873366  phrase
# 55                            מַה־תֹּאמַ֥ר נַפְשְׁךָ֖     VC  739272  phrase
# 92              וְהָֽיְתָה־לֹּ֥ו נַפְשֹׁ֖ו לְשָׁלָֽל׃     VC  795845  phrase
# ...

# %% [markdown]
# A vast variety of actions can be performed by **Nephesh**. A total of 94 different verbs are attached to **Nephesh** has a subject. While there are a few verbs that appear more frequently, Nephesh does not seem to have a particular verb it prefers to use. This is clear form the still low distribution of even the most frequently occuring verbs:
#
#
# lexeme|occurence
# ------|---------
# כרת  |    16
# חיה  |     8
# היה  |     8
# אוה  |     8
# שׂבע  |     5
# געל  |     5
# יקר  |     5
# נקע  |     5
# קצר  |     4
# ברך  |     4
# אהב  |     4
# נקם  |     3
# מות  |     3
# דבק  |     3
# כלה  |     3
#
#
#
# Almost half of the verbs appear just  once or twice in the entire TNK (most of these hapax legomena appear in the Psalms). These verbs should therefore not be used as primary means to establish a better understanding of Nepesh as scholars have difficulty to establish their exact meaning due to their rare appearance.
#
# When we analyse the more frequently used words we come to the following conlcusions:

# %%
NepehshSub1activeVS='''
clause kind=VC
    phrase function=Subj
        word lex=NPC/
    phrase function=Pred|PreO|PreC
        word sp=verb lex* lex_utf8* freq_lex* vt* vs*
'''
NepehshSub1activeVS  = A.search(NepehshSub1activeVS)
A.table(NepehshSub1activeVS, start=1, end=4, condensed=True)
# Out:
#   2.82s 184 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">phrase</th></tr>
# ...

# %%
A.export(NepehshSub1activeVS, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='NepehshSub1activeVS.tsv')

# %%
NepehshSub1activeVS=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/NepehshSub1activeVS.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
NepehshSub1activeVS.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis  12  13  428559  clause
# 1  2  Genesis  17  14  428902  clause
# 2  3  Genesis  19  20  429212  clause
# 3  4  Genesis  27   4  430232  clause
# 4  5  Genesis  27  19  430297  clause
#
#                                           TEXT1 kind1   NODE2   TYPE2  \
# 0           וְחָיְתָ֥ה נַפְשִׁ֖י בִּגְלָלֵֽךְ׃     VC  654679  phrase
# 1  וְנִכְרְתָ֛ה הַנֶּ֥פֶשׁ הַהִ֖וא מֵעַמֶּ֑יהָ     VC  655740  phrase
# 2                          וּתְחִ֥י נַפְשִֽׁי׃     VC  656641  phrase
# 3            בַּעֲב֛וּר תְּבָרֶכְךָ֥ נַפְשִׁ֖י     VC  659712  phrase
# 4        בַּעֲב֖וּר תְּבָרֲכַ֥נִּי נַפְשֶֽׁךָ׃     VC  659886  phrase
#
#                  TEXT2 function2  NODE3 TYPE3         TEXT3  lex3   NODE4  \
# 0           נַפְשִׁ֖י       Subj   5742  word    נַפְשִׁ֖י   NPC/  654678
# 1  הַנֶּ֥פֶשׁ הַהִ֖וא       Subj   7555  word     נֶּ֥פֶשׁ   NPC/  655739
# 2          נַפְשִֽׁי׃       Subj   8890  word   נַפְשִֽׁי׃   NPC/  656640
# ...

# %%
NepehshSub1["lex_utf85"].value_counts()
# Out:
# כרת     16
# היה      8
# אוה      8
# חיה      8
# יקר      5
#         ..
# קוט      1
# לין      1
# שׁמר     1
# ידע      1
# קוה      1
# Name: lex_utf85, Length: 94, dtype: int64

# %% [markdown]
# #### KRT[
# KRT[ appears with Nepesh as subject only in the Niphal. Since the niphal activate the passive meaning of KRT[ Nephesh becomes the logical object and should therfore be categorized under "Nephesh as object". In order to better understand the construction one needs to better grasp the actual valence of KRT[:

# %%
KRTValence='''
clause kind=VC
    phrase function=Pred|PreC
        word sp=verb lex=KRT[ lex_utf8* freq_lex* vt* vs*
    phrase function=Subj|Objc|Cmpl
        word lex*
'''
KRTValence  = A.search(KRTValence)
A.table(KRTValence, start=1, end=4, condensed=True)
# Out:
#   2.36s 985 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">phrase</th><th class="tf">phrase</th></tr>
# ...

# %%
A.export(KRTValence, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='KRTValence.tsv')

# %%
KRTValence=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/KRTValence.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
KRTValence.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   9  11  428293  clause
# 1  2  Genesis   9  11  428293  clause
# 2  3  Genesis   9  11  428293  clause
# 3  4  Genesis   9  11  428293  clause
# 4  5  Genesis   9  11  428293  clause
#
#                                                TEXT1 kind1   NODE2   TYPE2  \
# 0  וְלֹֽא־יִכָּרֵ֧ת כָּל־בָּשָׂ֛ר עֹ֖וד מִמֵּ֣י ה...    VC  653848  phrase
# 1  וְלֹֽא־יִכָּרֵ֧ת כָּל־בָּשָׂ֛ר עֹ֖וד מִמֵּ֣י ה...    VC  653848  phrase
# 2  וְלֹֽא־יִכָּרֵ֧ת כָּל־בָּשָׂ֛ר עֹ֖וד מִמֵּ֣י ה...    VC  653848  phrase
# 3  וְלֹֽא־יִכָּרֵ֧ת כָּל־בָּשָׂ֛ר עֹ֖וד מִמֵּ֣י ה...    VC  653848  phrase
# 4  וְלֹֽא־יִכָּרֵ֧ת כָּל־בָּשָׂ֛ר עֹ֖וד מִמֵּ֣י ה...    VC  653848  phrase
#
#         TEXT2 function2  NODE3 TYPE3       TEXT3  freq_lex3  lex3 lex_utf83  \
# 0  יִכָּרֵ֧ת       Pred   4224  word  יִכָּרֵ֧ת         288  KRT[       כרת
# 1  יִכָּרֵ֧ת       Pred   4224  word  יִכָּרֵ֧ת         288  KRT[       כרת
# ...

# %%
KRTValence["function4"].value_counts()
# Out:
# Cmpl    427
# Objc    343
# Subj    215
# Name: function4, dtype: int64

# %% [markdown]
# In all cases the Nepesh is being destroyed or cut off. The formulation is used as an idiomatic expression for "being killed". This  becomes clear through the fact that generaly humans can be cut off. We find both the formulation >JC/ being cut off (cf. 1 Kgs 2:4) as well as NPC/ being cut off.

# %% [markdown]
# #### XJH[
# After KRT[ the verbs XJH[, HJH[, and >WH[ appear each 8x. While the Nephesh can be cut off, i.e. a human being dies, the Nephesh can also be alive. Most of the time XJH[ appears as a jussive renering the meaning "the soul shall live" (e.g. Gen 19:20, 1 Kgs 20:32, Isa 55:3, Jer 38:20, Psa 119:175). Thus, the wish for a soul to live assumes that the soul is vulnerable and threatened by death.

# %% [markdown]
# #### HJH[
# The impression of Nepesh possibly dying or surviving is also present in its valence construction with HJH[. 1 Sam 25:29, describes how one can seek after (BKC[) one soul or sling away (QL<[) a soul as an idiomatic expression for "killing". As contrast to BKC[ and QL<[ the soul can "be"(HJH[), i.e. remain its existance.
# The two appearances of the construction in 1 Kings appear in the same context: The nephesh of one person can be used as the revenage for the lost (dead) nephesh of another person.
# 3 of the 4 construction with HJH[ in Jeremiah continue the impression: Here the Nephesh is at risk to perish but the Lord promises the possibility of naked survival considering the fall of Jerusalem. While everything will get lost there is a chance that the Nephesh could survive (Jer 21:9, 38:2, 39:18).

# %% [markdown]
# #### >WH[
# In contrast to the other three verbs, the valance with >WH[ expresses genrally a wish for well tasting food. At the core it describes taste, as a primary food related sensation. However, derived from this one can also have a taste for power or control.... That the primary meaning of the construction has to do with food becomes clear when one look at all constructions with >WH[. In most of the cases, food is the object of longing/craving for: Num 11:4, 34; 2 Sam 23:15; Prov 23:3, 6: 1 Chr 11:17. From this basic meaning other uses of >WH[ are developed. For example to long of riches, etc.
#
# WHen one does not only look at syntactical subject-predicate relations one realizes that the default construction of >WH[ comes with NPC/. Thus, there, where NPC/ is missing it is replaced by a person (e.g. David). Form this, one can conclude that NPC/ can stand for a person in tota.

# %% [markdown]
# #### words of gusto
# In addition to the frequently used >WH[ constructions a comparison with other verbs that have NPC/ as subject creates a fuller image of the Sachverhalt.
# 1. a>KL[: The NPC can eat.
# 2. FB<[: The NPC/ can be sated (gesaettigt). The verb has as primary function the idea of food saturation. E.g. Ex 16:8, 12; jer 44:17. That is the reason why it is often preceded by the word >KL[ (e.g. Lev 26:26, Deut 6:11, 8:10, 12, 26:12, Isa 44:16, Hos 4:10). From this primary food related meaning other meanings like being staurated with peace and meaning (see here particularly Isa 58:11, 66:11 who makes the link with food explicit, but others do not establsihe that link: Jer 31:14, ).
# 3. R<B[ if the NPC/ can eat and can be satisfied with food it becomes clear that it an also starve when it does not receive enough food. Although its use in Prov 19:15 is metaphorical as NPC/ is not starving from food but from meaning the primary usage of R<P[ is food related (Gen 41:55, Isa 9:19, Jer 42:14). Dan 8:3 makes this connection explicit.
# 4. YM>[ is the partner word of R<P[ as it expresses thirst in contrast to hunger. Obviously NPC/ can drink and eat when it can be thirsty and hungry. Both appearance in the Psalms (Psa 42:3, 63:2), however, do not have fluids in mind but God as the object that can still the thirsty NPC/. Thus, we can see again, that the Nephesh appears both as a biological organ that can eat and drink but is also used as an entity that metaphorically eats and drinks God and wisdom.
# 4. XPY[, RYH[ These words express satisfaction, fullfillment, and saturation. This does not come as a surprise considering the previous findings.
#
# We have to make a distinction between NPC/ as a biological organ and NPC/ as a symbol for human existance. While some verbs relate best to the organ others relate best to metaphor for human existance.

# %%
NPCEats2='''
clause
            word lex=NPC/
<: clause
            word lex=L
            <: word sp=verb lex=>KL[ lex_utf8* freq_lex* vt* vs*

'''
NPCEats2  = A.search(NPCEats2)
A.table(NPCEats2, start=1, end=4, condensed=True)
# Out:
#   1.60s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th><th class="tf">clause</th></tr>
# ...

# %% [markdown]
# ### *Query04* (book chapter)

# %%
ObjectOfBeingSated='''
clause
    phrase function=Pred|PredC
        word lex=FB<[
    phrase function=Objc

'''
ObjectOfBeingSated  = A.search(ObjectOfBeingSated)
A.table(ObjectOfBeingSated, start=1, end=7, condensed=False)
# Out:
#   0.90s 32 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th></tr>
# ...

# %%
NPCBeingDisgusted1='''
clause
    phrase function=Pred
        word lex=NQ<[
    phrase function=Subj
        word lex*

'''
NPCBeingDisgusted1  = A.search(NPCBeingDisgusted1)
A.table(NPCBeingDisgusted1, start=1, end=7, condensed=False)
# Out:
#   1.80s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# ### **Nephesh** as a syntactical object in Verbal Clauses
# In our second query we seek to find all verbal predicates that **Nephesh** receives as an object in VCs. Thus, we want to catalogue the activities done to **Nephesh** in order to better understand the nature of **Nephesh** as a receving entity.

# %%
NepehshObj1='''
clause kind=VC
    phrase function=Objc
        word lex=NPC/
    phrase function=Pred|PreO|PreC
        word sp=verb lex* lex_utf8* freq_lex* vt* vs*
'''
NepehshObj1  = A.search(NepehshObj1)
A.table(NepehshObj1, start=1, end=4, condensed=True)
# Out:
#   3.18s 250 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.export(NepehshObj1, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='NepehshObj1.tsv')

# %%
NepehshObj1=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/NepehshObj1.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
NepehshObj1.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   1  20  427621  clause
# 1  2  Genesis   1  21  427623  clause
# 2  3  Genesis   1  24  427640  clause
# 3  4  Genesis   2  19  427749  clause
# 4  5  Genesis   9   4  428273  clause
#
#                                                TEXT1 kind1   NODE2   TYPE2  \
# 0     יִשְׁרְצ֣וּ הַמַּ֔יִם שֶׁ֖רֶץ נֶ֣פֶשׁ חַיָּ֑ה     VC  651750  phrase
# 1  וַיִּבְרָ֣א אֱלֹהִ֔ים אֶת־הַתַּנִּינִ֖ם הַגְּד...    VC  651758  phrase
# 2      תֹּוצֵ֨א הָאָ֜רֶץ נֶ֤פֶשׁ חַיָּה֙ לְמִינָ֔הּ     VC  651802  phrase
# 3    אֲשֶׁ֨ר יִקְרָא־לֹ֧ו הָֽאָדָ֛ם נֶ֥פֶשׁ חַיָּ֖ה     VC  652123  phrase
# 4  אַךְ־בָּשָׂ֕ר בְּנַפְשֹׁ֥ו דָמֹ֖ו לֹ֥א תֹאכֵֽל...    VC  653791  phrase
#
#                                                TEXT2 function2  NODE3 TYPE3  \
# 0                           שֶׁ֖רֶץ נֶ֣פֶשׁ חַיָּ֑ה       Objc    367  word
# 1  אֶת־הַתַּנִּינִ֖ם הַגְּדֹלִ֑ים וְאֵ֣ת כָּל־נֶ֣...      Objc    391  word
# ...

# %%
NepehshObj1["lex_utf85"].value_counts()
# Out:
# בקשׁ    21
# נצל     16
# מלט     14
# נשׂא    10
# נכה     10
#         ..
# בזה      1
# ארך      1
# נשׁא     1
# שׂנא     1
# ישׁע     1
# Name: lex_utf85, Length: 91, dtype: int64

# %% [markdown]
# - For the constrution BQC[ + NPC/ see the next section on complements. Its a typical constructon with the meaning "ich will dir an die Kehle".
# - like BQC[ NKH[and >BD[ make its more explicit. To hit (NKH[) the NPC means to kill a person: Gen 37:21, lev 24:17+18 (to strike the soul of a man or an animal), Num 35:15+Deut 19:6 - here NPC stands for a human being. >BD[ in Lev 23:30, Eze 22:27 it clearlz refers to destruction/death of the soul.
# - as the opposite pair to BQC[ the construction with NYL[ and MLV[ and CMR[ is frequent and expresses salvation/rescue (NYL[: Jos 2:13, Jer 20:13, MLV[: 1 Sam 19:11, 2 sam 19:6, Jer 48:6; CMR[ Deut 4:9, psa 25:20 => "protect my soul" stands in parallelism with "save me", Job 2:6 [cf Job 2:4]).
# - Josh 11:11 is a nice example for when one wants to hit/kill the soul it means that no breath/breathing (נְשָׁמָה) is left.
#
# - with LQX[ the construction with NPC/ shows that here NPC/ means "people" (Gen 12:5, 36:6, )
#
# **1 kgs 19:4** Eliah asks that his soul/NPC can die.

# %% [markdown]
# ### **Nephesh** as a syntactical complement (indirect object) in Verbal Clauses
# In our third query we seek to find all verbal predicates that **Nephesh** receives as an indirect object in VCs. Thus, we want to catalogue the activities done to **Nephesh** in order to better understand the nature of **Nephesh** as a receving entity.

# %%
NepehshCmpl1='''
clause kind=VC
    phrase function=Cmpl
        word lex=NPC/
    phrase function=Pred|PreO|PreC
        word sp=verb lex* lex_utf8* freq_lex* vt* vs*
'''
NepehshCmpl1  = A.search(NepehshCmpl1)
A.table(NepehshCmpl1, start=1, end=4, condensed=True)
# Out:
#   2.74s 98 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase</th><th class="tf">phrase</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.export(NepehshCmpl1, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='NepehshCmpl1.tsv')

# %%
NepehshCmpl1=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/NepehshCmpl1.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
NepehshCmpl1.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   9   5  428274  clause
# 1  2  Genesis   9  12  428298  clause
# 2  3  Genesis  19  17  429191  clause
# 3  4  Genesis  44  30  432837  clause
# 4  5   Exodus  30  15  436757  clause
#
#                                                TEXT1 kind1   NODE2   TYPE2  \
# 0  וְאַ֨ךְ אֶת־דִּמְכֶ֤ם לְנַפְשֹֽׁתֵיכֶם֙ אֶדְרֹ...    VC  653796  phrase
# 1  אֲשֶׁר־אֲנִ֣י נֹתֵ֗ן בֵּינִי֙ וּבֵ֣ינֵיכֶ֔ם וּ...    VC  653867  phrase
# 2                          הִמָּלֵ֣ט עַל־נַפְשֶׁ֔ךָ     VC  656579  phrase
# 3               וְנַפְשֹׁ֖ו קְשׁוּרָ֥ה בְנַפְשֹֽׁו׃     VC  667439  phrase
# 4                     לְכַפֵּ֖ר עַל־נַפְשֹׁתֵיכֶֽם׃     VC  679439  phrase
#
#                                                TEXT2 function2  NODE3 TYPE3  \
# 0                                 לְנַפְשֹֽׁתֵיכֶם֙       Cmpl   4114  word
# 1  בֵּינִי֙ וּבֵ֣ינֵיכֶ֔ם וּבֵ֛ין כָּל־נֶ֥פֶשׁ חַ...      Cmpl   4257  word
# ...

# %%
NepehshCmpl1["lex_utf85"].value_counts()
# Out:
# נתן     15
# אסר     10
# כפר      6
# אמר      4
# נגע      3
# שׁמר     3
# עשׂה     3
# בוא      3
# היה      3
# לקח      2
# עמד      2
# עבר      2
# שׁלח     2
# שׂים     2
# שׁבע     2
# קשׁר     2
# הלל      1
# מלט      1
# גדד      1
# ענה      1
# הלך      1
# ישׁע     1
# קרב      1
# ארב      1
# עלל      1
# ירא      1
# שׁאף     1
# מצא      1
# חתת      1
# צפן      1
# דמה      1
# נפל      1
# נעם      1
# שׂיח     1
# חטא      1
# עשׁק     1
# רהב      1
# תעה      1
# סבב      1
# שׁית     1
# נקשׁ     1
# כרה      1
# דבר      1
# דרשׁ     1
# ערב      1
# טמא      1
# בקשׁ     1
# נזה      1
# שׁאל     1
# זבח      1
# Name: lex_utf85, dtype: int64

# %%
NepehshCmpl2='''
clause kind=VC
    phrase function=Cmpl
        word sp=prep lex* lex_utf8*
        word lex=NPC/
    phrase function=Pred|PreO|PreC
        word sp=verb lex* lex_utf8* freq_lex* vt* vs*
'''
NepehshCmpl2  = A.search(NepehshCmpl2)
A.table(NepehshCmpl2, start=1, end=4, condensed=True)
# Out:
#   4.08s 112 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
A.export(NepehshCmpl2, toDir='D:/OneDrive/1200_AUS-research/Fabric-TEXT', toFile='NepehshCmpl2.tsv')

# %%
NepehshCmpl2=pd.read_csv('D:/OneDrive/1200_AUS-research/Fabric-TEXT/NepehshCmpl2.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
NepehshCmpl2.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   9   5  428274  clause
# 1  2  Genesis  19  17  429191  clause
# 2  3  Genesis  44  30  432837  clause
# 3  4   Exodus  30  15  436757  clause
# 4  5   Exodus  30  16  436761  clause
#
#                                                TEXT1 kind1   NODE2   TYPE2  \
# 0  וְאַ֨ךְ אֶת־דִּמְכֶ֤ם לְנַפְשֹֽׁתֵיכֶם֙ אֶדְרֹ...    VC  653796  phrase
# 1                          הִמָּלֵ֣ט עַל־נַפְשֶׁ֔ךָ     VC  656579  phrase
# 2               וְנַפְשֹׁ֖ו קְשׁוּרָ֥ה בְנַפְשֹֽׁו׃     VC  667439  phrase
# 3                     לְכַפֵּ֖ר עַל־נַפְשֹׁתֵיכֶֽם׃     VC  679439  phrase
# 4                   לְכַפֵּ֖ר עַל־נַפְשֹׁתֵיכֶֽם׃ פ     VC  679454  phrase
#
#                     TEXT2 function2  NODE3 TYPE3 TEXT3 lex3 lex_utf83   sp3  \
# 0      לְנַפְשֹֽׁתֵיכֶם֙       Cmpl   4113  word    לְ    L         ל  prep
# 1         עַל־נַפְשֶׁ֔ךָ       Cmpl   8813  word  עַל־   <L        על  prep
# ...

# %%
NepehshCmpl2["lex_utf83"].value_counts()
# Out:
# ב     43
# על    32
# ל     29
# אל     3
# מן     2
# עד     2
# כ      1
# Name: lex_utf83, dtype: int64

# %%
NepheshCmplB = NepehshCmpl2[
          (NepehshCmpl2['lex3'] == '<L')
        & (NepehshCmpl2['lex4'] == 'NPC/')
       ]
NepheshCmplB['lex6'].value_counts()
# Out:
# >SR[    10
# KPR[     5
# NZH[     3
# <MD[     2
# FJM[     2
# BW>[     2
# <BR[     2
# DBR[     1
# GDD[     1
# HLL[     1
# XV>[     1
# MLV[     1
# BQC[     1
# Name: lex6, dtype: int64

# %% [markdown]
# 1. What the results show is that NPC/ can also mean craving as a noun (Ezekiel 16:27, Psa 41:3).
# 2. Another typical construction is BQC[ + NPC/ meaning "to go after once life". (33x: Ex 4:19, 1 sam 20:1, etc)

# %%
NepheshBiqesh1 = '''
clause
    word lex=NPC/
    word lex=BQC[
'''
NepheshBiqesh1  = A.search(NepheshBiqesh1)
A.table(NepheshBiqesh1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   0.91s 33 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
KRToff = '''
clause
    phrase function=Objc
        word lex* lex_utf8* sp=nmpr
    phrase function=Pred
        word lex=KRT[
'''
KRToff  = A.search(KRToff)
A.table(KRToff, start=1, end=20, colorMap={2: 'magenta', 5: 'yellow'}, condensed=False)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   2.16s 16 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# ## Nepesh alive and Nephesh dead

# %%
DeadNephesh = '''
phrase
    word lex=NPC/
    <: word lex=MWT[
'''
DeadNephesh  = A.search(DeadNephesh)
A.table(DeadNephesh, start=1, end=50, colorMap={3: 'magenta', 5: 'yellow'}, condensed=True)
# A.show(DeadNephesh, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   0.86s 2 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
LivingNephesh = '''
phrase
    word lex=NPC/
    <: word lex=XJ/
'''
LivingNephesh  = A.search(LivingNephesh)
A.table(LivingNephesh, start=1, end=50, colorMap={3: 'magenta', 5: 'yellow'}, condensed=True)
# A.show(LivingNephesh, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   0.83s 9 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# ## Nepesh as body part vs Nephesh as pars pro toto

# %%
NepheshInTheBody = '''
verse book=Proverbia
    c1:clause
        p1:phrase
            w1:word lex=NPC/ prs_ps*
    c2:clause
        p2:phrase
            w2:word lex#NPC/ prs_ps*
p1 .function=function. p2
w1 .prs_ps=prs_ps. w2

'''
NepheshInTheBody  = A.search(NepheshInTheBody)
A.table(NepheshInTheBody, start=1, end=50, colorMap={3: 'magenta', 5: 'yellow'}, condensed=True)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   2.09s 61 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">clause</th><th class="tf">phrase</th></tr>
# ...

# %%
NepheshOfFlesh = '''
clause 
    phrase
        w1:word lex=NPC/
        w2:word lex=BFR/
'''
NepheshOfFlesh  = A.search(NepheshOfFlesh)
A.table(NepheshOfFlesh, start=1, end=50, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   0.86s 6 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# ## JHWH's NPC/

# %%
NepheshOfJHWH = '''
clause 
    phrase
        w1:word lex=NPC/
    phrase function=Subj
        w2:word lex=JHWH/|>L/|>LHJM/
'''
NepheshOfJHWH  = A.search(NepheshOfJHWH)
A.table(NepheshOfJHWH, start=1, end=50, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   1.17s 9 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# ## To swear by your soul

# %%
NepheshSwearing = '''
clause 
    phrase
        w1:word lex=NPC/
    phrase function=Pred
        w2:word lex=CB<[
'''
NepheshSwearing  = A.search(NepheshSwearing)
A.table(NepheshSwearing, start=1, end=50, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   1.43s 2 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# ## Flesh faints

# %%
FleshFaints1 = '''
clause 
        w1:word lex=BFR/
        w2:word lex=KMH[
'''
FleshFaints1  = A.search(FleshFaints1)
A.table(FleshFaints1, start=1, end=50, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   0.80s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %%
FleshFaints2 = '''
clause 
    phrase function=Pred|PreC
        word lex* vs=qal|piel|hif
    phrase function=Subj
        word lex=BFR/
'''
FleshFaints2  = A.search(FleshFaints2)
A.table(FleshFaints2, start=1, end=50, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   1.78s 44 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %%
Psa63 = '''
verse book=Psalmi chapter=63 verse=2 
    word lex*
'''
Psa63  = A.search(Psa63)
A.show(Psa63, start=1, end=50, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   0.47s 17 results
# <p><b>result</b> <i>1</i></p>
# ...

# %% [markdown]
# ## Check the following
# 1. attribution of Nephesh
# 2. relative clauses for Nephesh
# 3. construct relationships: how often does soul stand by itself, how often is it part of another entity (soul of Abraham).

# %% [markdown]
# ### Nephesh with attributes

# %%
NepheshAdjSub1 = '''
phrase
    sp1M:subphrase
        word lex=NPC/
    sp2D:subphrase  rela=rec|ajd|atr
        word sp=adjv lex_utf8* lex*

sp1M <mother- sp2D
'''
NepheshAdjSub1  = A.search(NepheshAdjSub1)
A.table(NepheshAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# A.show(GodsAdjSub1, start=1, end=10, colorMap={3: 'magenta', 5: 'yellow'}, condensed=False)
# Out:
#   1.86s 19 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">phrase</th><th class="tf">subphrase</th><th class="tf">word</th><th class="tf">subphrase</th><th class="tf">word</th></tr>
# ...

# %% [markdown]
# With the exception of two cases, Nepesh is always attributed with "alive".

# %% [markdown]
# #### Nephesh attributed with relative clauses

# %%
NepheshRelas1 = '''
sentence
    cl1:clause
        w1M:word lex=NPC/
    cl2D:clause rela=Attr
        word lex=>KL[

'''
NepheshRelas1  = A.search(NepheshRelas1)
A.table(NepheshRelas1, start=1, end=12, condensed=False, colorMap={2: 'magenta', 4: 'yellow'})
#A.show(NepheshRelas1, start=1, end=2, condensed=False, colorMap={2: 'magenta', 4: 'yellow'})
# Out:
#   0.96s 11 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">word</th></tr>
# ...

# %%
NepheshRelas2 = '''
sentence
    cl1:clause
        w1M:word lex=NPC/
    cl2D:clause rela=Attr
        phrase function=Pred|PreO|PreC|PreS
            word lex*

w1M <mother- cl2D
'''
NepheshRelas2  = A.search(NepheshRelas2)
A.table(NepheshRelas2, start=1, end=14, condensed=False, colorMap={3: 'magenta', 6: 'yellow'})
#A.show(NepheshRelas2, start=1, end=2, condensed=False, colorMap={3: 'magenta', 6: 'yellow'})
# Out:
#   1.71s 14 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">clause</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %%
NepheshRelas3 = '''
sentence
    cl1:clause
        p1M:phrase
                word lex=NPC/
    cl2D:clause rela=Attr

p1M <mother- cl2D
'''
NepheshRelas3  = A.search(NepheshRelas3)
A.table(NepheshRelas3, start=1, end=37, condensed=False, colorMap={3: 'magenta', 5: 'yellow'})
#A.show(GodsRelas4, start=1, end=2, condensed=False, colorMap={3: 'magenta', 5: 'yellow'})
# Out:
#   0.59s 37 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">clause</th></tr>
# ...

# %%
NepheshRelas4 = '''
sentence
    cl1:clause
        p1M:phrase
                word lex=NPC/
    cl2D:clause rela=Attr
        phrase function=Pred|PreO|PreC|PreS
            word lex*

p1M <mother- cl2D
'''
NepheshRelas4  = A.search(NepheshRelas4)
A.table(NepheshRelas4, start=1, end=2, condensed=False, colorMap={3: 'magenta', 5: 'yellow'})
#A.show(NepheshRelas4, start=1, end=2, condensed=False, colorMap={3: 'magenta', 5: 'yellow'})
# Out:
#   2.26s 37 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">sentence</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# ...

# %%
NepheshRelas5 = '''
sentence
    cl1M:clause
            word lex=NPC/
    cl2D:clause rela=Attr

cl1M <mother- cl2D
'''
NepheshRelas5  = A.search(NepheshRelas5)
A.table(NepheshRelas5, start=1, end=2, condensed=False, colorMap={3: 'magenta', 4: 'yellow'})
#A.show(NepheshRelas5, start=1, end=2, condensed=False, colorMap={2: 'magenta', 4: 'yellow'})
# Out:
#   0.58s 0 results
# <table></table>

# %%
SearchTheHeart = '''
clause
    phrase
        word lex=BQC[
    phrase
        word lex=LB/
'''
SearchTheHeart  = A.search(SearchTheHeart)
A.show(SearchTheHeart, start=1, end=2, condensed=False, colorMap={3: 'magenta', 4: 'yellow'})
#A.show(NepheshRelas5, start=1, end=2, condensed=False, colorMap={2: 'magenta', 4: 'yellow'})
# Out:
#   1.19s 2 results
# <p><b>result</b> <i>1</i></p>
# ...

# %% [markdown]
# # Quotes from literature
# 1. "The adjectival form “soulish” indicates a person governed by the sensuous nature with subjection to appetite and passion. Such a person is “natural/unspiritual” and cannot receive the gifts of God’s Spirit because they make no sense to him (1 Cor. 2:14–15). (Carl Schultz, “Soul,” in Evangelical Dictionary of Biblical Theology, electronic ed., Baker reference library (Grand Rapids: Baker Book House, 1996), 744.)
# 2. "Nepeš in the Old Testament is never the “immortal soul” but simply the life principle or living being. (Carl Schultz, “Soul,” in Evangelical Dictionary of Biblical Theology, electronic ed., Baker reference library (Grand Rapids: Baker Book House, 1996), 743.)
# 3. "Frequently in the Old Testament nepesû designates the individual (Lev. 17:10; 23:30). In its plural form it indicates a number of individuals such as Abraham’s party (Gen. 12:5), (Carl Schultz, “Soul,” in Evangelical Dictionary of Biblical Theology, electronic ed., Baker reference library (Grand Rapids: Baker Book House, 1996), 743.)
# 4. "Nepesû qualified by “dead” means a dead individual, a corpse (Num. 6:6). More significant here is that nepesû can mean the corpse of an individual even without the qualification “dead” (Num. 5:2; 6:11). Here nepesû is detached from the concept of life and refers to the corpse. Hebrew thought could not conceive of a disembodied nepesû. (Carl Schultz, “Soul,” in Evangelical Dictionary of Biblical Theology, electronic ed., Baker reference library (Grand Rapids: Baker Book House, 1996), 743.)
# 5. "Frequently nepesû takes the place of a personal or reflexive pronoun (Ps. 54:4; Prov. 18:7). Admittedly this movement from the nominal to the pronominal is without an exact borderline. The Revised Standard Version reflects the above understanding of nepesû by replacing the King James Version “soul” with such translations as “being,” “one,” “self,” “I/me.” (Carl Schultz, “Soul,” in Evangelical Dictionary of Biblical Theology, electronic ed., Baker reference library (Grand Rapids: Baker Book House, 1996), 743.)
# 6. "It can refer to the throat (Isa. 5:14; Hab. 2:5), noting that it can be parched and dry (Num. 11:6; Jer. 31:12, 25), discerning (Prov. 16:23), hungry (Num. 21:5), and breathing (Jer. 2:24). Nepesû also can mean the neck, and the vital function that takes place there, noting that it can be ensnared (1 Sam. 28:9; Ps. 105:18), humbled and endangered (Prov. 18:7), and bowed to the ground (Ps. 44:25). Even while focusing on a single part of the body, by synecdoche the whole person is represented. (Carl Schultz, “Soul,” in Evangelical Dictionary of Biblical Theology, electronic ed., Baker reference library (Grand Rapids: Baker Book House, 1996), 743.)
# 7. "Instead of splitting a person into two or three parts, Hebrew thought sees a unified being, but one that is profoundly complex, a psychophysical being. (Carl Schultz, “Soul,” in Evangelical Dictionary of Biblical Theology, electronic ed., Baker reference library (Grand Rapids: Baker Book House, 1996), 743–744.)

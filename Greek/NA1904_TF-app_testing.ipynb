# %%
# %load_ext autoreload
# %autoreload 2

# %%
# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections
import pandas as pd
import numpy as np
import re
import csv
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %%
#NA2 = use('NA1904/tf/1904_v3', hoist=globals())
NA = use("CenterBLC/NA", version="1904")
# Out:
# The requested TF-app is not available offline
# 	~/text-fabric-data/github/CenterBLC/NA/app not found
# rate limit is 5000 requests per hour, with 5000 left for this hour
# 	connecting to online GitHub repo CenterBLC/NA ... connected
# 	app/config.yaml...downloaded
# 	OK
# <b title="latest release">TF-app:</b> <span title="rv1.0.24=#1416756d3b7c9aed1530d207d087ab30707f82cc">~/text-fabric-data/github/CenterBLC/NA/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/CenterBLC/NA/tf/1904 not found
# rate limit is 5000 requests per hour, with 4988 left for this hour
# 	connecting to online GitHub repo CenterBLC/NA ... connected
# 	tf/1904/abc_order.tf...downloaded
# 	tf/1904/bol_dict_abc.tf...downloaded
# 	tf/1904/bol_gloss.tf...downloaded
# 	tf/1904/bol_lemma_dict.tf...downloaded
# 	tf/1904/book.tf...downloaded
# 	tf/1904/book_code.tf...downloaded
# 	tf/1904/book_short.tf...downloaded
# 	tf/1904/bookshort.tf...downloaded
# 	tf/1904/case.tf...downloaded
# ...

# %%
Search0 = '''
book book=Matthew
  chapter chapter=1
    verse verse=1
      word
'''
Search0 = NA.search(Search0)
NA.show(Search0, start=1, end=3, condensed=True, colorMap={1:'pink'}, extraFeatures={'bol_dict_abc','bol_lemma_dict', 'bol_gloss', 'lemma','morph_form','morph_functional','normalized','strongs', 'case', 'degree', 'bol_dict_abc','extra', 'freq_lemma', 'gloss', 'gn', 'lemma', 'lexeme_dict', 'mood', 'nu', 'orig_order', 'ps', 'sp', 'strongs','tense','voice'})
# Out:
#   0.10s 8 results
# <p><b>verse</b> <i>1</i></p>
# ...

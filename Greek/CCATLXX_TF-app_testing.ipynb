# %%
# %load_ext autoreload
# %autoreload 2

# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections
import pandas as pd
import numpy as np
import re
import csv
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %%
#LXX = use('CCATLXX/tf/1994_v1', hoist=globals())
#LXX = use('CCATLXX/tf/1994_v2', hoist=globals())
LXX = use("CenterBLC/LXX", version="1935")
# Out:
# The requested TF-app is not available offline
# 	~/text-fabric-data/github/CenterBLC/LXX/app not found
# rate limit is 5000 requests per hour, with 4887 left for this hour
# 	connecting to online GitHub repo CenterBLC/LXX ... connected
# 	app/config.yaml...downloaded
# 	OK
# <b title="latest release">TF-app:</b> <span title="rv1.0.1=#f32a98eddf7eb239aa73ab863d70381e416d5076">~/text-fabric-data/github/CenterBLC/LXX/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/CenterBLC/LXX/tf/1935 not found
# rate limit is 5000 requests per hour, with 4875 left for this hour
# 	connecting to online GitHub repo CenterBLC/LXX ... connected
# 	tf/1935/abc_order.tf...downloaded
# 	tf/1935/bol_gloss.tf...downloaded
# 	tf/1935/bol_lexeme_dict.tf...downloaded
# 	tf/1935/book.tf...downloaded
# 	tf/1935/case.tf...downloaded
# 	tf/1935/chapter.tf...downloaded
# 	tf/1935/degree.tf...downloaded
# 	tf/1935/freq_lemma.tf...downloaded
# 	tf/1935/g_cons_utf8.tf...downloaded
# ...

# %%
Search0 = '''
book book=Gen
  chapter chapter=1
    verse verse=1
      word
'''
Search0 = LXX.search(Search0)
LXX.show(Search0, start=1, end=1, condensed=True, colorMap={1:'pink'}, extraFeatures={'lex','lex_utf8','bol_gloss','bol_lexeme_dict','freq_lemma','g_cons_utf8','book','verse','orig_order','voice','translit_SBL','tense','strongs','sp','ps','nu','gn','orig_order','abc_order','nu','morphology','mood','gn','gloss','degree','case'})
# Out:
#   0.10s 10 results
# <p><b>verse</b> <i>1</i></p>
# ...

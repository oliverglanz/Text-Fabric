# %%
# %load_ext autoreload
# %autoreload 2

# %%
# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections
import pandas as pd
import numpy as np
import re
import csv
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %%
#SBLGNTv1 = use('SBLGNT/tf/6.12_v1', hoist=globals())
#SBLGNTv2 = use('SBLGNT/tf/6.12_v2', hoist=globals())
SBLGNT = use("CenterBLC/SBLGNT", version="2022")
# Out:
# The requested TF-app is not available offline
# 	~/text-fabric-data/github/CenterBLC/SBLGNT/app not found
# rate limit is 5000 requests per hour, with 4941 left for this hour
# 	connecting to online GitHub repo CenterBLC/SBLGNT ... connected
# 	app/config.yaml...downloaded
# 	OK
# <b title="latest release">TF-app:</b> <span title="rv1.0.11=#3c1695b7ffc87b74975ca57312d62a55000c9505">~/text-fabric-data/github/CenterBLC/SBLGNT/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/CenterBLC/SBLGNT/tf/2022 not found
# rate limit is 5000 requests per hour, with 4929 left for this hour
# 	connecting to online GitHub repo CenterBLC/SBLGNT ... connected
# 	tf/2022/book.tf...downloaded
# 	tf/2022/book_code.tf...downloaded
# 	tf/2022/case.tf...downloaded
# 	tf/2022/chapter.tf...downloaded
# 	tf/2022/clause.tf...downloaded
# 	tf/2022/degree.tf...downloaded
# 	tf/2022/dict_abc_order.tf...downloaded
# 	tf/2022/gloss.tf...downloaded
# 	tf/2022/gn.tf...downloaded
# ...

# %%
Search0 = '''
book book=Matthew
  chapter chapter=1
    verse verse=1
        word

'''
Search0 = SBLGNT.search(Search0)
SBLGNT.show(Search0, start=1, end=3, condensed=True, colorMap={1:'pink'}, extraFeatures={'verse','vrsnum','orig_order','voice','translit','tense','strongs','ps','nu','orig_order','nu','normalized_word','morphology','morph','mood','lemma_freq','lemma_dictform','lemma','gn','gloss','dict_abc_order','degree','clause','case'})
# Out:
#   0.08s 8 results
# <p><b>verse</b> <i>1</i></p>
# ...
